# %%
# !pip install openmeteo-requests
# !pip install requests-cache retry-requests numpy pandas
# Out:
# Collecting openmeteo-requests
#   Downloading openmeteo_requests-1.3.0-py3-none-any.whl.metadata (9.7 kB)
# Collecting openmeteo-sdk>=1.4.0 (from openmeteo-requests)
#   Downloading openmeteo_sdk-1.19.0-py3-none-any.whl.metadata (935 bytes)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from openmeteo-requests) (2.32.3)
# Requirement already satisfied: flatbuffers==25.2.10 in /usr/local/lib/python3.11/dist-packages (from openmeteo-sdk>=1.4.0->openmeteo-requests) (25.2.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->openmeteo-requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->openmeteo-requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->openmeteo-requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->openmeteo-requests) (2025.1.31)
# Downloading openmeteo_requests-1.3.0-py3-none-any.whl (6.0 kB)
# Downloading openmeteo_sdk-1.19.0-py3-none-any.whl (15 kB)
# Installing collected packages: openmeteo-sdk, openmeteo-requests
# Successfully installed openmeteo-requests-1.3.0 openmeteo-sdk-1.19.0
# Collecting requests-cache
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting retry-requests
#   Downloading retry_requests-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.11/dist-packages (from requests-cache) (25.1.0)
# Collecting cattrs>=22.2 (from requests-cache)
#   Downloading cattrs-24.1.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests-cache) (4.3.6)
# Requirement already satisfied: requests>=2.22 in /usr/local/lib/python3.11/dist-packages (from requests-cache) (2.32.3)
# Collecting url-normalize>=1.4 (from requests-cache)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: urllib3>=1.25.5 in /usr/local/lib/python3.11/dist-packages (from requests-cache) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22->requests-cache) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22->requests-cache) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22->requests-cache) (2025.1.31)
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 2.5 MB/s eta 0:00:00
# Downloading retry_requests-2.0.0-py3-none-any.whl (15 kB)
# Downloading cattrs-24.1.2-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 2.8 MB/s eta 0:00:00
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: url-normalize, cattrs, retry-requests, requests-cache
# Successfully installed cattrs-24.1.2 requests-cache-1.2.1 retry-requests-2.0.0 url-normalize-1.4.3

# %%
import openmeteo_requests

import requests_cache
import pandas as pd
from retry_requests import retry

# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": 52.52,
	"longitude": 13.41,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth", "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", "soil_moisture_27_to_81cm"],
	"start_date": "2024-12-01",
	"end_date": "2025-03-04"
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_showers = hourly.Variables(7).ValuesAsNumpy()
hourly_snowfall = hourly.Variables(8).ValuesAsNumpy()
hourly_snow_depth = hourly.Variables(9).ValuesAsNumpy()
hourly_weather_code = hourly.Variables(10).ValuesAsNumpy()
hourly_pressure_msl = hourly.Variables(11).ValuesAsNumpy()
hourly_surface_pressure = hourly.Variables(12).ValuesAsNumpy()
hourly_cloud_cover = hourly.Variables(13).ValuesAsNumpy()
hourly_cloud_cover_low = hourly.Variables(14).ValuesAsNumpy()
hourly_cloud_cover_mid = hourly.Variables(15).ValuesAsNumpy()
hourly_cloud_cover_high = hourly.Variables(16).ValuesAsNumpy()
hourly_visibility = hourly.Variables(17).ValuesAsNumpy()
hourly_evapotranspiration = hourly.Variables(18).ValuesAsNumpy()
hourly_et0_fao_evapotranspiration = hourly.Variables(19).ValuesAsNumpy()
hourly_vapour_pressure_deficit = hourly.Variables(20).ValuesAsNumpy()
hourly_wind_speed_10m = hourly.Variables(21).ValuesAsNumpy()
hourly_wind_speed_80m = hourly.Variables(22).ValuesAsNumpy()
hourly_wind_speed_120m = hourly.Variables(23).ValuesAsNumpy()
hourly_wind_speed_180m = hourly.Variables(24).ValuesAsNumpy()
hourly_wind_direction_10m = hourly.Variables(25).ValuesAsNumpy()
hourly_wind_direction_80m = hourly.Variables(26).ValuesAsNumpy()
hourly_wind_direction_120m = hourly.Variables(27).ValuesAsNumpy()
hourly_wind_direction_180m = hourly.Variables(28).ValuesAsNumpy()
hourly_wind_gusts_10m = hourly.Variables(29).ValuesAsNumpy()
hourly_temperature_80m = hourly.Variables(30).ValuesAsNumpy()
hourly_temperature_120m = hourly.Variables(31).ValuesAsNumpy()
hourly_temperature_180m = hourly.Variables(32).ValuesAsNumpy()
hourly_soil_temperature_0cm = hourly.Variables(33).ValuesAsNumpy()
hourly_soil_temperature_6cm = hourly.Variables(34).ValuesAsNumpy()
hourly_soil_temperature_18cm = hourly.Variables(35).ValuesAsNumpy()
hourly_soil_temperature_54cm = hourly.Variables(36).ValuesAsNumpy()
hourly_soil_moisture_0_to_1cm = hourly.Variables(37).ValuesAsNumpy()
hourly_soil_moisture_1_to_3cm = hourly.Variables(38).ValuesAsNumpy()
hourly_soil_moisture_3_to_9cm = hourly.Variables(39).ValuesAsNumpy()
hourly_soil_moisture_9_to_27cm = hourly.Variables(40).ValuesAsNumpy()
hourly_soil_moisture_27_to_81cm = hourly.Variables(41).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["showers"] = hourly_showers
hourly_data["snowfall"] = hourly_snowfall
hourly_data["snow_depth"] = hourly_snow_depth
hourly_data["weather_code"] = hourly_weather_code
hourly_data["pressure_msl"] = hourly_pressure_msl
hourly_data["surface_pressure"] = hourly_surface_pressure
hourly_data["cloud_cover"] = hourly_cloud_cover
hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
hourly_data["visibility"] = hourly_visibility
hourly_data["evapotranspiration"] = hourly_evapotranspiration
hourly_data["et0_fao_evapotranspiration"] = hourly_et0_fao_evapotranspiration
hourly_data["vapour_pressure_deficit"] = hourly_vapour_pressure_deficit
hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
hourly_data["wind_speed_80m"] = hourly_wind_speed_80m
hourly_data["wind_speed_120m"] = hourly_wind_speed_120m
hourly_data["wind_speed_180m"] = hourly_wind_speed_180m
hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
hourly_data["wind_direction_80m"] = hourly_wind_direction_80m
hourly_data["wind_direction_120m"] = hourly_wind_direction_120m
hourly_data["wind_direction_180m"] = hourly_wind_direction_180m
hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m
hourly_data["temperature_80m"] = hourly_temperature_80m
hourly_data["temperature_120m"] = hourly_temperature_120m
hourly_data["temperature_180m"] = hourly_temperature_180m
hourly_data["soil_temperature_0cm"] = hourly_soil_temperature_0cm
hourly_data["soil_temperature_6cm"] = hourly_soil_temperature_6cm
hourly_data["soil_temperature_18cm"] = hourly_soil_temperature_18cm
hourly_data["soil_temperature_54cm"] = hourly_soil_temperature_54cm
hourly_data["soil_moisture_0_to_1cm"] = hourly_soil_moisture_0_to_1cm
hourly_data["soil_moisture_1_to_3cm"] = hourly_soil_moisture_1_to_3cm
hourly_data["soil_moisture_3_to_9cm"] = hourly_soil_moisture_3_to_9cm
hourly_data["soil_moisture_9_to_27cm"] = hourly_soil_moisture_9_to_27cm
hourly_data["soil_moisture_27_to_81cm"] = hourly_soil_moisture_27_to_81cm

hourly_dataframe = pd.DataFrame(data = hourly_data)
print(hourly_dataframe)
# Out:
# Coordinates 52.52000045776367°N 13.419998168945312°E
# Elevation 38.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#                           date  temperature_2m  relative_humidity_2m  \
# 0    2024-12-01 00:00:00+00:00             NaN                   NaN
# 1    2024-12-01 01:00:00+00:00             NaN                   NaN
# 2    2024-12-01 02:00:00+00:00             NaN                   NaN
# 3    2024-12-01 03:00:00+00:00             NaN                   NaN
# 4    2024-12-01 04:00:00+00:00             NaN                   NaN
# ...                        ...             ...                   ...
# 2251 2025-03-04 19:00:00+00:00          7.8955                  50.0
# 2252 2025-03-04 20:00:00+00:00          6.9455                  54.0
# 2253 2025-03-04 21:00:00+00:00          6.3955                  55.0
# 2254 2025-03-04 22:00:00+00:00          5.7455                  54.0
# 2255 2025-03-04 23:00:00+00:00          5.1455                  54.0
#
#       dew_point_2m  apparent_temperature  precipitation_probability  \
# 0              NaN                   NaN                        0.0
# 1              NaN                   NaN                        0.0
# 2              NaN                   NaN                        0.0
# 3              NaN                   NaN                        0.0
# 4              NaN                   NaN                        0.0
# ...            ...                   ...                        ...
# 2251     -1.896171              4.322351                        0.0
# 2252     -1.731940              3.722195                        0.0
# 2253     -1.995830              2.968689                        0.0
# 2254     -2.850265              2.325986                        0.0
# 2255     -3.409566              1.651002                        0.0
#
#       precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0               NaN   NaN      NaN       NaN  ...               NaN
# 1               NaN   NaN      NaN       NaN  ...               NaN
# 2               NaN   NaN      NaN       NaN  ...               NaN
# 3               NaN   NaN      NaN       NaN  ...               NaN
# 4               NaN   NaN      NaN       NaN  ...               NaN
# ...             ...   ...      ...       ...  ...               ...
# 2251            0.0   0.0      0.0       0.0  ...            8.0455
# 2252            0.0   0.0      0.0       0.0  ...            7.6455
# 2253            0.0   0.0      0.0       0.0  ...            7.3455
# 2254            0.0   0.0      0.0       0.0  ...            6.9455
# 2255            0.0   0.0      0.0       0.0  ...            6.8455
#
#       soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2251                6.4955                8.0955               8.545500
# 2252                5.6955                7.3455               8.445499
# 2253                5.0455                6.6955               8.245500
# 2254                4.4455                6.1955               8.045500
# 2255                3.9955                5.6955               7.795500
#
#       soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 2251                 6.7955                   0.309                   0.310
# 2252                 6.7955                   0.310                   0.311
# 2253                 6.8455                   0.310                   0.311
# 2254                 6.8455                   0.310                   0.311
# 2255                 6.8455                   0.310                   0.311
#
#       soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2251                   0.313                    0.322
# 2252                   0.313                    0.322
# 2253                   0.313                    0.322
# 2254                   0.313                    0.322
# 2255                   0.313                    0.322
#
#       soil_moisture_27_to_81cm
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2251                     0.346
# 2252                     0.345
# 2253                     0.345
# 2254                     0.345
# 2255                     0.345
#
# [2256 rows x 43 columns]

# %%
hourly_dataframe.head()
# Out:
#                        date  temperature_2m  relative_humidity_2m  \
# 0 2024-12-01 00:00:00+00:00             NaN                   NaN
# 1 2024-12-01 01:00:00+00:00             NaN                   NaN
# 2 2024-12-01 02:00:00+00:00             NaN                   NaN
# 3 2024-12-01 03:00:00+00:00             NaN                   NaN
# 4 2024-12-01 04:00:00+00:00             NaN                   NaN
#
#    dew_point_2m  apparent_temperature  precipitation_probability  \
# 0           NaN                   NaN                        0.0
# 1           NaN                   NaN                        0.0
# 2           NaN                   NaN                        0.0
# 3           NaN                   NaN                        0.0
# 4           NaN                   NaN                        0.0
#
#    precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0            NaN   NaN      NaN       NaN  ...               NaN
# 1            NaN   NaN      NaN       NaN  ...               NaN
# 2            NaN   NaN      NaN       NaN  ...               NaN
# 3            NaN   NaN      NaN       NaN  ...               NaN
# 4            NaN   NaN      NaN       NaN  ...               NaN
#
#    soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                   NaN                   NaN                    NaN
# 1                   NaN                   NaN                    NaN
# 2                   NaN                   NaN                    NaN
# 3                   NaN                   NaN                    NaN
# 4                   NaN                   NaN                    NaN
#
#    soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                    NaN                     NaN                     NaN
# 1                    NaN                     NaN                     NaN
# 2                    NaN                     NaN                     NaN
# 3                    NaN                     NaN                     NaN
# 4                    NaN                     NaN                     NaN
#
#    soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  soil_moisture_27_to_81cm
# 0                     NaN                      NaN                       NaN
# 1                     NaN                      NaN                       NaN
# 2                     NaN                      NaN                       NaN
# 3                     NaN                      NaN                       NaN
# 4                     NaN                      NaN                       NaN
#
# [5 rows x 43 columns]

# %%
hourly_dataframe.isna().sum()
# Out:
# date                            0
# temperature_2m                 89
# relative_humidity_2m           89
# dew_point_2m                   89
# apparent_temperature           89
# precipitation_probability       0
# precipitation                  89
# rain                          115
# showers                        89
# snowfall                      115
# snow_depth                     90
# weather_code                  115
# pressure_msl                   89
# surface_pressure               89
# cloud_cover                    89
# cloud_cover_low                89
# cloud_cover_mid                89
# cloud_cover_high               89
# visibility                     89
# evapotranspiration              0
# et0_fao_evapotranspiration     89
# vapour_pressure_deficit        89
# wind_speed_10m                 89
# wind_speed_80m                 89
# wind_speed_120m                89
# wind_speed_180m               309
# wind_direction_10m             89
# wind_direction_80m             89
# wind_direction_120m            89
# wind_direction_180m           309
# wind_gusts_10m                 89
# temperature_80m                89
# temperature_120m               89
# temperature_180m              309
# soil_temperature_0cm          309
# soil_temperature_6cm          309
# soil_temperature_18cm         309
# soil_temperature_54cm         309
# soil_moisture_0_to_1cm        309
# soil_moisture_1_to_3cm        309
# soil_moisture_3_to_9cm        309
# soil_moisture_9_to_27cm       309
# soil_moisture_27_to_81cm      309
# dtype: int64

# %%
# hourly_dataframe.to_csv('.csv', index=False)

# %%
df1 = hourly_dataframe.copy()

# %%
df1["Country"] = "Berlin"

# %%
df1.head()
# Out:
#                        date  temperature_2m  relative_humidity_2m  \
# 0 2024-12-01 00:00:00+00:00             NaN                   NaN
# 1 2024-12-01 01:00:00+00:00             NaN                   NaN
# 2 2024-12-01 02:00:00+00:00             NaN                   NaN
# 3 2024-12-01 03:00:00+00:00             NaN                   NaN
# 4 2024-12-01 04:00:00+00:00             NaN                   NaN
#
#    dew_point_2m  apparent_temperature  precipitation_probability  \
# 0           NaN                   NaN                        0.0
# 1           NaN                   NaN                        0.0
# 2           NaN                   NaN                        0.0
# 3           NaN                   NaN                        0.0
# 4           NaN                   NaN                        0.0
#
#    precipitation  rain  showers  snowfall  ...  soil_temperature_0cm  \
# 0            NaN   NaN      NaN       NaN  ...                   NaN
# 1            NaN   NaN      NaN       NaN  ...                   NaN
# 2            NaN   NaN      NaN       NaN  ...                   NaN
# 3            NaN   NaN      NaN       NaN  ...                   NaN
# 4            NaN   NaN      NaN       NaN  ...                   NaN
#
#    soil_temperature_6cm  soil_temperature_18cm  soil_temperature_54cm  \
# 0                   NaN                    NaN                    NaN
# 1                   NaN                    NaN                    NaN
# 2                   NaN                    NaN                    NaN
# 3                   NaN                    NaN                    NaN
# 4                   NaN                    NaN                    NaN
#
#    soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  soil_moisture_3_to_9cm  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
#
#    soil_moisture_9_to_27cm  soil_moisture_27_to_81cm  Country
# 0                      NaN                       NaN   Berlin
# 1                      NaN                       NaN   Berlin
# 2                      NaN                       NaN   Berlin
# 3                      NaN                       NaN   Berlin
# 4                      NaN                       NaN   Berlin
#
# [5 rows x 44 columns]

# %%
import openmeteo_requests

import requests_cache
import pandas as pd
from retry_requests import retry

# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": 51.51,
	"longitude": -0.11,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth", "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", "soil_moisture_27_to_81cm"],
	"start_date": "2024-12-01",
	"end_date": "2025-03-04"
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_showers = hourly.Variables(7).ValuesAsNumpy()
hourly_snowfall = hourly.Variables(8).ValuesAsNumpy()
hourly_snow_depth = hourly.Variables(9).ValuesAsNumpy()
hourly_weather_code = hourly.Variables(10).ValuesAsNumpy()
hourly_pressure_msl = hourly.Variables(11).ValuesAsNumpy()
hourly_surface_pressure = hourly.Variables(12).ValuesAsNumpy()
hourly_cloud_cover = hourly.Variables(13).ValuesAsNumpy()
hourly_cloud_cover_low = hourly.Variables(14).ValuesAsNumpy()
hourly_cloud_cover_mid = hourly.Variables(15).ValuesAsNumpy()
hourly_cloud_cover_high = hourly.Variables(16).ValuesAsNumpy()
hourly_visibility = hourly.Variables(17).ValuesAsNumpy()
hourly_evapotranspiration = hourly.Variables(18).ValuesAsNumpy()
hourly_et0_fao_evapotranspiration = hourly.Variables(19).ValuesAsNumpy()
hourly_vapour_pressure_deficit = hourly.Variables(20).ValuesAsNumpy()
hourly_wind_speed_10m = hourly.Variables(21).ValuesAsNumpy()
hourly_wind_speed_80m = hourly.Variables(22).ValuesAsNumpy()
hourly_wind_speed_120m = hourly.Variables(23).ValuesAsNumpy()
hourly_wind_speed_180m = hourly.Variables(24).ValuesAsNumpy()
hourly_wind_direction_10m = hourly.Variables(25).ValuesAsNumpy()
hourly_wind_direction_80m = hourly.Variables(26).ValuesAsNumpy()
hourly_wind_direction_120m = hourly.Variables(27).ValuesAsNumpy()
hourly_wind_direction_180m = hourly.Variables(28).ValuesAsNumpy()
hourly_wind_gusts_10m = hourly.Variables(29).ValuesAsNumpy()
hourly_temperature_80m = hourly.Variables(30).ValuesAsNumpy()
hourly_temperature_120m = hourly.Variables(31).ValuesAsNumpy()
hourly_temperature_180m = hourly.Variables(32).ValuesAsNumpy()
hourly_soil_temperature_0cm = hourly.Variables(33).ValuesAsNumpy()
hourly_soil_temperature_6cm = hourly.Variables(34).ValuesAsNumpy()
hourly_soil_temperature_18cm = hourly.Variables(35).ValuesAsNumpy()
hourly_soil_temperature_54cm = hourly.Variables(36).ValuesAsNumpy()
hourly_soil_moisture_0_to_1cm = hourly.Variables(37).ValuesAsNumpy()
hourly_soil_moisture_1_to_3cm = hourly.Variables(38).ValuesAsNumpy()
hourly_soil_moisture_3_to_9cm = hourly.Variables(39).ValuesAsNumpy()
hourly_soil_moisture_9_to_27cm = hourly.Variables(40).ValuesAsNumpy()
hourly_soil_moisture_27_to_81cm = hourly.Variables(41).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["showers"] = hourly_showers
hourly_data["snowfall"] = hourly_snowfall
hourly_data["snow_depth"] = hourly_snow_depth
hourly_data["weather_code"] = hourly_weather_code
hourly_data["pressure_msl"] = hourly_pressure_msl
hourly_data["surface_pressure"] = hourly_surface_pressure
hourly_data["cloud_cover"] = hourly_cloud_cover
hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
hourly_data["visibility"] = hourly_visibility
hourly_data["evapotranspiration"] = hourly_evapotranspiration
hourly_data["et0_fao_evapotranspiration"] = hourly_et0_fao_evapotranspiration
hourly_data["vapour_pressure_deficit"] = hourly_vapour_pressure_deficit
hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
hourly_data["wind_speed_80m"] = hourly_wind_speed_80m
hourly_data["wind_speed_120m"] = hourly_wind_speed_120m
hourly_data["wind_speed_180m"] = hourly_wind_speed_180m
hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
hourly_data["wind_direction_80m"] = hourly_wind_direction_80m
hourly_data["wind_direction_120m"] = hourly_wind_direction_120m
hourly_data["wind_direction_180m"] = hourly_wind_direction_180m
hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m
hourly_data["temperature_80m"] = hourly_temperature_80m
hourly_data["temperature_120m"] = hourly_temperature_120m
hourly_data["temperature_180m"] = hourly_temperature_180m
hourly_data["soil_temperature_0cm"] = hourly_soil_temperature_0cm
hourly_data["soil_temperature_6cm"] = hourly_soil_temperature_6cm
hourly_data["soil_temperature_18cm"] = hourly_soil_temperature_18cm
hourly_data["soil_temperature_54cm"] = hourly_soil_temperature_54cm
hourly_data["soil_moisture_0_to_1cm"] = hourly_soil_moisture_0_to_1cm
hourly_data["soil_moisture_1_to_3cm"] = hourly_soil_moisture_1_to_3cm
hourly_data["soil_moisture_3_to_9cm"] = hourly_soil_moisture_3_to_9cm
hourly_data["soil_moisture_9_to_27cm"] = hourly_soil_moisture_9_to_27cm
hourly_data["soil_moisture_27_to_81cm"] = hourly_soil_moisture_27_to_81cm

df2 = pd.DataFrame(data = hourly_data)
print(df2)
# Out:
# Coordinates 51.5°N -0.10000014305114746°E
# Elevation 1.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#                           date  temperature_2m  relative_humidity_2m  \
# 0    2024-12-01 00:00:00+00:00             NaN                   NaN
# 1    2024-12-01 01:00:00+00:00             NaN                   NaN
# 2    2024-12-01 02:00:00+00:00             NaN                   NaN
# 3    2024-12-01 03:00:00+00:00             NaN                   NaN
# 4    2024-12-01 04:00:00+00:00             NaN                   NaN
# ...                        ...             ...                   ...
# 2251 2025-03-04 19:00:00+00:00          10.128                  52.0
# 2252 2025-03-04 20:00:00+00:00           8.978                  55.0
# 2253 2025-03-04 21:00:00+00:00           7.878                  64.0
# 2254 2025-03-04 22:00:00+00:00           6.978                  70.0
# 2255 2025-03-04 23:00:00+00:00           6.278                  72.0
#
#       dew_point_2m  apparent_temperature  precipitation_probability  \
# 0              NaN                   NaN                        0.0
# 1              NaN                   NaN                        0.0
# 2              NaN                   NaN                        0.0
# 3              NaN                   NaN                        0.0
# 4              NaN                   NaN                        1.0
# ...            ...                   ...                        ...
# 2251      0.707562              7.125030                        0.0
# 2252      0.414996              5.739018                        0.0
# 2253      1.485605              5.280110                        0.0
# 2254      1.879294              4.547185                        0.0
# 2255      1.600479              3.729058                        0.0
#
#       precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0               NaN   NaN      NaN       NaN  ...               NaN
# 1               NaN   NaN      NaN       NaN  ...               NaN
# 2               NaN   NaN      NaN       NaN  ...               NaN
# 3               NaN   NaN      NaN       NaN  ...               NaN
# 4               NaN   NaN      NaN       NaN  ...               NaN
# ...             ...   ...      ...       ...  ...               ...
# 2251            0.0   0.0      0.0       0.0  ...             8.578
# 2252            0.0   0.0      0.0       0.0  ...             8.078
# 2253            0.0   0.0      0.0       0.0  ...             7.878
# 2254            0.0   0.0      0.0       0.0  ...             7.878
# 2255            0.0   0.0      0.0       0.0  ...             7.078
#
#       soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2251                 8.528                10.328                  9.928
# 2252                 7.628                 9.328                  9.828
# 2253                 6.678                 8.528                  9.728
# 2254                 5.878                 7.778                  9.528
# 2255                 5.228                 7.178                  9.278
#
#       soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 2251                  8.228                   0.345                   0.346
# 2252                  8.228                   0.346                   0.346
# 2253                  8.228                   0.346                   0.347
# 2254                  8.278                   0.346                   0.347
# 2255                  8.278                   0.346                   0.347
#
#       soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2251                   0.349                    0.361
# 2252                   0.349                    0.361
# 2253                   0.349                    0.361
# 2254                   0.349                    0.361
# 2255                   0.350                    0.361
#
#       soil_moisture_27_to_81cm
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2251                     0.395
# 2252                     0.394
# 2253                     0.394
# 2254                     0.394
# 2255                     0.394
#
# [2256 rows x 43 columns]

# %%
df2.isna().sum()
# Out:
# date                            0
# temperature_2m                 89
# relative_humidity_2m           89
# dew_point_2m                   89
# apparent_temperature           89
# precipitation_probability       0
# precipitation                  89
# rain                          115
# showers                        89
# snowfall                      115
# snow_depth                     90
# weather_code                  115
# pressure_msl                   89
# surface_pressure               89
# cloud_cover                    89
# cloud_cover_low                89
# cloud_cover_mid                89
# cloud_cover_high               89
# visibility                     89
# evapotranspiration              0
# et0_fao_evapotranspiration     89
# vapour_pressure_deficit        89
# wind_speed_10m                 89
# wind_speed_80m                 89
# wind_speed_120m                89
# wind_speed_180m               309
# wind_direction_10m             89
# wind_direction_80m             89
# wind_direction_120m            89
# wind_direction_180m           309
# wind_gusts_10m                 89
# temperature_80m                89
# temperature_120m               89
# temperature_180m              309
# soil_temperature_0cm          309
# soil_temperature_6cm          309
# soil_temperature_18cm         309
# soil_temperature_54cm         309
# soil_moisture_0_to_1cm        309
# soil_moisture_1_to_3cm        309
# soil_moisture_3_to_9cm        309
# soil_moisture_9_to_27cm       309
# soil_moisture_27_to_81cm      309
# dtype: int64

# %%
df2["Country"] = "London"

# %%
df2.head()
# Out:
#                        date  temperature_2m  relative_humidity_2m  \
# 0 2024-12-01 00:00:00+00:00             NaN                   NaN
# 1 2024-12-01 01:00:00+00:00             NaN                   NaN
# 2 2024-12-01 02:00:00+00:00             NaN                   NaN
# 3 2024-12-01 03:00:00+00:00             NaN                   NaN
# 4 2024-12-01 04:00:00+00:00             NaN                   NaN
#
#    dew_point_2m  apparent_temperature  precipitation_probability  \
# 0           NaN                   NaN                        0.0
# 1           NaN                   NaN                        0.0
# 2           NaN                   NaN                        0.0
# 3           NaN                   NaN                        0.0
# 4           NaN                   NaN                        1.0
#
#    precipitation  rain  showers  snowfall  ...  soil_temperature_0cm  \
# 0            NaN   NaN      NaN       NaN  ...                   NaN
# 1            NaN   NaN      NaN       NaN  ...                   NaN
# 2            NaN   NaN      NaN       NaN  ...                   NaN
# 3            NaN   NaN      NaN       NaN  ...                   NaN
# 4            NaN   NaN      NaN       NaN  ...                   NaN
#
#    soil_temperature_6cm  soil_temperature_18cm  soil_temperature_54cm  \
# 0                   NaN                    NaN                    NaN
# 1                   NaN                    NaN                    NaN
# 2                   NaN                    NaN                    NaN
# 3                   NaN                    NaN                    NaN
# 4                   NaN                    NaN                    NaN
#
#    soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  soil_moisture_3_to_9cm  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
#
#    soil_moisture_9_to_27cm  soil_moisture_27_to_81cm  Country
# 0                      NaN                       NaN   London
# 1                      NaN                       NaN   London
# 2                      NaN                       NaN   London
# 3                      NaN                       NaN   London
# 4                      NaN                       NaN   London
#
# [5 rows x 44 columns]

# %%
df = pd.concat([df1, df2])

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": 48.85,
	"longitude": 2.35,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth", "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", "soil_moisture_27_to_81cm"],
	"start_date": "2024-12-01",
	"end_date": "2025-03-04"
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_showers = hourly.Variables(7).ValuesAsNumpy()
hourly_snowfall = hourly.Variables(8).ValuesAsNumpy()
hourly_snow_depth = hourly.Variables(9).ValuesAsNumpy()
hourly_weather_code = hourly.Variables(10).ValuesAsNumpy()
hourly_pressure_msl = hourly.Variables(11).ValuesAsNumpy()
hourly_surface_pressure = hourly.Variables(12).ValuesAsNumpy()
hourly_cloud_cover = hourly.Variables(13).ValuesAsNumpy()
hourly_cloud_cover_low = hourly.Variables(14).ValuesAsNumpy()
hourly_cloud_cover_mid = hourly.Variables(15).ValuesAsNumpy()
hourly_cloud_cover_high = hourly.Variables(16).ValuesAsNumpy()
hourly_visibility = hourly.Variables(17).ValuesAsNumpy()
hourly_evapotranspiration = hourly.Variables(18).ValuesAsNumpy()
hourly_et0_fao_evapotranspiration = hourly.Variables(19).ValuesAsNumpy()
hourly_vapour_pressure_deficit = hourly.Variables(20).ValuesAsNumpy()
hourly_wind_speed_10m = hourly.Variables(21).ValuesAsNumpy()
hourly_wind_speed_80m = hourly.Variables(22).ValuesAsNumpy()
hourly_wind_speed_120m = hourly.Variables(23).ValuesAsNumpy()
hourly_wind_speed_180m = hourly.Variables(24).ValuesAsNumpy()
hourly_wind_direction_10m = hourly.Variables(25).ValuesAsNumpy()
hourly_wind_direction_80m = hourly.Variables(26).ValuesAsNumpy()
hourly_wind_direction_120m = hourly.Variables(27).ValuesAsNumpy()
hourly_wind_direction_180m = hourly.Variables(28).ValuesAsNumpy()
hourly_wind_gusts_10m = hourly.Variables(29).ValuesAsNumpy()
hourly_temperature_80m = hourly.Variables(30).ValuesAsNumpy()
hourly_temperature_120m = hourly.Variables(31).ValuesAsNumpy()
hourly_temperature_180m = hourly.Variables(32).ValuesAsNumpy()
hourly_soil_temperature_0cm = hourly.Variables(33).ValuesAsNumpy()
hourly_soil_temperature_6cm = hourly.Variables(34).ValuesAsNumpy()
hourly_soil_temperature_18cm = hourly.Variables(35).ValuesAsNumpy()
hourly_soil_temperature_54cm = hourly.Variables(36).ValuesAsNumpy()
hourly_soil_moisture_0_to_1cm = hourly.Variables(37).ValuesAsNumpy()
hourly_soil_moisture_1_to_3cm = hourly.Variables(38).ValuesAsNumpy()
hourly_soil_moisture_3_to_9cm = hourly.Variables(39).ValuesAsNumpy()
hourly_soil_moisture_9_to_27cm = hourly.Variables(40).ValuesAsNumpy()
hourly_soil_moisture_27_to_81cm = hourly.Variables(41).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["showers"] = hourly_showers
hourly_data["snowfall"] = hourly_snowfall
hourly_data["snow_depth"] = hourly_snow_depth
hourly_data["weather_code"] = hourly_weather_code
hourly_data["pressure_msl"] = hourly_pressure_msl
hourly_data["surface_pressure"] = hourly_surface_pressure
hourly_data["cloud_cover"] = hourly_cloud_cover
hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
hourly_data["visibility"] = hourly_visibility
hourly_data["evapotranspiration"] = hourly_evapotranspiration
hourly_data["et0_fao_evapotranspiration"] = hourly_et0_fao_evapotranspiration
hourly_data["vapour_pressure_deficit"] = hourly_vapour_pressure_deficit
hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
hourly_data["wind_speed_80m"] = hourly_wind_speed_80m
hourly_data["wind_speed_120m"] = hourly_wind_speed_120m
hourly_data["wind_speed_180m"] = hourly_wind_speed_180m
hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
hourly_data["wind_direction_80m"] = hourly_wind_direction_80m
hourly_data["wind_direction_120m"] = hourly_wind_direction_120m
hourly_data["wind_direction_180m"] = hourly_wind_direction_180m
hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m
hourly_data["temperature_80m"] = hourly_temperature_80m
hourly_data["temperature_120m"] = hourly_temperature_120m
hourly_data["temperature_180m"] = hourly_temperature_180m
hourly_data["soil_temperature_0cm"] = hourly_soil_temperature_0cm
hourly_data["soil_temperature_6cm"] = hourly_soil_temperature_6cm
hourly_data["soil_temperature_18cm"] = hourly_soil_temperature_18cm
hourly_data["soil_temperature_54cm"] = hourly_soil_temperature_54cm
hourly_data["soil_moisture_0_to_1cm"] = hourly_soil_moisture_0_to_1cm
hourly_data["soil_moisture_1_to_3cm"] = hourly_soil_moisture_1_to_3cm
hourly_data["soil_moisture_3_to_9cm"] = hourly_soil_moisture_3_to_9cm
hourly_data["soil_moisture_9_to_27cm"] = hourly_soil_moisture_9_to_27cm
hourly_data["soil_moisture_27_to_81cm"] = hourly_soil_moisture_27_to_81cm

df3 = pd.DataFrame(data = hourly_data)
print(df3)
# Out:
# Coordinates 48.84000015258789°N 2.359999656677246°E
# Elevation 46.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#                           date  temperature_2m  relative_humidity_2m  \
# 0    2024-12-01 00:00:00+00:00             NaN                   NaN
# 1    2024-12-01 01:00:00+00:00             NaN                   NaN
# 2    2024-12-01 02:00:00+00:00             NaN                   NaN
# 3    2024-12-01 03:00:00+00:00             NaN                   NaN
# 4    2024-12-01 04:00:00+00:00             NaN                   NaN
# ...                        ...             ...                   ...
# 2251 2025-03-04 19:00:00+00:00          10.987                  62.0
# 2252 2025-03-04 20:00:00+00:00           9.987                  68.0
# 2253 2025-03-04 21:00:00+00:00           8.737                  73.0
# 2254 2025-03-04 22:00:00+00:00           7.787                  79.0
# 2255 2025-03-04 23:00:00+00:00           7.137                  81.0
#
#       dew_point_2m  apparent_temperature  precipitation_probability  \
# 0              NaN                   NaN                        0.0
# 1              NaN                   NaN                        0.0
# 2              NaN                   NaN                        0.0
# 3              NaN                   NaN                        0.0
# 4              NaN                   NaN                        0.0
# ...            ...                   ...                        ...
# 2251      3.984182              9.142001                        0.0
# 2252      4.351251              8.215628                        0.0
# 2253      4.164259              6.965656                        0.0
# 2254      4.372015              6.250429                        0.0
# 2255      4.095530              5.585477                        0.0
#
#       precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0               NaN   NaN      NaN       NaN  ...               NaN
# 1               NaN   NaN      NaN       NaN  ...               NaN
# 2               NaN   NaN      NaN       NaN  ...               NaN
# 3               NaN   NaN      NaN       NaN  ...               NaN
# 4               NaN   NaN      NaN       NaN  ...               NaN
# ...             ...   ...      ...       ...  ...               ...
# 2251            0.0   0.0      0.0       0.0  ...         10.787001
# 2252            0.0   0.0      0.0       0.0  ...         10.487000
# 2253            0.0   0.0      0.0       0.0  ...         10.087001
# 2254            0.0   0.0      0.0       0.0  ...          9.587001
# 2255            0.0   0.0      0.0       0.0  ...          9.387000
#
#       soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2251              8.537001             10.337001               9.887000
# 2252              7.487000              9.387000               9.837001
# 2253              6.587000              8.587001               9.737000
# 2254              5.687000              7.837000               9.537001
# 2255              4.937000              7.137000               9.337001
#
#       soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 2251               8.337001                   0.342                   0.342
# 2252               8.337001                   0.342                   0.342
# 2253               8.387000                   0.342                   0.343
# 2254               8.387000                   0.343                   0.343
# 2255               8.387000                   0.343                   0.344
#
#       soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2251                   0.343                    0.347
# 2252                   0.344                    0.348
# 2253                   0.344                    0.348
# 2254                   0.344                    0.348
# 2255                   0.345                    0.348
#
#       soil_moisture_27_to_81cm
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2251                     0.370
# 2252                     0.370
# 2253                     0.369
# 2254                     0.369
# 2255                     0.369
#
# [2256 rows x 43 columns]

# %%
df3["Country"] = "Paris"

# %%
df = pd.concat([df, df3])

# %%
df.shape
# Out:
# (6768, 44)

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": 13.73,
	"longitude": 100.52,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth", "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", "soil_moisture_27_to_81cm"],
	"start_date": "2024-12-01",
	"end_date": "2025-03-04"
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_showers = hourly.Variables(7).ValuesAsNumpy()
hourly_snowfall = hourly.Variables(8).ValuesAsNumpy()
hourly_snow_depth = hourly.Variables(9).ValuesAsNumpy()
hourly_weather_code = hourly.Variables(10).ValuesAsNumpy()
hourly_pressure_msl = hourly.Variables(11).ValuesAsNumpy()
hourly_surface_pressure = hourly.Variables(12).ValuesAsNumpy()
hourly_cloud_cover = hourly.Variables(13).ValuesAsNumpy()
hourly_cloud_cover_low = hourly.Variables(14).ValuesAsNumpy()
hourly_cloud_cover_mid = hourly.Variables(15).ValuesAsNumpy()
hourly_cloud_cover_high = hourly.Variables(16).ValuesAsNumpy()
hourly_visibility = hourly.Variables(17).ValuesAsNumpy()
hourly_evapotranspiration = hourly.Variables(18).ValuesAsNumpy()
hourly_et0_fao_evapotranspiration = hourly.Variables(19).ValuesAsNumpy()
hourly_vapour_pressure_deficit = hourly.Variables(20).ValuesAsNumpy()
hourly_wind_speed_10m = hourly.Variables(21).ValuesAsNumpy()
hourly_wind_speed_80m = hourly.Variables(22).ValuesAsNumpy()
hourly_wind_speed_120m = hourly.Variables(23).ValuesAsNumpy()
hourly_wind_speed_180m = hourly.Variables(24).ValuesAsNumpy()
hourly_wind_direction_10m = hourly.Variables(25).ValuesAsNumpy()
hourly_wind_direction_80m = hourly.Variables(26).ValuesAsNumpy()
hourly_wind_direction_120m = hourly.Variables(27).ValuesAsNumpy()
hourly_wind_direction_180m = hourly.Variables(28).ValuesAsNumpy()
hourly_wind_gusts_10m = hourly.Variables(29).ValuesAsNumpy()
hourly_temperature_80m = hourly.Variables(30).ValuesAsNumpy()
hourly_temperature_120m = hourly.Variables(31).ValuesAsNumpy()
hourly_temperature_180m = hourly.Variables(32).ValuesAsNumpy()
hourly_soil_temperature_0cm = hourly.Variables(33).ValuesAsNumpy()
hourly_soil_temperature_6cm = hourly.Variables(34).ValuesAsNumpy()
hourly_soil_temperature_18cm = hourly.Variables(35).ValuesAsNumpy()
hourly_soil_temperature_54cm = hourly.Variables(36).ValuesAsNumpy()
hourly_soil_moisture_0_to_1cm = hourly.Variables(37).ValuesAsNumpy()
hourly_soil_moisture_1_to_3cm = hourly.Variables(38).ValuesAsNumpy()
hourly_soil_moisture_3_to_9cm = hourly.Variables(39).ValuesAsNumpy()
hourly_soil_moisture_9_to_27cm = hourly.Variables(40).ValuesAsNumpy()
hourly_soil_moisture_27_to_81cm = hourly.Variables(41).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["showers"] = hourly_showers
hourly_data["snowfall"] = hourly_snowfall
hourly_data["snow_depth"] = hourly_snow_depth
hourly_data["weather_code"] = hourly_weather_code
hourly_data["pressure_msl"] = hourly_pressure_msl
hourly_data["surface_pressure"] = hourly_surface_pressure
hourly_data["cloud_cover"] = hourly_cloud_cover
hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
hourly_data["visibility"] = hourly_visibility
hourly_data["evapotranspiration"] = hourly_evapotranspiration
hourly_data["et0_fao_evapotranspiration"] = hourly_et0_fao_evapotranspiration
hourly_data["vapour_pressure_deficit"] = hourly_vapour_pressure_deficit
hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
hourly_data["wind_speed_80m"] = hourly_wind_speed_80m
hourly_data["wind_speed_120m"] = hourly_wind_speed_120m
hourly_data["wind_speed_180m"] = hourly_wind_speed_180m
hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
hourly_data["wind_direction_80m"] = hourly_wind_direction_80m
hourly_data["wind_direction_120m"] = hourly_wind_direction_120m
hourly_data["wind_direction_180m"] = hourly_wind_direction_180m
hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m
hourly_data["temperature_80m"] = hourly_temperature_80m
hourly_data["temperature_120m"] = hourly_temperature_120m
hourly_data["temperature_180m"] = hourly_temperature_180m
hourly_data["soil_temperature_0cm"] = hourly_soil_temperature_0cm
hourly_data["soil_temperature_6cm"] = hourly_soil_temperature_6cm
hourly_data["soil_temperature_18cm"] = hourly_soil_temperature_18cm
hourly_data["soil_temperature_54cm"] = hourly_soil_temperature_54cm
hourly_data["soil_moisture_0_to_1cm"] = hourly_soil_moisture_0_to_1cm
hourly_data["soil_moisture_1_to_3cm"] = hourly_soil_moisture_1_to_3cm
hourly_data["soil_moisture_3_to_9cm"] = hourly_soil_moisture_3_to_9cm
hourly_data["soil_moisture_9_to_27cm"] = hourly_soil_moisture_9_to_27cm
hourly_data["soil_moisture_27_to_81cm"] = hourly_soil_moisture_27_to_81cm

df4 = pd.DataFrame(data = hourly_data)
print(df4)
# Out:
# Coordinates 13.75°N 100.5°E
# Elevation 6.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#                           date  temperature_2m  relative_humidity_2m  \
# 0    2024-12-01 00:00:00+00:00             NaN                   NaN
# 1    2024-12-01 01:00:00+00:00             NaN                   NaN
# 2    2024-12-01 02:00:00+00:00             NaN                   NaN
# 3    2024-12-01 03:00:00+00:00             NaN                   NaN
# 4    2024-12-01 04:00:00+00:00             NaN                   NaN
# ...                        ...             ...                   ...
# 2251 2025-03-04 19:00:00+00:00       27.274000                  81.0
# 2252 2025-03-04 20:00:00+00:00       27.274000                  79.0
# 2253 2025-03-04 21:00:00+00:00       27.224001                  78.0
# 2254 2025-03-04 22:00:00+00:00       27.224001                  79.0
# 2255 2025-03-04 23:00:00+00:00       27.224001                  80.0
#
#       dew_point_2m  apparent_temperature  precipitation_probability  \
# 0              NaN                   NaN                        0.0
# 1              NaN                   NaN                        0.0
# 2              NaN                   NaN                        0.0
# 3              NaN                   NaN                        0.0
# 4              NaN                   NaN                        0.0
# ...            ...                   ...                        ...
# 2251     23.726673             31.680851                        0.0
# 2252     23.311966             31.531509                        0.0
# 2253     23.052685             31.379555                        0.0
# 2254     23.263422             31.612812                        0.0
# 2255     23.471836             31.734852                        0.0
#
#       precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0               NaN   NaN      NaN       NaN  ...               NaN
# 1               NaN   NaN      NaN       NaN  ...               NaN
# 2               NaN   NaN      NaN       NaN  ...               NaN
# 3               NaN   NaN      NaN       NaN  ...               NaN
# 4               NaN   NaN      NaN       NaN  ...               NaN
# ...             ...   ...      ...       ...  ...               ...
# 2251            0.0   0.0      0.0       0.0  ...         25.174002
# 2252            0.0   0.0      0.0       0.0  ...         25.274000
# 2253            0.0   0.0      0.0       0.0  ...         25.274000
# 2254            0.0   0.0      0.0       0.0  ...         25.274000
# 2255            0.0   0.0      0.0       0.0  ...         25.274000
#
#       soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2251             27.024000             28.624001              31.024000
# 2252             26.774000             28.374001              30.824001
# 2253             26.624001             28.174002              30.674002
# 2254             26.574001             28.024000              30.474001
# 2255             26.574001             27.924002              30.324001
#
#       soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 2251              30.374001                   0.339                   0.343
# 2252              30.374001                   0.340                   0.343
# 2253              30.374001                   0.340                   0.344
# 2254              30.374001                   0.341                   0.344
# 2255              30.374001                   0.342                   0.345
#
#       soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2251                   0.356                    0.375
# 2252                   0.356                    0.375
# 2253                   0.356                    0.375
# 2254                   0.356                    0.375
# 2255                   0.356                    0.375
#
#       soil_moisture_27_to_81cm
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2251                     0.411
# 2252                     0.411
# 2253                     0.411
# 2254                     0.411
# 2255                     0.411
#
# [2256 rows x 43 columns]

# %%
df4["Country"] = "Bangkok"

# %%
df = pd.concat([df, df4])

# %%
df.shape
# Out:
# (9024, 44)

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": 35.68,
	"longitude": 139.69,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth", "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", "soil_moisture_27_to_81cm"],
	"start_date": "2024-12-01",
	"end_date": "2025-03-04"
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_showers = hourly.Variables(7).ValuesAsNumpy()
hourly_snowfall = hourly.Variables(8).ValuesAsNumpy()
hourly_snow_depth = hourly.Variables(9).ValuesAsNumpy()
hourly_weather_code = hourly.Variables(10).ValuesAsNumpy()
hourly_pressure_msl = hourly.Variables(11).ValuesAsNumpy()
hourly_surface_pressure = hourly.Variables(12).ValuesAsNumpy()
hourly_cloud_cover = hourly.Variables(13).ValuesAsNumpy()
hourly_cloud_cover_low = hourly.Variables(14).ValuesAsNumpy()
hourly_cloud_cover_mid = hourly.Variables(15).ValuesAsNumpy()
hourly_cloud_cover_high = hourly.Variables(16).ValuesAsNumpy()
hourly_visibility = hourly.Variables(17).ValuesAsNumpy()
hourly_evapotranspiration = hourly.Variables(18).ValuesAsNumpy()
hourly_et0_fao_evapotranspiration = hourly.Variables(19).ValuesAsNumpy()
hourly_vapour_pressure_deficit = hourly.Variables(20).ValuesAsNumpy()
hourly_wind_speed_10m = hourly.Variables(21).ValuesAsNumpy()
hourly_wind_speed_80m = hourly.Variables(22).ValuesAsNumpy()
hourly_wind_speed_120m = hourly.Variables(23).ValuesAsNumpy()
hourly_wind_speed_180m = hourly.Variables(24).ValuesAsNumpy()
hourly_wind_direction_10m = hourly.Variables(25).ValuesAsNumpy()
hourly_wind_direction_80m = hourly.Variables(26).ValuesAsNumpy()
hourly_wind_direction_120m = hourly.Variables(27).ValuesAsNumpy()
hourly_wind_direction_180m = hourly.Variables(28).ValuesAsNumpy()
hourly_wind_gusts_10m = hourly.Variables(29).ValuesAsNumpy()
hourly_temperature_80m = hourly.Variables(30).ValuesAsNumpy()
hourly_temperature_120m = hourly.Variables(31).ValuesAsNumpy()
hourly_temperature_180m = hourly.Variables(32).ValuesAsNumpy()
hourly_soil_temperature_0cm = hourly.Variables(33).ValuesAsNumpy()
hourly_soil_temperature_6cm = hourly.Variables(34).ValuesAsNumpy()
hourly_soil_temperature_18cm = hourly.Variables(35).ValuesAsNumpy()
hourly_soil_temperature_54cm = hourly.Variables(36).ValuesAsNumpy()
hourly_soil_moisture_0_to_1cm = hourly.Variables(37).ValuesAsNumpy()
hourly_soil_moisture_1_to_3cm = hourly.Variables(38).ValuesAsNumpy()
hourly_soil_moisture_3_to_9cm = hourly.Variables(39).ValuesAsNumpy()
hourly_soil_moisture_9_to_27cm = hourly.Variables(40).ValuesAsNumpy()
hourly_soil_moisture_27_to_81cm = hourly.Variables(41).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["showers"] = hourly_showers
hourly_data["snowfall"] = hourly_snowfall
hourly_data["snow_depth"] = hourly_snow_depth
hourly_data["weather_code"] = hourly_weather_code
hourly_data["pressure_msl"] = hourly_pressure_msl
hourly_data["surface_pressure"] = hourly_surface_pressure
hourly_data["cloud_cover"] = hourly_cloud_cover
hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
hourly_data["visibility"] = hourly_visibility
hourly_data["evapotranspiration"] = hourly_evapotranspiration
hourly_data["et0_fao_evapotranspiration"] = hourly_et0_fao_evapotranspiration
hourly_data["vapour_pressure_deficit"] = hourly_vapour_pressure_deficit
hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
hourly_data["wind_speed_80m"] = hourly_wind_speed_80m
hourly_data["wind_speed_120m"] = hourly_wind_speed_120m
hourly_data["wind_speed_180m"] = hourly_wind_speed_180m
hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
hourly_data["wind_direction_80m"] = hourly_wind_direction_80m
hourly_data["wind_direction_120m"] = hourly_wind_direction_120m
hourly_data["wind_direction_180m"] = hourly_wind_direction_180m
hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m
hourly_data["temperature_80m"] = hourly_temperature_80m
hourly_data["temperature_120m"] = hourly_temperature_120m
hourly_data["temperature_180m"] = hourly_temperature_180m
hourly_data["soil_temperature_0cm"] = hourly_soil_temperature_0cm
hourly_data["soil_temperature_6cm"] = hourly_soil_temperature_6cm
hourly_data["soil_temperature_18cm"] = hourly_soil_temperature_18cm
hourly_data["soil_temperature_54cm"] = hourly_soil_temperature_54cm
hourly_data["soil_moisture_0_to_1cm"] = hourly_soil_moisture_0_to_1cm
hourly_data["soil_moisture_1_to_3cm"] = hourly_soil_moisture_1_to_3cm
hourly_data["soil_moisture_3_to_9cm"] = hourly_soil_moisture_3_to_9cm
hourly_data["soil_moisture_9_to_27cm"] = hourly_soil_moisture_9_to_27cm
hourly_data["soil_moisture_27_to_81cm"] = hourly_soil_moisture_27_to_81cm

df5 = pd.DataFrame(data = hourly_data)
print(df5)
# Out:
# Coordinates 35.70000076293945°N 139.6875°E
# Elevation 38.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#                           date  temperature_2m  relative_humidity_2m  \
# 0    2024-12-01 00:00:00+00:00             NaN                   NaN
# 1    2024-12-01 01:00:00+00:00             NaN                   NaN
# 2    2024-12-01 02:00:00+00:00             NaN                   NaN
# 3    2024-12-01 03:00:00+00:00             NaN                   NaN
# 4    2024-12-01 04:00:00+00:00             NaN                   NaN
# ...                        ...             ...                   ...
# 2251 2025-03-04 19:00:00+00:00            1.35                  96.0
# 2252 2025-03-04 20:00:00+00:00            1.55                  95.0
# 2253 2025-03-04 21:00:00+00:00            1.80                  96.0
# 2254 2025-03-04 22:00:00+00:00            2.20                  96.0
# 2255 2025-03-04 23:00:00+00:00            2.60                  96.0
#
#       dew_point_2m  apparent_temperature  precipitation_probability  \
# 0              NaN                   NaN                        0.0
# 1              NaN                   NaN                        0.0
# 2              NaN                   NaN                        0.0
# 3              NaN                   NaN                        0.0
# 4              NaN                   NaN                        0.0
# ...            ...                   ...                        ...
# 2251      0.782136             -1.802916                       98.0
# 2252      0.835732             -1.476881                       98.0
# 2253      1.230046             -1.141712                       98.0
# 2254      1.628184             -0.694574                       98.0
# 2255      2.026319             -0.201260                      100.0
#
#       precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0               NaN   NaN      NaN       NaN  ...               NaN
# 1               NaN   NaN      NaN       NaN  ...               NaN
# 2               NaN   NaN      NaN       NaN  ...               NaN
# 3               NaN   NaN      NaN       NaN  ...               NaN
# 4               NaN   NaN      NaN       NaN  ...               NaN
# ...             ...   ...      ...       ...  ...               ...
# 2251            1.3   1.3      0.0       0.0  ...             1.166
# 2252            2.1   2.1      0.0       0.0  ...             2.166
# 2253            0.5   0.5      0.0       0.0  ...             2.066
# 2254            0.3   0.3      0.0       0.0  ...             2.766
# 2255            0.3   0.3      0.0       0.0  ...             2.766
#
#       soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2251                 6.316                 4.016                  6.716
# 2252                 6.566                 4.166                  6.616
# 2253                 6.666                 4.316                  6.516
# 2254                 6.916                 4.466                  6.466
# 2255                 7.116                 4.666                  6.416
#
#       soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 2251              10.716000                   0.332                   0.332
# 2252              10.665999                   0.329                   0.330
# 2253              10.616000                   0.333                   0.332
# 2254              10.616000                   0.330                   0.330
# 2255              10.566000                   0.329                   0.329
#
#       soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2251                   0.332                    0.319
# 2252                   0.330                    0.320
# 2253                   0.330                    0.321
# 2254                   0.330                    0.321
# 2255                   0.329                    0.322
#
#       soil_moisture_27_to_81cm
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2251                     0.295
# 2252                     0.295
# 2253                     0.296
# 2254                     0.296
# 2255                     0.296
#
# [2256 rows x 43 columns]

# %%
df5["Country"] = "Tokyo"

# %%
df = pd.concat([df, df5])

# %%
df.shape
# Out:
# (11280, 44)

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": 41.90,
	"longitude": 12.49,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth", "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", "soil_moisture_27_to_81cm"],
	"start_date": "2024-12-01",
	"end_date": "2025-03-04"
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_showers = hourly.Variables(7).ValuesAsNumpy()
hourly_snowfall = hourly.Variables(8).ValuesAsNumpy()
hourly_snow_depth = hourly.Variables(9).ValuesAsNumpy()
hourly_weather_code = hourly.Variables(10).ValuesAsNumpy()
hourly_pressure_msl = hourly.Variables(11).ValuesAsNumpy()
hourly_surface_pressure = hourly.Variables(12).ValuesAsNumpy()
hourly_cloud_cover = hourly.Variables(13).ValuesAsNumpy()
hourly_cloud_cover_low = hourly.Variables(14).ValuesAsNumpy()
hourly_cloud_cover_mid = hourly.Variables(15).ValuesAsNumpy()
hourly_cloud_cover_high = hourly.Variables(16).ValuesAsNumpy()
hourly_visibility = hourly.Variables(17).ValuesAsNumpy()
hourly_evapotranspiration = hourly.Variables(18).ValuesAsNumpy()
hourly_et0_fao_evapotranspiration = hourly.Variables(19).ValuesAsNumpy()
hourly_vapour_pressure_deficit = hourly.Variables(20).ValuesAsNumpy()
hourly_wind_speed_10m = hourly.Variables(21).ValuesAsNumpy()
hourly_wind_speed_80m = hourly.Variables(22).ValuesAsNumpy()
hourly_wind_speed_120m = hourly.Variables(23).ValuesAsNumpy()
hourly_wind_speed_180m = hourly.Variables(24).ValuesAsNumpy()
hourly_wind_direction_10m = hourly.Variables(25).ValuesAsNumpy()
hourly_wind_direction_80m = hourly.Variables(26).ValuesAsNumpy()
hourly_wind_direction_120m = hourly.Variables(27).ValuesAsNumpy()
hourly_wind_direction_180m = hourly.Variables(28).ValuesAsNumpy()
hourly_wind_gusts_10m = hourly.Variables(29).ValuesAsNumpy()
hourly_temperature_80m = hourly.Variables(30).ValuesAsNumpy()
hourly_temperature_120m = hourly.Variables(31).ValuesAsNumpy()
hourly_temperature_180m = hourly.Variables(32).ValuesAsNumpy()
hourly_soil_temperature_0cm = hourly.Variables(33).ValuesAsNumpy()
hourly_soil_temperature_6cm = hourly.Variables(34).ValuesAsNumpy()
hourly_soil_temperature_18cm = hourly.Variables(35).ValuesAsNumpy()
hourly_soil_temperature_54cm = hourly.Variables(36).ValuesAsNumpy()
hourly_soil_moisture_0_to_1cm = hourly.Variables(37).ValuesAsNumpy()
hourly_soil_moisture_1_to_3cm = hourly.Variables(38).ValuesAsNumpy()
hourly_soil_moisture_3_to_9cm = hourly.Variables(39).ValuesAsNumpy()
hourly_soil_moisture_9_to_27cm = hourly.Variables(40).ValuesAsNumpy()
hourly_soil_moisture_27_to_81cm = hourly.Variables(41).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["showers"] = hourly_showers
hourly_data["snowfall"] = hourly_snowfall
hourly_data["snow_depth"] = hourly_snow_depth
hourly_data["weather_code"] = hourly_weather_code
hourly_data["pressure_msl"] = hourly_pressure_msl
hourly_data["surface_pressure"] = hourly_surface_pressure
hourly_data["cloud_cover"] = hourly_cloud_cover
hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
hourly_data["visibility"] = hourly_visibility
hourly_data["evapotranspiration"] = hourly_evapotranspiration
hourly_data["et0_fao_evapotranspiration"] = hourly_et0_fao_evapotranspiration
hourly_data["vapour_pressure_deficit"] = hourly_vapour_pressure_deficit
hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
hourly_data["wind_speed_80m"] = hourly_wind_speed_80m
hourly_data["wind_speed_120m"] = hourly_wind_speed_120m
hourly_data["wind_speed_180m"] = hourly_wind_speed_180m
hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
hourly_data["wind_direction_80m"] = hourly_wind_direction_80m
hourly_data["wind_direction_120m"] = hourly_wind_direction_120m
hourly_data["wind_direction_180m"] = hourly_wind_direction_180m
hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m
hourly_data["temperature_80m"] = hourly_temperature_80m
hourly_data["temperature_120m"] = hourly_temperature_120m
hourly_data["temperature_180m"] = hourly_temperature_180m
hourly_data["soil_temperature_0cm"] = hourly_soil_temperature_0cm
hourly_data["soil_temperature_6cm"] = hourly_soil_temperature_6cm
hourly_data["soil_temperature_18cm"] = hourly_soil_temperature_18cm
hourly_data["soil_temperature_54cm"] = hourly_soil_temperature_54cm
hourly_data["soil_moisture_0_to_1cm"] = hourly_soil_moisture_0_to_1cm
hourly_data["soil_moisture_1_to_3cm"] = hourly_soil_moisture_1_to_3cm
hourly_data["soil_moisture_3_to_9cm"] = hourly_soil_moisture_3_to_9cm
hourly_data["soil_moisture_9_to_27cm"] = hourly_soil_moisture_9_to_27cm
hourly_data["soil_moisture_27_to_81cm"] = hourly_soil_moisture_27_to_81cm

df6 = pd.DataFrame(data = hourly_data)
print(df6)
# Out:
# Coordinates 41.875°N 12.5°E
# Elevation 59.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#                           date  temperature_2m  relative_humidity_2m  \
# 0    2024-12-01 00:00:00+00:00             NaN                   NaN
# 1    2024-12-01 01:00:00+00:00             NaN                   NaN
# 2    2024-12-01 02:00:00+00:00             NaN                   NaN
# 3    2024-12-01 03:00:00+00:00             NaN                   NaN
# 4    2024-12-01 04:00:00+00:00             NaN                   NaN
# ...                        ...             ...                   ...
# 2251 2025-03-04 19:00:00+00:00       11.235001                  86.0
# 2252 2025-03-04 20:00:00+00:00        9.885000                  92.0
# 2253 2025-03-04 21:00:00+00:00        9.185000                  94.0
# 2254 2025-03-04 22:00:00+00:00        8.485001                  95.0
# 2255 2025-03-04 23:00:00+00:00        7.785000                  97.0
#
#       dew_point_2m  apparent_temperature  precipitation_probability  \
# 0              NaN                   NaN                        0.0
# 1              NaN                   NaN                        0.0
# 2              NaN                   NaN                        0.0
# 3              NaN                   NaN                        0.0
# 4              NaN                   NaN                        0.0
# ...            ...                   ...                        ...
# 2251      8.978702             10.433127                        0.0
# 2252      8.645879              9.031929                        0.0
# 2253      8.269396              8.321864                        0.0
# 2254      7.729718              7.632595                        0.0
# 2255      7.338440              6.727382                        0.0
#
#       precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0               NaN   NaN      NaN       NaN  ...               NaN
# 1               NaN   NaN      NaN       NaN  ...               NaN
# 2               NaN   NaN      NaN       NaN  ...               NaN
# 3               NaN   NaN      NaN       NaN  ...               NaN
# 4               NaN   NaN      NaN       NaN  ...               NaN
# ...             ...   ...      ...       ...  ...               ...
# 2251            0.0   0.0      0.0       0.0  ...         11.135000
# 2252            0.0   0.0      0.0       0.0  ...         10.835000
# 2253            0.0   0.0      0.0       0.0  ...         10.735001
# 2254            0.0   0.0      0.0       0.0  ...         10.635000
# 2255            0.0   0.0      0.0       0.0  ...         10.335000
#
#       soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2251              9.635000             12.485001              12.785001
# 2252              8.785001             11.535001              12.685000
# 2253              7.885000             10.735001              12.585000
# 2254              6.935000              9.985001              12.385000
# 2255              6.435000              9.335000              12.185000
#
#       soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 2251              11.735001                   0.295                   0.296
# 2252              11.735001                   0.296                   0.297
# 2253              11.735001                   0.296                   0.297
# 2254              11.785001                   0.296                   0.298
# 2255              11.785001                   0.297                   0.298
#
#       soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2251                   0.301                    0.314
# 2252                   0.301                    0.314
# 2253                   0.301                    0.314
# 2254                   0.301                    0.314
# 2255                   0.301                    0.313
#
#       soil_moisture_27_to_81cm
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2251                     0.339
# 2252                     0.339
# 2253                     0.339
# 2254                     0.339
# 2255                     0.339
#
# [2256 rows x 43 columns]

# %%
df6["Country"] = "Rome"

# %%
df = pd.concat([df, df6])

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": 40.71,
	"longitude": -74.00,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth", "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", "soil_moisture_27_to_81cm"],
	"start_date": "2024-12-01",
	"end_date": "2025-03-04"
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_showers = hourly.Variables(7).ValuesAsNumpy()
hourly_snowfall = hourly.Variables(8).ValuesAsNumpy()
hourly_snow_depth = hourly.Variables(9).ValuesAsNumpy()
hourly_weather_code = hourly.Variables(10).ValuesAsNumpy()
hourly_pressure_msl = hourly.Variables(11).ValuesAsNumpy()
hourly_surface_pressure = hourly.Variables(12).ValuesAsNumpy()
hourly_cloud_cover = hourly.Variables(13).ValuesAsNumpy()
hourly_cloud_cover_low = hourly.Variables(14).ValuesAsNumpy()
hourly_cloud_cover_mid = hourly.Variables(15).ValuesAsNumpy()
hourly_cloud_cover_high = hourly.Variables(16).ValuesAsNumpy()
hourly_visibility = hourly.Variables(17).ValuesAsNumpy()
hourly_evapotranspiration = hourly.Variables(18).ValuesAsNumpy()
hourly_et0_fao_evapotranspiration = hourly.Variables(19).ValuesAsNumpy()
hourly_vapour_pressure_deficit = hourly.Variables(20).ValuesAsNumpy()
hourly_wind_speed_10m = hourly.Variables(21).ValuesAsNumpy()
hourly_wind_speed_80m = hourly.Variables(22).ValuesAsNumpy()
hourly_wind_speed_120m = hourly.Variables(23).ValuesAsNumpy()
hourly_wind_speed_180m = hourly.Variables(24).ValuesAsNumpy()
hourly_wind_direction_10m = hourly.Variables(25).ValuesAsNumpy()
hourly_wind_direction_80m = hourly.Variables(26).ValuesAsNumpy()
hourly_wind_direction_120m = hourly.Variables(27).ValuesAsNumpy()
hourly_wind_direction_180m = hourly.Variables(28).ValuesAsNumpy()
hourly_wind_gusts_10m = hourly.Variables(29).ValuesAsNumpy()
hourly_temperature_80m = hourly.Variables(30).ValuesAsNumpy()
hourly_temperature_120m = hourly.Variables(31).ValuesAsNumpy()
hourly_temperature_180m = hourly.Variables(32).ValuesAsNumpy()
hourly_soil_temperature_0cm = hourly.Variables(33).ValuesAsNumpy()
hourly_soil_temperature_6cm = hourly.Variables(34).ValuesAsNumpy()
hourly_soil_temperature_18cm = hourly.Variables(35).ValuesAsNumpy()
hourly_soil_temperature_54cm = hourly.Variables(36).ValuesAsNumpy()
hourly_soil_moisture_0_to_1cm = hourly.Variables(37).ValuesAsNumpy()
hourly_soil_moisture_1_to_3cm = hourly.Variables(38).ValuesAsNumpy()
hourly_soil_moisture_3_to_9cm = hourly.Variables(39).ValuesAsNumpy()
hourly_soil_moisture_9_to_27cm = hourly.Variables(40).ValuesAsNumpy()
hourly_soil_moisture_27_to_81cm = hourly.Variables(41).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["showers"] = hourly_showers
hourly_data["snowfall"] = hourly_snowfall
hourly_data["snow_depth"] = hourly_snow_depth
hourly_data["weather_code"] = hourly_weather_code
hourly_data["pressure_msl"] = hourly_pressure_msl
hourly_data["surface_pressure"] = hourly_surface_pressure
hourly_data["cloud_cover"] = hourly_cloud_cover
hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
hourly_data["visibility"] = hourly_visibility
hourly_data["evapotranspiration"] = hourly_evapotranspiration
hourly_data["et0_fao_evapotranspiration"] = hourly_et0_fao_evapotranspiration
hourly_data["vapour_pressure_deficit"] = hourly_vapour_pressure_deficit
hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
hourly_data["wind_speed_80m"] = hourly_wind_speed_80m
hourly_data["wind_speed_120m"] = hourly_wind_speed_120m
hourly_data["wind_speed_180m"] = hourly_wind_speed_180m
hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
hourly_data["wind_direction_80m"] = hourly_wind_direction_80m
hourly_data["wind_direction_120m"] = hourly_wind_direction_120m
hourly_data["wind_direction_180m"] = hourly_wind_direction_180m
hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m
hourly_data["temperature_80m"] = hourly_temperature_80m
hourly_data["temperature_120m"] = hourly_temperature_120m
hourly_data["temperature_180m"] = hourly_temperature_180m
hourly_data["soil_temperature_0cm"] = hourly_soil_temperature_0cm
hourly_data["soil_temperature_6cm"] = hourly_soil_temperature_6cm
hourly_data["soil_temperature_18cm"] = hourly_soil_temperature_18cm
hourly_data["soil_temperature_54cm"] = hourly_soil_temperature_54cm
hourly_data["soil_moisture_0_to_1cm"] = hourly_soil_moisture_0_to_1cm
hourly_data["soil_moisture_1_to_3cm"] = hourly_soil_moisture_1_to_3cm
hourly_data["soil_moisture_3_to_9cm"] = hourly_soil_moisture_3_to_9cm
hourly_data["soil_moisture_9_to_27cm"] = hourly_soil_moisture_9_to_27cm
hourly_data["soil_moisture_27_to_81cm"] = hourly_soil_moisture_27_to_81cm

df7 = pd.DataFrame(data = hourly_data)
print(df7)
# Out:
# Coordinates 40.71033477783203°N -73.99308776855469°E
# Elevation 7.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#                           date  temperature_2m  relative_humidity_2m  \
# 0    2024-12-01 00:00:00+00:00             NaN                   NaN
# 1    2024-12-01 01:00:00+00:00             NaN                   NaN
# 2    2024-12-01 02:00:00+00:00             NaN                   NaN
# 3    2024-12-01 03:00:00+00:00             NaN                   NaN
# 4    2024-12-01 04:00:00+00:00             NaN                   NaN
# ...                        ...             ...                   ...
# 2251 2025-03-04 19:00:00+00:00       12.793500                  45.0
# 2252 2025-03-04 20:00:00+00:00       13.443500                  43.0
# 2253 2025-03-04 21:00:00+00:00       14.093500                  38.0
# 2254 2025-03-04 22:00:00+00:00       12.993500                  42.0
# 2255 2025-03-04 23:00:00+00:00        9.893499                  53.0
#
#       dew_point_2m  apparent_temperature  precipitation_probability  \
# 0              NaN                   NaN                        0.0
# 1              NaN                   NaN                        0.0
# 2              NaN                   NaN                        0.0
# 3              NaN                   NaN                        0.0
# 4              NaN                   NaN                        0.0
# ...            ...                   ...                        ...
# 2251      1.148107              8.420982                        2.0
# 2252      1.105945              9.171221                        2.0
# 2253     -0.021466              9.601213                        3.0
# 2254      0.372256              9.024430                        2.0
# 2255      0.754191              5.958226                        2.0
#
#       precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0               NaN   NaN      NaN       NaN  ...               NaN
# 1               NaN   NaN      NaN       NaN  ...               NaN
# 2               NaN   NaN      NaN       NaN  ...               NaN
# 3               NaN   NaN      NaN       NaN  ...               NaN
# 4               NaN   NaN      NaN       NaN  ...               NaN
# ...             ...   ...      ...       ...  ...               ...
# 2251            0.0   0.0      0.0       0.0  ...            6.9325
# 2252            0.0   0.0      0.0       0.0  ...            7.2325
# 2253            0.0   0.0      0.0       0.0  ...            7.5325
# 2254            0.0   0.0      0.0       0.0  ...            8.5325
# 2255            0.0   0.0      0.0       0.0  ...            9.0325
#
#       soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2251               13.7825               10.7825                 3.7825
# 2252               11.9825               11.3325                 4.3325
# 2253               10.2325               11.0325                 4.7825
# 2254                7.6825                9.9825                 5.1825
# 2255                5.5325                8.4325                 5.4825
#
#       soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 2251                 5.4825                   0.245                   0.249
# 2252                 5.4825                   0.245                   0.249
# 2253                 5.4825                   0.245                   0.249
# 2254                 5.4825                   0.246                   0.249
# 2255                 5.4825                   0.246                   0.249
#
#       soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2251                   0.258                    0.276
# 2252                   0.258                    0.276
# 2253                   0.257                    0.276
# 2254                   0.257                    0.276
# 2255                   0.257                    0.276
#
#       soil_moisture_27_to_81cm
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2251                     0.306
# 2252                     0.306
# 2253                     0.306
# 2254                     0.306
# 2255                     0.306
#
# [2256 rows x 43 columns]

# %%
df7["Country"] = "New York City"

# %%
df = pd.concat([df, df7])

# %%
df.shape
# Out:
# (15792, 44)

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": -8.34,
	"longitude": 115.09,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth", "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", "soil_moisture_27_to_81cm"],
	"start_date": "2024-12-01",
	"end_date": "2025-03-04"
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_showers = hourly.Variables(7).ValuesAsNumpy()
hourly_snowfall = hourly.Variables(8).ValuesAsNumpy()
hourly_snow_depth = hourly.Variables(9).ValuesAsNumpy()
hourly_weather_code = hourly.Variables(10).ValuesAsNumpy()
hourly_pressure_msl = hourly.Variables(11).ValuesAsNumpy()
hourly_surface_pressure = hourly.Variables(12).ValuesAsNumpy()
hourly_cloud_cover = hourly.Variables(13).ValuesAsNumpy()
hourly_cloud_cover_low = hourly.Variables(14).ValuesAsNumpy()
hourly_cloud_cover_mid = hourly.Variables(15).ValuesAsNumpy()
hourly_cloud_cover_high = hourly.Variables(16).ValuesAsNumpy()
hourly_visibility = hourly.Variables(17).ValuesAsNumpy()
hourly_evapotranspiration = hourly.Variables(18).ValuesAsNumpy()
hourly_et0_fao_evapotranspiration = hourly.Variables(19).ValuesAsNumpy()
hourly_vapour_pressure_deficit = hourly.Variables(20).ValuesAsNumpy()
hourly_wind_speed_10m = hourly.Variables(21).ValuesAsNumpy()
hourly_wind_speed_80m = hourly.Variables(22).ValuesAsNumpy()
hourly_wind_speed_120m = hourly.Variables(23).ValuesAsNumpy()
hourly_wind_speed_180m = hourly.Variables(24).ValuesAsNumpy()
hourly_wind_direction_10m = hourly.Variables(25).ValuesAsNumpy()
hourly_wind_direction_80m = hourly.Variables(26).ValuesAsNumpy()
hourly_wind_direction_120m = hourly.Variables(27).ValuesAsNumpy()
hourly_wind_direction_180m = hourly.Variables(28).ValuesAsNumpy()
hourly_wind_gusts_10m = hourly.Variables(29).ValuesAsNumpy()
hourly_temperature_80m = hourly.Variables(30).ValuesAsNumpy()
hourly_temperature_120m = hourly.Variables(31).ValuesAsNumpy()
hourly_temperature_180m = hourly.Variables(32).ValuesAsNumpy()
hourly_soil_temperature_0cm = hourly.Variables(33).ValuesAsNumpy()
hourly_soil_temperature_6cm = hourly.Variables(34).ValuesAsNumpy()
hourly_soil_temperature_18cm = hourly.Variables(35).ValuesAsNumpy()
hourly_soil_temperature_54cm = hourly.Variables(36).ValuesAsNumpy()
hourly_soil_moisture_0_to_1cm = hourly.Variables(37).ValuesAsNumpy()
hourly_soil_moisture_1_to_3cm = hourly.Variables(38).ValuesAsNumpy()
hourly_soil_moisture_3_to_9cm = hourly.Variables(39).ValuesAsNumpy()
hourly_soil_moisture_9_to_27cm = hourly.Variables(40).ValuesAsNumpy()
hourly_soil_moisture_27_to_81cm = hourly.Variables(41).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["showers"] = hourly_showers
hourly_data["snowfall"] = hourly_snowfall
hourly_data["snow_depth"] = hourly_snow_depth
hourly_data["weather_code"] = hourly_weather_code
hourly_data["pressure_msl"] = hourly_pressure_msl
hourly_data["surface_pressure"] = hourly_surface_pressure
hourly_data["cloud_cover"] = hourly_cloud_cover
hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
hourly_data["visibility"] = hourly_visibility
hourly_data["evapotranspiration"] = hourly_evapotranspiration
hourly_data["et0_fao_evapotranspiration"] = hourly_et0_fao_evapotranspiration
hourly_data["vapour_pressure_deficit"] = hourly_vapour_pressure_deficit
hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
hourly_data["wind_speed_80m"] = hourly_wind_speed_80m
hourly_data["wind_speed_120m"] = hourly_wind_speed_120m
hourly_data["wind_speed_180m"] = hourly_wind_speed_180m
hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
hourly_data["wind_direction_80m"] = hourly_wind_direction_80m
hourly_data["wind_direction_120m"] = hourly_wind_direction_120m
hourly_data["wind_direction_180m"] = hourly_wind_direction_180m
hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m
hourly_data["temperature_80m"] = hourly_temperature_80m
hourly_data["temperature_120m"] = hourly_temperature_120m
hourly_data["temperature_180m"] = hourly_temperature_180m
hourly_data["soil_temperature_0cm"] = hourly_soil_temperature_0cm
hourly_data["soil_temperature_6cm"] = hourly_soil_temperature_6cm
hourly_data["soil_temperature_18cm"] = hourly_soil_temperature_18cm
hourly_data["soil_temperature_54cm"] = hourly_soil_temperature_54cm
hourly_data["soil_moisture_0_to_1cm"] = hourly_soil_moisture_0_to_1cm
hourly_data["soil_moisture_1_to_3cm"] = hourly_soil_moisture_1_to_3cm
hourly_data["soil_moisture_3_to_9cm"] = hourly_soil_moisture_3_to_9cm
hourly_data["soil_moisture_9_to_27cm"] = hourly_soil_moisture_9_to_27cm
hourly_data["soil_moisture_27_to_81cm"] = hourly_soil_moisture_27_to_81cm

df8 = pd.DataFrame(data = hourly_data)
print(df8)
# Out:
# Coordinates -8.25°N 115.25°E
# Elevation 1764.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#                           date  temperature_2m  relative_humidity_2m  \
# 0    2024-12-01 00:00:00+00:00             NaN                   NaN
# 1    2024-12-01 01:00:00+00:00             NaN                   NaN
# 2    2024-12-01 02:00:00+00:00             NaN                   NaN
# 3    2024-12-01 03:00:00+00:00             NaN                   NaN
# 4    2024-12-01 04:00:00+00:00             NaN                   NaN
# ...                        ...             ...                   ...
# 2251 2025-03-04 19:00:00+00:00       15.399499                  89.0
# 2252 2025-03-04 20:00:00+00:00       15.549500                  85.0
# 2253 2025-03-04 21:00:00+00:00       15.349500                  84.0
# 2254 2025-03-04 22:00:00+00:00       15.449500                  83.0
# 2255 2025-03-04 23:00:00+00:00       15.699500                  83.0
#
#       dew_point_2m  apparent_temperature  precipitation_probability  \
# 0              NaN                   NaN                       81.0
# 1              NaN                   NaN                       73.0
# 2              NaN                   NaN                       62.0
# 3              NaN                   NaN                       58.0
# 4              NaN                   NaN                       67.0
# ...            ...                   ...                        ...
# 2251     13.595152             16.220858                        0.0
# 2252     13.037157             16.181805                        0.0
# 2253     12.660261             15.753975                        0.0
# 2254     12.575378             15.952528                        0.0
# 2255     12.819848             16.062626                        0.0
#
#       precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0               NaN   NaN      NaN       NaN  ...               NaN
# 1               NaN   NaN      NaN       NaN  ...               NaN
# 2               NaN   NaN      NaN       NaN  ...               NaN
# 3               NaN   NaN      NaN       NaN  ...               NaN
# 4               NaN   NaN      NaN       NaN  ...               NaN
# ...             ...   ...      ...       ...  ...               ...
# 2251            0.0   0.0      0.0       0.0  ...         16.299500
# 2252            0.0   0.0      0.0       0.0  ...         16.299500
# 2253            0.0   0.0      0.0       0.0  ...         15.999499
# 2254            0.0   0.0      0.0       0.0  ...         15.999499
# 2255            0.0   0.0      0.0       0.0  ...         15.899499
#
#       soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2251             13.799500             15.699500              17.699501
# 2252             13.549500             15.399499              17.499500
# 2253             13.399499             15.149499              17.299500
# 2254             13.249499             14.949500              17.049500
# 2255             14.449500             14.849500              16.849499
#
#       soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 2251                17.7995                   0.273                   0.276
# 2252                17.7995                   0.272                   0.275
# 2253                17.7495                   0.272                   0.275
# 2254                17.7495                   0.271                   0.274
# 2255                17.7495                   0.271                   0.274
#
#       soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2251                   0.282                    0.291
# 2252                   0.282                    0.291
# 2253                   0.281                    0.290
# 2254                   0.280                    0.290
# 2255                   0.280                    0.290
#
#       soil_moisture_27_to_81cm
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2251                     0.290
# 2252                     0.290
# 2253                     0.291
# 2254                     0.291
# 2255                     0.291
#
# [2256 rows x 43 columns]

# %%
df8["Country"] = "Bali"

# %%
df = pd.concat([df, df8])

# %%
df.shape
# Out:
# (18048, 44)

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": -33.86,
	"longitude": 151.20,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth", "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", "soil_moisture_27_to_81cm"],
	"start_date": "2024-12-01",
	"end_date": "2025-03-04"
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_showers = hourly.Variables(7).ValuesAsNumpy()
hourly_snowfall = hourly.Variables(8).ValuesAsNumpy()
hourly_snow_depth = hourly.Variables(9).ValuesAsNumpy()
hourly_weather_code = hourly.Variables(10).ValuesAsNumpy()
hourly_pressure_msl = hourly.Variables(11).ValuesAsNumpy()
hourly_surface_pressure = hourly.Variables(12).ValuesAsNumpy()
hourly_cloud_cover = hourly.Variables(13).ValuesAsNumpy()
hourly_cloud_cover_low = hourly.Variables(14).ValuesAsNumpy()
hourly_cloud_cover_mid = hourly.Variables(15).ValuesAsNumpy()
hourly_cloud_cover_high = hourly.Variables(16).ValuesAsNumpy()
hourly_visibility = hourly.Variables(17).ValuesAsNumpy()
hourly_evapotranspiration = hourly.Variables(18).ValuesAsNumpy()
hourly_et0_fao_evapotranspiration = hourly.Variables(19).ValuesAsNumpy()
hourly_vapour_pressure_deficit = hourly.Variables(20).ValuesAsNumpy()
hourly_wind_speed_10m = hourly.Variables(21).ValuesAsNumpy()
hourly_wind_speed_80m = hourly.Variables(22).ValuesAsNumpy()
hourly_wind_speed_120m = hourly.Variables(23).ValuesAsNumpy()
hourly_wind_speed_180m = hourly.Variables(24).ValuesAsNumpy()
hourly_wind_direction_10m = hourly.Variables(25).ValuesAsNumpy()
hourly_wind_direction_80m = hourly.Variables(26).ValuesAsNumpy()
hourly_wind_direction_120m = hourly.Variables(27).ValuesAsNumpy()
hourly_wind_direction_180m = hourly.Variables(28).ValuesAsNumpy()
hourly_wind_gusts_10m = hourly.Variables(29).ValuesAsNumpy()
hourly_temperature_80m = hourly.Variables(30).ValuesAsNumpy()
hourly_temperature_120m = hourly.Variables(31).ValuesAsNumpy()
hourly_temperature_180m = hourly.Variables(32).ValuesAsNumpy()
hourly_soil_temperature_0cm = hourly.Variables(33).ValuesAsNumpy()
hourly_soil_temperature_6cm = hourly.Variables(34).ValuesAsNumpy()
hourly_soil_temperature_18cm = hourly.Variables(35).ValuesAsNumpy()
hourly_soil_temperature_54cm = hourly.Variables(36).ValuesAsNumpy()
hourly_soil_moisture_0_to_1cm = hourly.Variables(37).ValuesAsNumpy()
hourly_soil_moisture_1_to_3cm = hourly.Variables(38).ValuesAsNumpy()
hourly_soil_moisture_3_to_9cm = hourly.Variables(39).ValuesAsNumpy()
hourly_soil_moisture_9_to_27cm = hourly.Variables(40).ValuesAsNumpy()
hourly_soil_moisture_27_to_81cm = hourly.Variables(41).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["showers"] = hourly_showers
hourly_data["snowfall"] = hourly_snowfall
hourly_data["snow_depth"] = hourly_snow_depth
hourly_data["weather_code"] = hourly_weather_code
hourly_data["pressure_msl"] = hourly_pressure_msl
hourly_data["surface_pressure"] = hourly_surface_pressure
hourly_data["cloud_cover"] = hourly_cloud_cover
hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
hourly_data["visibility"] = hourly_visibility
hourly_data["evapotranspiration"] = hourly_evapotranspiration
hourly_data["et0_fao_evapotranspiration"] = hourly_et0_fao_evapotranspiration
hourly_data["vapour_pressure_deficit"] = hourly_vapour_pressure_deficit
hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
hourly_data["wind_speed_80m"] = hourly_wind_speed_80m
hourly_data["wind_speed_120m"] = hourly_wind_speed_120m
hourly_data["wind_speed_180m"] = hourly_wind_speed_180m
hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
hourly_data["wind_direction_80m"] = hourly_wind_direction_80m
hourly_data["wind_direction_120m"] = hourly_wind_direction_120m
hourly_data["wind_direction_180m"] = hourly_wind_direction_180m
hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m
hourly_data["temperature_80m"] = hourly_temperature_80m
hourly_data["temperature_120m"] = hourly_temperature_120m
hourly_data["temperature_180m"] = hourly_temperature_180m
hourly_data["soil_temperature_0cm"] = hourly_soil_temperature_0cm
hourly_data["soil_temperature_6cm"] = hourly_soil_temperature_6cm
hourly_data["soil_temperature_18cm"] = hourly_soil_temperature_18cm
hourly_data["soil_temperature_54cm"] = hourly_soil_temperature_54cm
hourly_data["soil_moisture_0_to_1cm"] = hourly_soil_moisture_0_to_1cm
hourly_data["soil_moisture_1_to_3cm"] = hourly_soil_moisture_1_to_3cm
hourly_data["soil_moisture_3_to_9cm"] = hourly_soil_moisture_3_to_9cm
hourly_data["soil_moisture_9_to_27cm"] = hourly_soil_moisture_9_to_27cm
hourly_data["soil_moisture_27_to_81cm"] = hourly_soil_moisture_27_to_81cm

df9 = pd.DataFrame(data = hourly_data)
print(df9)
# Out:
# Coordinates -33.875°N 151.125°E
# Elevation 0.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#                           date  temperature_2m  relative_humidity_2m  \
# 0    2024-12-01 00:00:00+00:00             NaN                   NaN
# 1    2024-12-01 01:00:00+00:00             NaN                   NaN
# 2    2024-12-01 02:00:00+00:00             NaN                   NaN
# 3    2024-12-01 03:00:00+00:00             NaN                   NaN
# 4    2024-12-01 04:00:00+00:00             NaN                   NaN
# ...                        ...             ...                   ...
# 2251 2025-03-04 19:00:00+00:00       19.719501                  90.0
# 2252 2025-03-04 20:00:00+00:00       19.869501                  91.0
# 2253 2025-03-04 21:00:00+00:00       19.919500                  91.0
# 2254 2025-03-04 22:00:00+00:00       21.219501                  86.0
# 2255 2025-03-04 23:00:00+00:00       22.669500                  76.0
#
#       dew_point_2m  apparent_temperature  precipitation_probability  \
# 0              NaN                   NaN                        0.0
# 1              NaN                   NaN                        1.0
# 2              NaN                   NaN                        6.0
# 3              NaN                   NaN                       10.0
# 4              NaN                   NaN                       11.0
# ...            ...                   ...                        ...
# 2251     18.032209             21.598467                       43.0
# 2252     18.356430             21.914497                       53.0
# 2253     18.405853             22.124611                       45.0
# 2254     18.783377             23.438122                       58.0
# 2255     18.221970             24.369759                       33.0
#
#       precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0               NaN   NaN      NaN       NaN  ...               NaN
# 1               NaN   NaN      NaN       NaN  ...               NaN
# 2               NaN   NaN      NaN       NaN  ...               NaN
# 3               NaN   NaN      NaN       NaN  ...               NaN
# 4               NaN   NaN      NaN       NaN  ...               NaN
# ...             ...   ...      ...       ...  ...               ...
# 2251            0.1   0.0      0.1       0.0  ...         17.919500
# 2252            0.3   0.0      0.3       0.0  ...         18.119501
# 2253            0.3   0.0      0.3       0.0  ...         17.819500
# 2254            0.0   0.0      0.0       0.0  ...         18.719501
# 2255            0.1   0.0      0.1       0.0  ...         19.319500
#
#       soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2251             19.869501             20.769501              22.719501
# 2252             20.019501             20.719501              22.569500
# 2253             20.719501             20.869501              22.419500
# 2254             23.519501             21.669500              22.369501
# 2255             25.569500             23.269501              22.419500
#
#       soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 2251              24.169500                   0.180                   0.177
# 2252              24.119501                   0.183                   0.178
# 2253              24.119501                   0.185                   0.180
# 2254              24.069500                   0.179                   0.180
# 2255              24.069500                   0.181                   0.179
#
#       soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2251                   0.175                    0.183
# 2252                   0.175                    0.183
# 2253                   0.175                    0.183
# 2254                   0.175                    0.183
# 2255                   0.175                    0.183
#
#       soil_moisture_27_to_81cm
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2251                     0.236
# 2252                     0.236
# 2253                     0.236
# 2254                     0.236
# 2255                     0.236
#
# [2256 rows x 43 columns]

# %%
df9["Country"] = "Sydney"

# %%
df = pd.concat([df, df9])

# %%
df.shape
# Out:
# (20304, 44)

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": 52.37,
	"longitude": 4.88,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth", "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", "soil_moisture_27_to_81cm"],
	"start_date": "2024-12-01",
	"end_date": "2025-03-04"
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_showers = hourly.Variables(7).ValuesAsNumpy()
hourly_snowfall = hourly.Variables(8).ValuesAsNumpy()
hourly_snow_depth = hourly.Variables(9).ValuesAsNumpy()
hourly_weather_code = hourly.Variables(10).ValuesAsNumpy()
hourly_pressure_msl = hourly.Variables(11).ValuesAsNumpy()
hourly_surface_pressure = hourly.Variables(12).ValuesAsNumpy()
hourly_cloud_cover = hourly.Variables(13).ValuesAsNumpy()
hourly_cloud_cover_low = hourly.Variables(14).ValuesAsNumpy()
hourly_cloud_cover_mid = hourly.Variables(15).ValuesAsNumpy()
hourly_cloud_cover_high = hourly.Variables(16).ValuesAsNumpy()
hourly_visibility = hourly.Variables(17).ValuesAsNumpy()
hourly_evapotranspiration = hourly.Variables(18).ValuesAsNumpy()
hourly_et0_fao_evapotranspiration = hourly.Variables(19).ValuesAsNumpy()
hourly_vapour_pressure_deficit = hourly.Variables(20).ValuesAsNumpy()
hourly_wind_speed_10m = hourly.Variables(21).ValuesAsNumpy()
hourly_wind_speed_80m = hourly.Variables(22).ValuesAsNumpy()
hourly_wind_speed_120m = hourly.Variables(23).ValuesAsNumpy()
hourly_wind_speed_180m = hourly.Variables(24).ValuesAsNumpy()
hourly_wind_direction_10m = hourly.Variables(25).ValuesAsNumpy()
hourly_wind_direction_80m = hourly.Variables(26).ValuesAsNumpy()
hourly_wind_direction_120m = hourly.Variables(27).ValuesAsNumpy()
hourly_wind_direction_180m = hourly.Variables(28).ValuesAsNumpy()
hourly_wind_gusts_10m = hourly.Variables(29).ValuesAsNumpy()
hourly_temperature_80m = hourly.Variables(30).ValuesAsNumpy()
hourly_temperature_120m = hourly.Variables(31).ValuesAsNumpy()
hourly_temperature_180m = hourly.Variables(32).ValuesAsNumpy()
hourly_soil_temperature_0cm = hourly.Variables(33).ValuesAsNumpy()
hourly_soil_temperature_6cm = hourly.Variables(34).ValuesAsNumpy()
hourly_soil_temperature_18cm = hourly.Variables(35).ValuesAsNumpy()
hourly_soil_temperature_54cm = hourly.Variables(36).ValuesAsNumpy()
hourly_soil_moisture_0_to_1cm = hourly.Variables(37).ValuesAsNumpy()
hourly_soil_moisture_1_to_3cm = hourly.Variables(38).ValuesAsNumpy()
hourly_soil_moisture_3_to_9cm = hourly.Variables(39).ValuesAsNumpy()
hourly_soil_moisture_9_to_27cm = hourly.Variables(40).ValuesAsNumpy()
hourly_soil_moisture_27_to_81cm = hourly.Variables(41).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["showers"] = hourly_showers
hourly_data["snowfall"] = hourly_snowfall
hourly_data["snow_depth"] = hourly_snow_depth
hourly_data["weather_code"] = hourly_weather_code
hourly_data["pressure_msl"] = hourly_pressure_msl
hourly_data["surface_pressure"] = hourly_surface_pressure
hourly_data["cloud_cover"] = hourly_cloud_cover
hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
hourly_data["visibility"] = hourly_visibility
hourly_data["evapotranspiration"] = hourly_evapotranspiration
hourly_data["et0_fao_evapotranspiration"] = hourly_et0_fao_evapotranspiration
hourly_data["vapour_pressure_deficit"] = hourly_vapour_pressure_deficit
hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
hourly_data["wind_speed_80m"] = hourly_wind_speed_80m
hourly_data["wind_speed_120m"] = hourly_wind_speed_120m
hourly_data["wind_speed_180m"] = hourly_wind_speed_180m
hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
hourly_data["wind_direction_80m"] = hourly_wind_direction_80m
hourly_data["wind_direction_120m"] = hourly_wind_direction_120m
hourly_data["wind_direction_180m"] = hourly_wind_direction_180m
hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m
hourly_data["temperature_80m"] = hourly_temperature_80m
hourly_data["temperature_120m"] = hourly_temperature_120m
hourly_data["temperature_180m"] = hourly_temperature_180m
hourly_data["soil_temperature_0cm"] = hourly_soil_temperature_0cm
hourly_data["soil_temperature_6cm"] = hourly_soil_temperature_6cm
hourly_data["soil_temperature_18cm"] = hourly_soil_temperature_18cm
hourly_data["soil_temperature_54cm"] = hourly_soil_temperature_54cm
hourly_data["soil_moisture_0_to_1cm"] = hourly_soil_moisture_0_to_1cm
hourly_data["soil_moisture_1_to_3cm"] = hourly_soil_moisture_1_to_3cm
hourly_data["soil_moisture_3_to_9cm"] = hourly_soil_moisture_3_to_9cm
hourly_data["soil_moisture_9_to_27cm"] = hourly_soil_moisture_9_to_27cm
hourly_data["soil_moisture_27_to_81cm"] = hourly_soil_moisture_27_to_81cm

df10 = pd.DataFrame(data = hourly_data)
print(df10)
# Out:
# Coordinates 52.36600112915039°N 4.871999740600586°E
# Elevation 9.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#                           date  temperature_2m  relative_humidity_2m  \
# 0    2024-12-01 00:00:00+00:00             NaN                   NaN
# 1    2024-12-01 01:00:00+00:00             NaN                   NaN
# 2    2024-12-01 02:00:00+00:00             NaN                   NaN
# 3    2024-12-01 03:00:00+00:00             NaN                   NaN
# 4    2024-12-01 04:00:00+00:00             NaN                   NaN
# ...                        ...             ...                   ...
# 2251 2025-03-04 19:00:00+00:00           7.074                  78.0
# 2252 2025-03-04 20:00:00+00:00           6.174                  79.0
# 2253 2025-03-04 21:00:00+00:00           5.674                  80.0
# 2254 2025-03-04 22:00:00+00:00           5.674                  78.0
# 2255 2025-03-04 23:00:00+00:00           5.424                  79.0
#
#       dew_point_2m  apparent_temperature  precipitation_probability  \
# 0              NaN                   NaN                        0.0
# 1              NaN                   NaN                        0.0
# 2              NaN                   NaN                        0.0
# 3              NaN                   NaN                        0.0
# 4              NaN                   NaN                        0.0
# ...            ...                   ...                        ...
# 2251      3.497380              4.923720                        0.0
# 2252      2.802500              3.367791                        0.0
# 2253      2.492828              2.968733                        0.0
# 2254      2.137025              2.800178                        0.0
# 2255      2.072626              2.328789                        0.0
#
#       precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0               NaN   NaN      NaN       NaN  ...               NaN
# 1               NaN   NaN      NaN       NaN  ...               NaN
# 2               NaN   NaN      NaN       NaN  ...               NaN
# 3               NaN   NaN      NaN       NaN  ...               NaN
# 4               NaN   NaN      NaN       NaN  ...               NaN
# ...             ...   ...      ...       ...  ...               ...
# 2251            0.0   0.0      0.0       0.0  ...             7.424
# 2252            0.0   0.0      0.0       0.0  ...             7.324
# 2253            0.0   0.0      0.0       0.0  ...             7.374
# 2254            0.0   0.0      0.0       0.0  ...             7.774
# 2255            0.0   0.0      0.0       0.0  ...             7.874
#
#       soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2251                 -3.55                7.9545                 7.3545
# 2252                 -3.05                7.1045                 7.3545
# 2253                 -2.60                6.3545                 7.3045
# 2254                 -2.65                5.7545                 7.2045
# 2255                 -2.70                5.2045                 7.1045
#
#       soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 2251                 7.5545                   0.714                   0.717
# 2252                 7.5545                   0.714                   0.717
# 2253                 7.5545                   0.715                   0.718
# 2254                 7.5545                   0.715                   0.718
# 2255                 7.5545                   0.716                   0.718
#
#       soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2251                   0.727                    0.757
# 2252                   0.727                    0.757
# 2253                   0.727                    0.757
# 2254                   0.727                    0.757
# 2255                   0.727                    0.756
#
#       soil_moisture_27_to_81cm
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2251                     0.784
# 2252                     0.784
# 2253                     0.784
# 2254                     0.784
# 2255                     0.784
#
# [2256 rows x 43 columns]

# %%
df10["Country"] = "Amsterdam"

# %%
df = pd.concat([df, df10])

# %%
df.shape
# Out:
# (22560, 44)

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": 41.38,
	"longitude": 2.15,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth", "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", "soil_moisture_27_to_81cm"],
	"start_date": "2024-12-01",
	"end_date": "2025-03-04"
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_showers = hourly.Variables(7).ValuesAsNumpy()
hourly_snowfall = hourly.Variables(8).ValuesAsNumpy()
hourly_snow_depth = hourly.Variables(9).ValuesAsNumpy()
hourly_weather_code = hourly.Variables(10).ValuesAsNumpy()
hourly_pressure_msl = hourly.Variables(11).ValuesAsNumpy()
hourly_surface_pressure = hourly.Variables(12).ValuesAsNumpy()
hourly_cloud_cover = hourly.Variables(13).ValuesAsNumpy()
hourly_cloud_cover_low = hourly.Variables(14).ValuesAsNumpy()
hourly_cloud_cover_mid = hourly.Variables(15).ValuesAsNumpy()
hourly_cloud_cover_high = hourly.Variables(16).ValuesAsNumpy()
hourly_visibility = hourly.Variables(17).ValuesAsNumpy()
hourly_evapotranspiration = hourly.Variables(18).ValuesAsNumpy()
hourly_et0_fao_evapotranspiration = hourly.Variables(19).ValuesAsNumpy()
hourly_vapour_pressure_deficit = hourly.Variables(20).ValuesAsNumpy()
hourly_wind_speed_10m = hourly.Variables(21).ValuesAsNumpy()
hourly_wind_speed_80m = hourly.Variables(22).ValuesAsNumpy()
hourly_wind_speed_120m = hourly.Variables(23).ValuesAsNumpy()
hourly_wind_speed_180m = hourly.Variables(24).ValuesAsNumpy()
hourly_wind_direction_10m = hourly.Variables(25).ValuesAsNumpy()
hourly_wind_direction_80m = hourly.Variables(26).ValuesAsNumpy()
hourly_wind_direction_120m = hourly.Variables(27).ValuesAsNumpy()
hourly_wind_direction_180m = hourly.Variables(28).ValuesAsNumpy()
hourly_wind_gusts_10m = hourly.Variables(29).ValuesAsNumpy()
hourly_temperature_80m = hourly.Variables(30).ValuesAsNumpy()
hourly_temperature_120m = hourly.Variables(31).ValuesAsNumpy()
hourly_temperature_180m = hourly.Variables(32).ValuesAsNumpy()
hourly_soil_temperature_0cm = hourly.Variables(33).ValuesAsNumpy()
hourly_soil_temperature_6cm = hourly.Variables(34).ValuesAsNumpy()
hourly_soil_temperature_18cm = hourly.Variables(35).ValuesAsNumpy()
hourly_soil_temperature_54cm = hourly.Variables(36).ValuesAsNumpy()
hourly_soil_moisture_0_to_1cm = hourly.Variables(37).ValuesAsNumpy()
hourly_soil_moisture_1_to_3cm = hourly.Variables(38).ValuesAsNumpy()
hourly_soil_moisture_3_to_9cm = hourly.Variables(39).ValuesAsNumpy()
hourly_soil_moisture_9_to_27cm = hourly.Variables(40).ValuesAsNumpy()
hourly_soil_moisture_27_to_81cm = hourly.Variables(41).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["showers"] = hourly_showers
hourly_data["snowfall"] = hourly_snowfall
hourly_data["snow_depth"] = hourly_snow_depth
hourly_data["weather_code"] = hourly_weather_code
hourly_data["pressure_msl"] = hourly_pressure_msl
hourly_data["surface_pressure"] = hourly_surface_pressure
hourly_data["cloud_cover"] = hourly_cloud_cover
hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
hourly_data["visibility"] = hourly_visibility
hourly_data["evapotranspiration"] = hourly_evapotranspiration
hourly_data["et0_fao_evapotranspiration"] = hourly_et0_fao_evapotranspiration
hourly_data["vapour_pressure_deficit"] = hourly_vapour_pressure_deficit
hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
hourly_data["wind_speed_80m"] = hourly_wind_speed_80m
hourly_data["wind_speed_120m"] = hourly_wind_speed_120m
hourly_data["wind_speed_180m"] = hourly_wind_speed_180m
hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
hourly_data["wind_direction_80m"] = hourly_wind_direction_80m
hourly_data["wind_direction_120m"] = hourly_wind_direction_120m
hourly_data["wind_direction_180m"] = hourly_wind_direction_180m
hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m
hourly_data["temperature_80m"] = hourly_temperature_80m
hourly_data["temperature_120m"] = hourly_temperature_120m
hourly_data["temperature_180m"] = hourly_temperature_180m
hourly_data["soil_temperature_0cm"] = hourly_soil_temperature_0cm
hourly_data["soil_temperature_6cm"] = hourly_soil_temperature_6cm
hourly_data["soil_temperature_18cm"] = hourly_soil_temperature_18cm
hourly_data["soil_temperature_54cm"] = hourly_soil_temperature_54cm
hourly_data["soil_moisture_0_to_1cm"] = hourly_soil_moisture_0_to_1cm
hourly_data["soil_moisture_1_to_3cm"] = hourly_soil_moisture_1_to_3cm
hourly_data["soil_moisture_3_to_9cm"] = hourly_soil_moisture_3_to_9cm
hourly_data["soil_moisture_9_to_27cm"] = hourly_soil_moisture_9_to_27cm
hourly_data["soil_moisture_27_to_81cm"] = hourly_soil_moisture_27_to_81cm

df11 = pd.DataFrame(data = hourly_data)
print(df11)
# Out:
# Coordinates 41.375°N 2.125°E
# Elevation 38.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#                           date  temperature_2m  relative_humidity_2m  \
# 0    2024-12-01 00:00:00+00:00             NaN                   NaN
# 1    2024-12-01 01:00:00+00:00             NaN                   NaN
# 2    2024-12-01 02:00:00+00:00             NaN                   NaN
# 3    2024-12-01 03:00:00+00:00             NaN                   NaN
# 4    2024-12-01 04:00:00+00:00             NaN                   NaN
# ...                        ...             ...                   ...
# 2251 2025-03-04 19:00:00+00:00         13.1075                  78.0
# 2252 2025-03-04 20:00:00+00:00         12.9575                  76.0
# 2253 2025-03-04 21:00:00+00:00         12.8075                  76.0
# 2254 2025-03-04 22:00:00+00:00         12.7075                  77.0
# 2255 2025-03-04 23:00:00+00:00         12.5075                  80.0
#
#       dew_point_2m  apparent_temperature  precipitation_probability  \
# 0              NaN                   NaN                        0.0
# 1              NaN                   NaN                        0.0
# 2              NaN                   NaN                        0.0
# 3              NaN                   NaN                        0.0
# 4              NaN                   NaN                        0.0
# ...            ...                   ...                        ...
# 2251      9.357535             11.018421                        0.0
# 2252      8.826627             10.990039                        0.0
# 2253      8.681428             10.974980                        0.0
# 2254      8.777991             10.927680                        0.0
# 2255      9.150299             10.839010                        0.0
#
#       precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0               NaN   NaN      NaN       NaN  ...               NaN
# 1               NaN   NaN      NaN       NaN  ...               NaN
# 2               NaN   NaN      NaN       NaN  ...               NaN
# 3               NaN   NaN      NaN       NaN  ...               NaN
# 4               NaN   NaN      NaN       NaN  ...               NaN
# ...             ...   ...      ...       ...  ...               ...
# 2251            0.0   0.0      0.0       0.0  ...           11.7575
# 2252            0.0   0.0      0.0       0.0  ...           11.5575
# 2253            0.0   0.0      0.0       0.0  ...           11.4575
# 2254            0.0   0.0      0.0       0.0  ...           11.2575
# 2255            0.0   0.0      0.0       0.0  ...           10.9575
#
#       soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2251               12.2075               13.9075                14.3075
# 2252               11.9575               13.3075                14.2075
# 2253               11.7575               12.9075                14.1075
# 2254               11.7075               12.7075                13.9575
# 2255               11.7575               12.5575                13.8575
#
#       soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 2251                12.8575                   0.296                   0.297
# 2252                12.9075                   0.296                   0.297
# 2253                12.9075                   0.296                   0.297
# 2254                12.9075                   0.296                   0.297
# 2255                12.9075                   0.296                   0.297
#
#       soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2251                   0.301                    0.310
# 2252                   0.301                    0.309
# 2253                   0.301                    0.309
# 2254                   0.300                    0.309
# 2255                   0.300                    0.309
#
#       soil_moisture_27_to_81cm
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2251                     0.317
# 2252                     0.317
# 2253                     0.317
# 2254                     0.317
# 2255                     0.317
#
# [2256 rows x 43 columns]

# %%
df11["Country"] = "Barcelona"

# %%
df = pd.concat([df, df11])

# %%
df.shape
# Out:
# (24816, 44)

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": 48.20,
	"longitude": 16.37,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth", "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", "soil_moisture_27_to_81cm"],
	"start_date": "2024-12-01",
	"end_date": "2025-03-04"
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_showers = hourly.Variables(7).ValuesAsNumpy()
hourly_snowfall = hourly.Variables(8).ValuesAsNumpy()
hourly_snow_depth = hourly.Variables(9).ValuesAsNumpy()
hourly_weather_code = hourly.Variables(10).ValuesAsNumpy()
hourly_pressure_msl = hourly.Variables(11).ValuesAsNumpy()
hourly_surface_pressure = hourly.Variables(12).ValuesAsNumpy()
hourly_cloud_cover = hourly.Variables(13).ValuesAsNumpy()
hourly_cloud_cover_low = hourly.Variables(14).ValuesAsNumpy()
hourly_cloud_cover_mid = hourly.Variables(15).ValuesAsNumpy()
hourly_cloud_cover_high = hourly.Variables(16).ValuesAsNumpy()
hourly_visibility = hourly.Variables(17).ValuesAsNumpy()
hourly_evapotranspiration = hourly.Variables(18).ValuesAsNumpy()
hourly_et0_fao_evapotranspiration = hourly.Variables(19).ValuesAsNumpy()
hourly_vapour_pressure_deficit = hourly.Variables(20).ValuesAsNumpy()
hourly_wind_speed_10m = hourly.Variables(21).ValuesAsNumpy()
hourly_wind_speed_80m = hourly.Variables(22).ValuesAsNumpy()
hourly_wind_speed_120m = hourly.Variables(23).ValuesAsNumpy()
hourly_wind_speed_180m = hourly.Variables(24).ValuesAsNumpy()
hourly_wind_direction_10m = hourly.Variables(25).ValuesAsNumpy()
hourly_wind_direction_80m = hourly.Variables(26).ValuesAsNumpy()
hourly_wind_direction_120m = hourly.Variables(27).ValuesAsNumpy()
hourly_wind_direction_180m = hourly.Variables(28).ValuesAsNumpy()
hourly_wind_gusts_10m = hourly.Variables(29).ValuesAsNumpy()
hourly_temperature_80m = hourly.Variables(30).ValuesAsNumpy()
hourly_temperature_120m = hourly.Variables(31).ValuesAsNumpy()
hourly_temperature_180m = hourly.Variables(32).ValuesAsNumpy()
hourly_soil_temperature_0cm = hourly.Variables(33).ValuesAsNumpy()
hourly_soil_temperature_6cm = hourly.Variables(34).ValuesAsNumpy()
hourly_soil_temperature_18cm = hourly.Variables(35).ValuesAsNumpy()
hourly_soil_temperature_54cm = hourly.Variables(36).ValuesAsNumpy()
hourly_soil_moisture_0_to_1cm = hourly.Variables(37).ValuesAsNumpy()
hourly_soil_moisture_1_to_3cm = hourly.Variables(38).ValuesAsNumpy()
hourly_soil_moisture_3_to_9cm = hourly.Variables(39).ValuesAsNumpy()
hourly_soil_moisture_9_to_27cm = hourly.Variables(40).ValuesAsNumpy()
hourly_soil_moisture_27_to_81cm = hourly.Variables(41).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["showers"] = hourly_showers
hourly_data["snowfall"] = hourly_snowfall
hourly_data["snow_depth"] = hourly_snow_depth
hourly_data["weather_code"] = hourly_weather_code
hourly_data["pressure_msl"] = hourly_pressure_msl
hourly_data["surface_pressure"] = hourly_surface_pressure
hourly_data["cloud_cover"] = hourly_cloud_cover
hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
hourly_data["visibility"] = hourly_visibility
hourly_data["evapotranspiration"] = hourly_evapotranspiration
hourly_data["et0_fao_evapotranspiration"] = hourly_et0_fao_evapotranspiration
hourly_data["vapour_pressure_deficit"] = hourly_vapour_pressure_deficit
hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
hourly_data["wind_speed_80m"] = hourly_wind_speed_80m
hourly_data["wind_speed_120m"] = hourly_wind_speed_120m
hourly_data["wind_speed_180m"] = hourly_wind_speed_180m
hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
hourly_data["wind_direction_80m"] = hourly_wind_direction_80m
hourly_data["wind_direction_120m"] = hourly_wind_direction_120m
hourly_data["wind_direction_180m"] = hourly_wind_direction_180m
hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m
hourly_data["temperature_80m"] = hourly_temperature_80m
hourly_data["temperature_120m"] = hourly_temperature_120m
hourly_data["temperature_180m"] = hourly_temperature_180m
hourly_data["soil_temperature_0cm"] = hourly_soil_temperature_0cm
hourly_data["soil_temperature_6cm"] = hourly_soil_temperature_6cm
hourly_data["soil_temperature_18cm"] = hourly_soil_temperature_18cm
hourly_data["soil_temperature_54cm"] = hourly_soil_temperature_54cm
hourly_data["soil_moisture_0_to_1cm"] = hourly_soil_moisture_0_to_1cm
hourly_data["soil_moisture_1_to_3cm"] = hourly_soil_moisture_1_to_3cm
hourly_data["soil_moisture_3_to_9cm"] = hourly_soil_moisture_3_to_9cm
hourly_data["soil_moisture_9_to_27cm"] = hourly_soil_moisture_9_to_27cm
hourly_data["soil_moisture_27_to_81cm"] = hourly_soil_moisture_27_to_81cm

df12 = pd.DataFrame(data = hourly_data)
print(df12)
# Out:
# Coordinates 48.20000076293945°N 16.3799991607666°E
# Elevation 186.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#                           date  temperature_2m  relative_humidity_2m  \
# 0    2024-12-01 00:00:00+00:00             NaN                   NaN
# 1    2024-12-01 01:00:00+00:00             NaN                   NaN
# 2    2024-12-01 02:00:00+00:00             NaN                   NaN
# 3    2024-12-01 03:00:00+00:00             NaN                   NaN
# 4    2024-12-01 04:00:00+00:00             NaN                   NaN
# ...                        ...             ...                   ...
# 2251 2025-03-04 19:00:00+00:00           8.176                  57.0
# 2252 2025-03-04 20:00:00+00:00           7.326                  63.0
# 2253 2025-03-04 21:00:00+00:00           7.426                  60.0
# 2254 2025-03-04 22:00:00+00:00           6.426                  65.0
# 2255 2025-03-04 23:00:00+00:00           4.626                  74.0
#
#       dew_point_2m  apparent_temperature  precipitation_probability  \
# 0              NaN                   NaN                        0.0
# 1              NaN                   NaN                        0.0
# 2              NaN                   NaN                        0.0
# 3              NaN                   NaN                        0.0
# 4              NaN                   NaN                        0.0
# ...            ...                   ...                        ...
# 2251      0.158669              5.592489                        0.0
# 2252      0.742656              5.201739                        0.0
# 2253      0.161906              5.007623                        0.0
# 2254      0.320613              4.045600                        0.0
# 2255      0.388123              2.152095                        0.0
#
#       precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0               NaN   NaN      NaN       NaN  ...               NaN
# 1               NaN   NaN      NaN       NaN  ...               NaN
# 2               NaN   NaN      NaN       NaN  ...               NaN
# 3               NaN   NaN      NaN       NaN  ...               NaN
# 4               NaN   NaN      NaN       NaN  ...               NaN
# ...             ...   ...      ...       ...  ...               ...
# 2251            0.0   0.0      0.0       0.0  ...             9.426
# 2252            0.0   0.0      0.0       0.0  ...             9.026
# 2253            0.0   0.0      0.0       0.0  ...             8.826
# 2254            0.0   0.0      0.0       0.0  ...             8.226
# 2255            0.0   0.0      0.0       0.0  ...             7.526
#
#       soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2251                 7.176                 9.026                  9.426
# 2252                 6.226                 8.126                  9.276
# 2253                 5.526                 7.376                  9.026
# 2254                 4.926                 6.776                  8.776
# 2255                 4.376                 6.276                  8.526
#
#       soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 2251                  6.876                   0.182                   0.191
# 2252                  6.876                   0.182                   0.191
# 2253                  6.926                   0.182                   0.191
# 2254                  6.926                   0.182                   0.190
# 2255                  6.976                   0.182                   0.190
#
#       soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2251                   0.204                    0.227
# 2252                   0.204                    0.226
# 2253                   0.204                    0.226
# 2254                   0.204                    0.226
# 2255                   0.204                    0.226
#
#       soil_moisture_27_to_81cm
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2251                     0.247
# 2252                     0.247
# 2253                     0.247
# 2254                     0.247
# 2255                     0.247
#
# [2256 rows x 43 columns]

# %%
df12["Country"] = "Vienna"

# %%
df = pd.concat([df, df12])

# %%
df.shape
# Out:
# (27072, 44)

# %%
df.isna().sum()
# Out:
# date                             0
# temperature_2m                1068
# relative_humidity_2m          1068
# dew_point_2m                  1068
# apparent_temperature          1068
# precipitation_probability        0
# precipitation                 1068
# rain                          1380
# showers                       1068
# snowfall                      1380
# snow_depth                    1080
# weather_code                  1380
# pressure_msl                  1068
# surface_pressure              1068
# cloud_cover                   1068
# cloud_cover_low               1068
# cloud_cover_mid               1068
# cloud_cover_high              1068
# visibility                    1068
# evapotranspiration               0
# et0_fao_evapotranspiration    1068
# vapour_pressure_deficit       1068
# wind_speed_10m                1068
# wind_speed_80m                1068
# wind_speed_120m               1068
# wind_speed_180m               3785
# wind_direction_10m            1068
# wind_direction_80m            1068
# wind_direction_120m           1068
# wind_direction_180m           3785
# wind_gusts_10m                1068
# temperature_80m               1068
# temperature_120m              1068
# temperature_180m              3785
# soil_temperature_0cm          3785
# soil_temperature_6cm          3785
# soil_temperature_18cm         3785
# soil_temperature_54cm         3785
# soil_moisture_0_to_1cm        3785
# soil_moisture_1_to_3cm        3785
# soil_moisture_3_to_9cm        3785
# soil_moisture_9_to_27cm       3785
# soil_moisture_27_to_81cm      3785
# Country                          0
# dtype: int64

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": 50.08,
	"longitude": 14.42,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth", "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", "soil_moisture_27_to_81cm"],
	"start_date": "2024-12-01",
	"end_date": "2025-03-04"
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_showers = hourly.Variables(7).ValuesAsNumpy()
hourly_snowfall = hourly.Variables(8).ValuesAsNumpy()
hourly_snow_depth = hourly.Variables(9).ValuesAsNumpy()
hourly_weather_code = hourly.Variables(10).ValuesAsNumpy()
hourly_pressure_msl = hourly.Variables(11).ValuesAsNumpy()
hourly_surface_pressure = hourly.Variables(12).ValuesAsNumpy()
hourly_cloud_cover = hourly.Variables(13).ValuesAsNumpy()
hourly_cloud_cover_low = hourly.Variables(14).ValuesAsNumpy()
hourly_cloud_cover_mid = hourly.Variables(15).ValuesAsNumpy()
hourly_cloud_cover_high = hourly.Variables(16).ValuesAsNumpy()
hourly_visibility = hourly.Variables(17).ValuesAsNumpy()
hourly_evapotranspiration = hourly.Variables(18).ValuesAsNumpy()
hourly_et0_fao_evapotranspiration = hourly.Variables(19).ValuesAsNumpy()
hourly_vapour_pressure_deficit = hourly.Variables(20).ValuesAsNumpy()
hourly_wind_speed_10m = hourly.Variables(21).ValuesAsNumpy()
hourly_wind_speed_80m = hourly.Variables(22).ValuesAsNumpy()
hourly_wind_speed_120m = hourly.Variables(23).ValuesAsNumpy()
hourly_wind_speed_180m = hourly.Variables(24).ValuesAsNumpy()
hourly_wind_direction_10m = hourly.Variables(25).ValuesAsNumpy()
hourly_wind_direction_80m = hourly.Variables(26).ValuesAsNumpy()
hourly_wind_direction_120m = hourly.Variables(27).ValuesAsNumpy()
hourly_wind_direction_180m = hourly.Variables(28).ValuesAsNumpy()
hourly_wind_gusts_10m = hourly.Variables(29).ValuesAsNumpy()
hourly_temperature_80m = hourly.Variables(30).ValuesAsNumpy()
hourly_temperature_120m = hourly.Variables(31).ValuesAsNumpy()
hourly_temperature_180m = hourly.Variables(32).ValuesAsNumpy()
hourly_soil_temperature_0cm = hourly.Variables(33).ValuesAsNumpy()
hourly_soil_temperature_6cm = hourly.Variables(34).ValuesAsNumpy()
hourly_soil_temperature_18cm = hourly.Variables(35).ValuesAsNumpy()
hourly_soil_temperature_54cm = hourly.Variables(36).ValuesAsNumpy()
hourly_soil_moisture_0_to_1cm = hourly.Variables(37).ValuesAsNumpy()
hourly_soil_moisture_1_to_3cm = hourly.Variables(38).ValuesAsNumpy()
hourly_soil_moisture_3_to_9cm = hourly.Variables(39).ValuesAsNumpy()
hourly_soil_moisture_9_to_27cm = hourly.Variables(40).ValuesAsNumpy()
hourly_soil_moisture_27_to_81cm = hourly.Variables(41).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["showers"] = hourly_showers
hourly_data["snowfall"] = hourly_snowfall
hourly_data["snow_depth"] = hourly_snow_depth
hourly_data["weather_code"] = hourly_weather_code
hourly_data["pressure_msl"] = hourly_pressure_msl
hourly_data["surface_pressure"] = hourly_surface_pressure
hourly_data["cloud_cover"] = hourly_cloud_cover
hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
hourly_data["visibility"] = hourly_visibility
hourly_data["evapotranspiration"] = hourly_evapotranspiration
hourly_data["et0_fao_evapotranspiration"] = hourly_et0_fao_evapotranspiration
hourly_data["vapour_pressure_deficit"] = hourly_vapour_pressure_deficit
hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
hourly_data["wind_speed_80m"] = hourly_wind_speed_80m
hourly_data["wind_speed_120m"] = hourly_wind_speed_120m
hourly_data["wind_speed_180m"] = hourly_wind_speed_180m
hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
hourly_data["wind_direction_80m"] = hourly_wind_direction_80m
hourly_data["wind_direction_120m"] = hourly_wind_direction_120m
hourly_data["wind_direction_180m"] = hourly_wind_direction_180m
hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m
hourly_data["temperature_80m"] = hourly_temperature_80m
hourly_data["temperature_120m"] = hourly_temperature_120m
hourly_data["temperature_180m"] = hourly_temperature_180m
hourly_data["soil_temperature_0cm"] = hourly_soil_temperature_0cm
hourly_data["soil_temperature_6cm"] = hourly_soil_temperature_6cm
hourly_data["soil_temperature_18cm"] = hourly_soil_temperature_18cm
hourly_data["soil_temperature_54cm"] = hourly_soil_temperature_54cm
hourly_data["soil_moisture_0_to_1cm"] = hourly_soil_moisture_0_to_1cm
hourly_data["soil_moisture_1_to_3cm"] = hourly_soil_moisture_1_to_3cm
hourly_data["soil_moisture_3_to_9cm"] = hourly_soil_moisture_3_to_9cm
hourly_data["soil_moisture_9_to_27cm"] = hourly_soil_moisture_9_to_27cm
hourly_data["soil_moisture_27_to_81cm"] = hourly_soil_moisture_27_to_81cm

df13 = pd.DataFrame(data = hourly_data)
print(df13)
# Out:
# Coordinates 50.08000183105469°N 14.419998168945312°E
# Elevation 208.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#                           date  temperature_2m  relative_humidity_2m  \
# 0    2024-12-01 00:00:00+00:00             NaN                   NaN
# 1    2024-12-01 01:00:00+00:00             NaN                   NaN
# 2    2024-12-01 02:00:00+00:00             NaN                   NaN
# 3    2024-12-01 03:00:00+00:00             NaN                   NaN
# 4    2024-12-01 04:00:00+00:00             NaN                   NaN
# ...                        ...             ...                   ...
# 2251 2025-03-04 19:00:00+00:00           6.728                  50.0
# 2252 2025-03-04 20:00:00+00:00           5.178                  53.0
# 2253 2025-03-04 21:00:00+00:00           4.028                  54.0
# 2254 2025-03-04 22:00:00+00:00           2.778                  58.0
# 2255 2025-03-04 23:00:00+00:00           1.978                  60.0
#
#       dew_point_2m  apparent_temperature  precipitation_probability  \
# 0              NaN                   NaN                        0.0
# 1              NaN                   NaN                        0.0
# 2              NaN                   NaN                        0.0
# 3              NaN                   NaN                        0.0
# 4              NaN                   NaN                        0.0
# ...            ...                   ...                        ...
# 2251     -2.974531              3.970306                        0.0
# 2252     -3.629645              2.079794                        0.0
# 2253     -4.451514              0.772416                        0.0
# 2254     -4.673290             -0.554663                        0.0
# 2255     -4.977910             -1.337409                        0.0
#
#       precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0               NaN   NaN      NaN       NaN  ...               NaN
# 1               NaN   NaN      NaN       NaN  ...               NaN
# 2               NaN   NaN      NaN       NaN  ...               NaN
# 3               NaN   NaN      NaN       NaN  ...               NaN
# 4               NaN   NaN      NaN       NaN  ...               NaN
# ...             ...   ...      ...       ...  ...               ...
# 2251            0.0   0.0      0.0       0.0  ...             9.278
# 2252            0.0   0.0      0.0       0.0  ...             9.078
# 2253            0.0   0.0      0.0       0.0  ...             8.678
# 2254            0.0   0.0      0.0       0.0  ...             7.978
# 2255            0.0   0.0      0.0       0.0  ...             7.178
#
#       soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2251                 4.528                 6.928                  7.128
# 2252                 3.678                 5.878                  7.028
# 2253                 2.928                 5.078                  6.828
# 2254                 2.228                 4.378                  6.578
# 2255                 1.578                 3.778                  6.328
#
#       soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 2251                  5.328                   0.274                   0.275
# 2252                  5.328                   0.274                   0.275
# 2253                  5.378                   0.274                   0.275
# 2254                  5.378                   0.274                   0.275
# 2255                  5.378                   0.274                   0.275
#
#       soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2251                   0.279                    0.289
# 2252                   0.279                    0.289
# 2253                   0.279                    0.289
# 2254                   0.279                    0.289
# 2255                   0.279                    0.289
#
#       soil_moisture_27_to_81cm
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2251                      0.31
# 2252                      0.31
# 2253                      0.31
# 2254                      0.31
# 2255                      0.31
#
# [2256 rows x 43 columns]

# %%
df13["Country"] = "Prague"

# %%
df = pd.concat([df, df13])

# %%
df.shape
# Out:
# (29328, 44)

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": 41.16,
	"longitude": 28.76,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth", "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", "soil_moisture_27_to_81cm"],
	"start_date": "2024-12-01",
	"end_date": "2025-03-04"
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_showers = hourly.Variables(7).ValuesAsNumpy()
hourly_snowfall = hourly.Variables(8).ValuesAsNumpy()
hourly_snow_depth = hourly.Variables(9).ValuesAsNumpy()
hourly_weather_code = hourly.Variables(10).ValuesAsNumpy()
hourly_pressure_msl = hourly.Variables(11).ValuesAsNumpy()
hourly_surface_pressure = hourly.Variables(12).ValuesAsNumpy()
hourly_cloud_cover = hourly.Variables(13).ValuesAsNumpy()
hourly_cloud_cover_low = hourly.Variables(14).ValuesAsNumpy()
hourly_cloud_cover_mid = hourly.Variables(15).ValuesAsNumpy()
hourly_cloud_cover_high = hourly.Variables(16).ValuesAsNumpy()
hourly_visibility = hourly.Variables(17).ValuesAsNumpy()
hourly_evapotranspiration = hourly.Variables(18).ValuesAsNumpy()
hourly_et0_fao_evapotranspiration = hourly.Variables(19).ValuesAsNumpy()
hourly_vapour_pressure_deficit = hourly.Variables(20).ValuesAsNumpy()
hourly_wind_speed_10m = hourly.Variables(21).ValuesAsNumpy()
hourly_wind_speed_80m = hourly.Variables(22).ValuesAsNumpy()
hourly_wind_speed_120m = hourly.Variables(23).ValuesAsNumpy()
hourly_wind_speed_180m = hourly.Variables(24).ValuesAsNumpy()
hourly_wind_direction_10m = hourly.Variables(25).ValuesAsNumpy()
hourly_wind_direction_80m = hourly.Variables(26).ValuesAsNumpy()
hourly_wind_direction_120m = hourly.Variables(27).ValuesAsNumpy()
hourly_wind_direction_180m = hourly.Variables(28).ValuesAsNumpy()
hourly_wind_gusts_10m = hourly.Variables(29).ValuesAsNumpy()
hourly_temperature_80m = hourly.Variables(30).ValuesAsNumpy()
hourly_temperature_120m = hourly.Variables(31).ValuesAsNumpy()
hourly_temperature_180m = hourly.Variables(32).ValuesAsNumpy()
hourly_soil_temperature_0cm = hourly.Variables(33).ValuesAsNumpy()
hourly_soil_temperature_6cm = hourly.Variables(34).ValuesAsNumpy()
hourly_soil_temperature_18cm = hourly.Variables(35).ValuesAsNumpy()
hourly_soil_temperature_54cm = hourly.Variables(36).ValuesAsNumpy()
hourly_soil_moisture_0_to_1cm = hourly.Variables(37).ValuesAsNumpy()
hourly_soil_moisture_1_to_3cm = hourly.Variables(38).ValuesAsNumpy()
hourly_soil_moisture_3_to_9cm = hourly.Variables(39).ValuesAsNumpy()
hourly_soil_moisture_9_to_27cm = hourly.Variables(40).ValuesAsNumpy()
hourly_soil_moisture_27_to_81cm = hourly.Variables(41).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["showers"] = hourly_showers
hourly_data["snowfall"] = hourly_snowfall
hourly_data["snow_depth"] = hourly_snow_depth
hourly_data["weather_code"] = hourly_weather_code
hourly_data["pressure_msl"] = hourly_pressure_msl
hourly_data["surface_pressure"] = hourly_surface_pressure
hourly_data["cloud_cover"] = hourly_cloud_cover
hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
hourly_data["visibility"] = hourly_visibility
hourly_data["evapotranspiration"] = hourly_evapotranspiration
hourly_data["et0_fao_evapotranspiration"] = hourly_et0_fao_evapotranspiration
hourly_data["vapour_pressure_deficit"] = hourly_vapour_pressure_deficit
hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
hourly_data["wind_speed_80m"] = hourly_wind_speed_80m
hourly_data["wind_speed_120m"] = hourly_wind_speed_120m
hourly_data["wind_speed_180m"] = hourly_wind_speed_180m
hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
hourly_data["wind_direction_80m"] = hourly_wind_direction_80m
hourly_data["wind_direction_120m"] = hourly_wind_direction_120m
hourly_data["wind_direction_180m"] = hourly_wind_direction_180m
hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m
hourly_data["temperature_80m"] = hourly_temperature_80m
hourly_data["temperature_120m"] = hourly_temperature_120m
hourly_data["temperature_180m"] = hourly_temperature_180m
hourly_data["soil_temperature_0cm"] = hourly_soil_temperature_0cm
hourly_data["soil_temperature_6cm"] = hourly_soil_temperature_6cm
hourly_data["soil_temperature_18cm"] = hourly_soil_temperature_18cm
hourly_data["soil_temperature_54cm"] = hourly_soil_temperature_54cm
hourly_data["soil_moisture_0_to_1cm"] = hourly_soil_moisture_0_to_1cm
hourly_data["soil_moisture_1_to_3cm"] = hourly_soil_moisture_1_to_3cm
hourly_data["soil_moisture_3_to_9cm"] = hourly_soil_moisture_3_to_9cm
hourly_data["soil_moisture_9_to_27cm"] = hourly_soil_moisture_9_to_27cm
hourly_data["soil_moisture_27_to_81cm"] = hourly_soil_moisture_27_to_81cm

df14 = pd.DataFrame(data = hourly_data)
print(df14)
# Out:
# Coordinates 41.1875°N 28.75°E
# Elevation 135.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#                           date  temperature_2m  relative_humidity_2m  \
# 0    2024-12-01 00:00:00+00:00             NaN                   NaN
# 1    2024-12-01 01:00:00+00:00             NaN                   NaN
# 2    2024-12-01 02:00:00+00:00             NaN                   NaN
# 3    2024-12-01 03:00:00+00:00             NaN                   NaN
# 4    2024-12-01 04:00:00+00:00             NaN                   NaN
# ...                        ...             ...                   ...
# 2251 2025-03-04 19:00:00+00:00           3.901                  78.0
# 2252 2025-03-04 20:00:00+00:00           3.851                  78.0
# 2253 2025-03-04 21:00:00+00:00           3.851                  78.0
# 2254 2025-03-04 22:00:00+00:00           3.801                  77.0
# 2255 2025-03-04 23:00:00+00:00           3.601                  77.0
#
#       dew_point_2m  apparent_temperature  precipitation_probability  \
# 0              NaN                   NaN                        0.0
# 1              NaN                   NaN                        0.0
# 2              NaN                   NaN                        0.0
# 3              NaN                   NaN                        0.0
# 4              NaN                   NaN                        0.0
# ...            ...                   ...                        ...
# 2251      0.413919              0.653152                        0.0
# 2252      0.365321              0.669709                        0.0
# 2253      0.365321              0.667237                        0.0
# 2254      0.138458              0.581690                        0.0
# 2255     -0.055653              0.499769                        0.0
#
#       precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0               NaN   NaN      NaN       NaN  ...               NaN
# 1               NaN   NaN      NaN       NaN  ...               NaN
# 2               NaN   NaN      NaN       NaN  ...               NaN
# 3               NaN   NaN      NaN       NaN  ...               NaN
# 4               NaN   NaN      NaN       NaN  ...               NaN
# ...             ...   ...      ...       ...  ...               ...
# 2251            0.0   0.0      0.0       0.0  ...             3.001
# 2252            0.0   0.0      0.0       0.0  ...             3.001
# 2253            0.0   0.0      0.0       0.0  ...             2.901
# 2254            0.0   0.0      0.0       0.0  ...             2.801
# 2255            0.0   0.0      0.0       0.0  ...             2.901
#
#       soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2251                 3.201                 4.901                  6.051
# 2252                 3.051                 4.601                  5.951
# 2253                 3.001                 4.401                  5.851
# 2254                 2.901                 4.251                  5.751
# 2255                 2.451                 4.101                  5.651
#
#       soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 2251                  6.151                   0.317                   0.320
# 2252                  6.151                   0.318                   0.320
# 2253                  6.201                   0.318                   0.320
# 2254                  6.201                   0.318                   0.321
# 2255                  6.201                   0.318                   0.321
#
#       soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2251                   0.328                    0.342
# 2252                   0.327                    0.342
# 2253                   0.327                    0.342
# 2254                   0.327                    0.342
# 2255                   0.327                    0.342
#
#       soil_moisture_27_to_81cm
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2251                     0.371
# 2252                     0.371
# 2253                     0.371
# 2254                     0.371
# 2255                     0.371
#
# [2256 rows x 43 columns]

# %%
df14["Country"] = "Istanbul"

# %%
df = pd.concat([df, df14])

# %%
df.shape
# Out:
# (31584, 44)

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": 41.16,
	"longitude": 28.76,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth", "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", "soil_moisture_27_to_81cm"],
	"start_date": "2024-12-01",
	"end_date": "2025-03-04"
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_showers = hourly.Variables(7).ValuesAsNumpy()
hourly_snowfall = hourly.Variables(8).ValuesAsNumpy()
hourly_snow_depth = hourly.Variables(9).ValuesAsNumpy()
hourly_weather_code = hourly.Variables(10).ValuesAsNumpy()
hourly_pressure_msl = hourly.Variables(11).ValuesAsNumpy()
hourly_surface_pressure = hourly.Variables(12).ValuesAsNumpy()
hourly_cloud_cover = hourly.Variables(13).ValuesAsNumpy()
hourly_cloud_cover_low = hourly.Variables(14).ValuesAsNumpy()
hourly_cloud_cover_mid = hourly.Variables(15).ValuesAsNumpy()
hourly_cloud_cover_high = hourly.Variables(16).ValuesAsNumpy()
hourly_visibility = hourly.Variables(17).ValuesAsNumpy()
hourly_evapotranspiration = hourly.Variables(18).ValuesAsNumpy()
hourly_et0_fao_evapotranspiration = hourly.Variables(19).ValuesAsNumpy()
hourly_vapour_pressure_deficit = hourly.Variables(20).ValuesAsNumpy()
hourly_wind_speed_10m = hourly.Variables(21).ValuesAsNumpy()
hourly_wind_speed_80m = hourly.Variables(22).ValuesAsNumpy()
hourly_wind_speed_120m = hourly.Variables(23).ValuesAsNumpy()
hourly_wind_speed_180m = hourly.Variables(24).ValuesAsNumpy()
hourly_wind_direction_10m = hourly.Variables(25).ValuesAsNumpy()
hourly_wind_direction_80m = hourly.Variables(26).ValuesAsNumpy()
hourly_wind_direction_120m = hourly.Variables(27).ValuesAsNumpy()
hourly_wind_direction_180m = hourly.Variables(28).ValuesAsNumpy()
hourly_wind_gusts_10m = hourly.Variables(29).ValuesAsNumpy()
hourly_temperature_80m = hourly.Variables(30).ValuesAsNumpy()
hourly_temperature_120m = hourly.Variables(31).ValuesAsNumpy()
hourly_temperature_180m = hourly.Variables(32).ValuesAsNumpy()
hourly_soil_temperature_0cm = hourly.Variables(33).ValuesAsNumpy()
hourly_soil_temperature_6cm = hourly.Variables(34).ValuesAsNumpy()
hourly_soil_temperature_18cm = hourly.Variables(35).ValuesAsNumpy()
hourly_soil_temperature_54cm = hourly.Variables(36).ValuesAsNumpy()
hourly_soil_moisture_0_to_1cm = hourly.Variables(37).ValuesAsNumpy()
hourly_soil_moisture_1_to_3cm = hourly.Variables(38).ValuesAsNumpy()
hourly_soil_moisture_3_to_9cm = hourly.Variables(39).ValuesAsNumpy()
hourly_soil_moisture_9_to_27cm = hourly.Variables(40).ValuesAsNumpy()
hourly_soil_moisture_27_to_81cm = hourly.Variables(41).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["showers"] = hourly_showers
hourly_data["snowfall"] = hourly_snowfall
hourly_data["snow_depth"] = hourly_snow_depth
hourly_data["weather_code"] = hourly_weather_code
hourly_data["pressure_msl"] = hourly_pressure_msl
hourly_data["surface_pressure"] = hourly_surface_pressure
hourly_data["cloud_cover"] = hourly_cloud_cover
hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
hourly_data["visibility"] = hourly_visibility
hourly_data["evapotranspiration"] = hourly_evapotranspiration
hourly_data["et0_fao_evapotranspiration"] = hourly_et0_fao_evapotranspiration
hourly_data["vapour_pressure_deficit"] = hourly_vapour_pressure_deficit
hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
hourly_data["wind_speed_80m"] = hourly_wind_speed_80m
hourly_data["wind_speed_120m"] = hourly_wind_speed_120m
hourly_data["wind_speed_180m"] = hourly_wind_speed_180m
hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
hourly_data["wind_direction_80m"] = hourly_wind_direction_80m
hourly_data["wind_direction_120m"] = hourly_wind_direction_120m
hourly_data["wind_direction_180m"] = hourly_wind_direction_180m
hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m
hourly_data["temperature_80m"] = hourly_temperature_80m
hourly_data["temperature_120m"] = hourly_temperature_120m
hourly_data["temperature_180m"] = hourly_temperature_180m
hourly_data["soil_temperature_0cm"] = hourly_soil_temperature_0cm
hourly_data["soil_temperature_6cm"] = hourly_soil_temperature_6cm
hourly_data["soil_temperature_18cm"] = hourly_soil_temperature_18cm
hourly_data["soil_temperature_54cm"] = hourly_soil_temperature_54cm
hourly_data["soil_moisture_0_to_1cm"] = hourly_soil_moisture_0_to_1cm
hourly_data["soil_moisture_1_to_3cm"] = hourly_soil_moisture_1_to_3cm
hourly_data["soil_moisture_3_to_9cm"] = hourly_soil_moisture_3_to_9cm
hourly_data["soil_moisture_9_to_27cm"] = hourly_soil_moisture_9_to_27cm
hourly_data["soil_moisture_27_to_81cm"] = hourly_soil_moisture_27_to_81cm

df15 = pd.DataFrame(data = hourly_data)
print(df15)
# Out:
# Coordinates 41.1875°N 28.75°E
# Elevation 135.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#                           date  temperature_2m  relative_humidity_2m  \
# 0    2024-12-01 00:00:00+00:00             NaN                   NaN
# 1    2024-12-01 01:00:00+00:00             NaN                   NaN
# 2    2024-12-01 02:00:00+00:00             NaN                   NaN
# 3    2024-12-01 03:00:00+00:00             NaN                   NaN
# 4    2024-12-01 04:00:00+00:00             NaN                   NaN
# ...                        ...             ...                   ...
# 2251 2025-03-04 19:00:00+00:00           3.901                  78.0
# 2252 2025-03-04 20:00:00+00:00           3.851                  78.0
# 2253 2025-03-04 21:00:00+00:00           3.851                  78.0
# 2254 2025-03-04 22:00:00+00:00           3.801                  77.0
# 2255 2025-03-04 23:00:00+00:00           3.601                  77.0
#
#       dew_point_2m  apparent_temperature  precipitation_probability  \
# 0              NaN                   NaN                        0.0
# 1              NaN                   NaN                        0.0
# 2              NaN                   NaN                        0.0
# 3              NaN                   NaN                        0.0
# 4              NaN                   NaN                        0.0
# ...            ...                   ...                        ...
# 2251      0.413919              0.653152                        0.0
# 2252      0.365321              0.669709                        0.0
# 2253      0.365321              0.667237                        0.0
# 2254      0.138458              0.581690                        0.0
# 2255     -0.055653              0.499769                        0.0
#
#       precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0               NaN   NaN      NaN       NaN  ...               NaN
# 1               NaN   NaN      NaN       NaN  ...               NaN
# 2               NaN   NaN      NaN       NaN  ...               NaN
# 3               NaN   NaN      NaN       NaN  ...               NaN
# 4               NaN   NaN      NaN       NaN  ...               NaN
# ...             ...   ...      ...       ...  ...               ...
# 2251            0.0   0.0      0.0       0.0  ...             3.001
# 2252            0.0   0.0      0.0       0.0  ...             3.001
# 2253            0.0   0.0      0.0       0.0  ...             2.901
# 2254            0.0   0.0      0.0       0.0  ...             2.801
# 2255            0.0   0.0      0.0       0.0  ...             2.901
#
#       soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2251                 3.201                 4.901                  6.051
# 2252                 3.051                 4.601                  5.951
# 2253                 3.001                 4.401                  5.851
# 2254                 2.901                 4.251                  5.751
# 2255                 2.451                 4.101                  5.651
#
#       soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 2251                  6.151                   0.317                   0.320
# 2252                  6.151                   0.318                   0.320
# 2253                  6.201                   0.318                   0.320
# 2254                  6.201                   0.318                   0.321
# 2255                  6.201                   0.318                   0.321
#
#       soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2251                   0.328                    0.342
# 2252                   0.327                    0.342
# 2253                   0.327                    0.342
# 2254                   0.327                    0.342
# 2255                   0.327                    0.342
#
#       soil_moisture_27_to_81cm
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2251                     0.371
# 2252                     0.371
# 2253                     0.371
# 2254                     0.371
# 2255                     0.371
#
# [2256 rows x 43 columns]

# %%
df15["Country"] = "Istanbul"

# %%
df = pd.concat([df, df15])

# %%
df.shape
# Out:
# (33840, 44)

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": 1.36,
	"longitude": 103.8,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth", "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", "soil_moisture_27_to_81cm"],
	"start_date": "2024-12-01",
	"end_date": "2025-03-04"
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_showers = hourly.Variables(7).ValuesAsNumpy()
hourly_snowfall = hourly.Variables(8).ValuesAsNumpy()
hourly_snow_depth = hourly.Variables(9).ValuesAsNumpy()
hourly_weather_code = hourly.Variables(10).ValuesAsNumpy()
hourly_pressure_msl = hourly.Variables(11).ValuesAsNumpy()
hourly_surface_pressure = hourly.Variables(12).ValuesAsNumpy()
hourly_cloud_cover = hourly.Variables(13).ValuesAsNumpy()
hourly_cloud_cover_low = hourly.Variables(14).ValuesAsNumpy()
hourly_cloud_cover_mid = hourly.Variables(15).ValuesAsNumpy()
hourly_cloud_cover_high = hourly.Variables(16).ValuesAsNumpy()
hourly_visibility = hourly.Variables(17).ValuesAsNumpy()
hourly_evapotranspiration = hourly.Variables(18).ValuesAsNumpy()
hourly_et0_fao_evapotranspiration = hourly.Variables(19).ValuesAsNumpy()
hourly_vapour_pressure_deficit = hourly.Variables(20).ValuesAsNumpy()
hourly_wind_speed_10m = hourly.Variables(21).ValuesAsNumpy()
hourly_wind_speed_80m = hourly.Variables(22).ValuesAsNumpy()
hourly_wind_speed_120m = hourly.Variables(23).ValuesAsNumpy()
hourly_wind_speed_180m = hourly.Variables(24).ValuesAsNumpy()
hourly_wind_direction_10m = hourly.Variables(25).ValuesAsNumpy()
hourly_wind_direction_80m = hourly.Variables(26).ValuesAsNumpy()
hourly_wind_direction_120m = hourly.Variables(27).ValuesAsNumpy()
hourly_wind_direction_180m = hourly.Variables(28).ValuesAsNumpy()
hourly_wind_gusts_10m = hourly.Variables(29).ValuesAsNumpy()
hourly_temperature_80m = hourly.Variables(30).ValuesAsNumpy()
hourly_temperature_120m = hourly.Variables(31).ValuesAsNumpy()
hourly_temperature_180m = hourly.Variables(32).ValuesAsNumpy()
hourly_soil_temperature_0cm = hourly.Variables(33).ValuesAsNumpy()
hourly_soil_temperature_6cm = hourly.Variables(34).ValuesAsNumpy()
hourly_soil_temperature_18cm = hourly.Variables(35).ValuesAsNumpy()
hourly_soil_temperature_54cm = hourly.Variables(36).ValuesAsNumpy()
hourly_soil_moisture_0_to_1cm = hourly.Variables(37).ValuesAsNumpy()
hourly_soil_moisture_1_to_3cm = hourly.Variables(38).ValuesAsNumpy()
hourly_soil_moisture_3_to_9cm = hourly.Variables(39).ValuesAsNumpy()
hourly_soil_moisture_9_to_27cm = hourly.Variables(40).ValuesAsNumpy()
hourly_soil_moisture_27_to_81cm = hourly.Variables(41).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["showers"] = hourly_showers
hourly_data["snowfall"] = hourly_snowfall
hourly_data["snow_depth"] = hourly_snow_depth
hourly_data["weather_code"] = hourly_weather_code
hourly_data["pressure_msl"] = hourly_pressure_msl
hourly_data["surface_pressure"] = hourly_surface_pressure
hourly_data["cloud_cover"] = hourly_cloud_cover
hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
hourly_data["visibility"] = hourly_visibility
hourly_data["evapotranspiration"] = hourly_evapotranspiration
hourly_data["et0_fao_evapotranspiration"] = hourly_et0_fao_evapotranspiration
hourly_data["vapour_pressure_deficit"] = hourly_vapour_pressure_deficit
hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
hourly_data["wind_speed_80m"] = hourly_wind_speed_80m
hourly_data["wind_speed_120m"] = hourly_wind_speed_120m
hourly_data["wind_speed_180m"] = hourly_wind_speed_180m
hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
hourly_data["wind_direction_80m"] = hourly_wind_direction_80m
hourly_data["wind_direction_120m"] = hourly_wind_direction_120m
hourly_data["wind_direction_180m"] = hourly_wind_direction_180m
hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m
hourly_data["temperature_80m"] = hourly_temperature_80m
hourly_data["temperature_120m"] = hourly_temperature_120m
hourly_data["temperature_180m"] = hourly_temperature_180m
hourly_data["soil_temperature_0cm"] = hourly_soil_temperature_0cm
hourly_data["soil_temperature_6cm"] = hourly_soil_temperature_6cm
hourly_data["soil_temperature_18cm"] = hourly_soil_temperature_18cm
hourly_data["soil_temperature_54cm"] = hourly_soil_temperature_54cm
hourly_data["soil_moisture_0_to_1cm"] = hourly_soil_moisture_0_to_1cm
hourly_data["soil_moisture_1_to_3cm"] = hourly_soil_moisture_1_to_3cm
hourly_data["soil_moisture_3_to_9cm"] = hourly_soil_moisture_3_to_9cm
hourly_data["soil_moisture_9_to_27cm"] = hourly_soil_moisture_9_to_27cm
hourly_data["soil_moisture_27_to_81cm"] = hourly_soil_moisture_27_to_81cm

df16 = pd.DataFrame(data = hourly_data)
print(df16)
# Out:
# Coordinates 1.375°N 103.75°E
# Elevation 46.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#                           date  temperature_2m  relative_humidity_2m  \
# 0    2024-12-01 00:00:00+00:00             NaN                   NaN
# 1    2024-12-01 01:00:00+00:00             NaN                   NaN
# 2    2024-12-01 02:00:00+00:00             NaN                   NaN
# 3    2024-12-01 03:00:00+00:00             NaN                   NaN
# 4    2024-12-01 04:00:00+00:00             NaN                   NaN
# ...                        ...             ...                   ...
# 2251 2025-03-04 19:00:00+00:00       25.737499                  93.0
# 2252 2025-03-04 20:00:00+00:00       25.637499                  93.0
# 2253 2025-03-04 21:00:00+00:00       25.587500                  93.0
# 2254 2025-03-04 22:00:00+00:00       25.487499                  93.0
# 2255 2025-03-04 23:00:00+00:00       25.437500                  93.0
#
#       dew_point_2m  apparent_temperature  precipitation_probability  \
# 0              NaN                   NaN                        6.0
# 1              NaN                   NaN                       26.0
# 2              NaN                   NaN                       56.0
# 3              NaN                   NaN                       74.0
# 4              NaN                   NaN                       63.0
# ...            ...                   ...                        ...
# 2251     24.519163             31.693592                        0.0
# 2252     24.420069             31.478088                        0.0
# 2253     24.370518             31.539501                        3.0
# 2254     24.271423             31.407013                        3.0
# 2255     24.221876             31.208481                        0.0
#
#       precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0               NaN   NaN      NaN       NaN  ...               NaN
# 1               NaN   NaN      NaN       NaN  ...               NaN
# 2               NaN   NaN      NaN       NaN  ...               NaN
# 3               NaN   NaN      NaN       NaN  ...               NaN
# 4               NaN   NaN      NaN       NaN  ...               NaN
# ...             ...   ...      ...       ...  ...               ...
# 2251            0.0   0.0      0.0       0.0  ...         24.037500
# 2252            0.0   0.0      0.0       0.0  ...         24.037500
# 2253            0.0   0.0      0.0       0.0  ...         24.037500
# 2254            0.0   0.0      0.0       0.0  ...         24.137499
# 2255            0.0   0.0      0.0       0.0  ...         24.137499
#
#       soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2251             26.287500             27.037500              29.237499
# 2252             26.237499             26.887499              28.987499
# 2253             26.087500             26.737499              28.787500
# 2254             25.837500             26.537500              28.537500
# 2255             25.837500             26.387499              28.337500
#
#       soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 2251              28.887499                   0.245                   0.244
# 2252              28.887499                   0.242                   0.241
# 2253              28.887499                   0.240                   0.238
# 2254              28.887499                   0.238                   0.236
# 2255              28.887499                   0.236                   0.234
#
#       soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2251                   0.210                    0.192
# 2252                   0.210                    0.192
# 2253                   0.211                    0.192
# 2254                   0.212                    0.192
# 2255                   0.212                    0.192
#
#       soil_moisture_27_to_81cm
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2251                     0.229
# 2252                     0.229
# 2253                     0.229
# 2254                     0.229
# 2255                     0.229
#
# [2256 rows x 43 columns]

# %%
df16["Country"] = "Singapore"

# %%
df = pd.concat([df, df16])

# %%
df.shape
# Out:
# (36096, 44)

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": 37.56,
	"longitude": 126.97,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth", "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", "soil_moisture_27_to_81cm"],
	"start_date": "2024-12-01",
	"end_date": "2025-03-04"
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_showers = hourly.Variables(7).ValuesAsNumpy()
hourly_snowfall = hourly.Variables(8).ValuesAsNumpy()
hourly_snow_depth = hourly.Variables(9).ValuesAsNumpy()
hourly_weather_code = hourly.Variables(10).ValuesAsNumpy()
hourly_pressure_msl = hourly.Variables(11).ValuesAsNumpy()
hourly_surface_pressure = hourly.Variables(12).ValuesAsNumpy()
hourly_cloud_cover = hourly.Variables(13).ValuesAsNumpy()
hourly_cloud_cover_low = hourly.Variables(14).ValuesAsNumpy()
hourly_cloud_cover_mid = hourly.Variables(15).ValuesAsNumpy()
hourly_cloud_cover_high = hourly.Variables(16).ValuesAsNumpy()
hourly_visibility = hourly.Variables(17).ValuesAsNumpy()
hourly_evapotranspiration = hourly.Variables(18).ValuesAsNumpy()
hourly_et0_fao_evapotranspiration = hourly.Variables(19).ValuesAsNumpy()
hourly_vapour_pressure_deficit = hourly.Variables(20).ValuesAsNumpy()
hourly_wind_speed_10m = hourly.Variables(21).ValuesAsNumpy()
hourly_wind_speed_80m = hourly.Variables(22).ValuesAsNumpy()
hourly_wind_speed_120m = hourly.Variables(23).ValuesAsNumpy()
hourly_wind_speed_180m = hourly.Variables(24).ValuesAsNumpy()
hourly_wind_direction_10m = hourly.Variables(25).ValuesAsNumpy()
hourly_wind_direction_80m = hourly.Variables(26).ValuesAsNumpy()
hourly_wind_direction_120m = hourly.Variables(27).ValuesAsNumpy()
hourly_wind_direction_180m = hourly.Variables(28).ValuesAsNumpy()
hourly_wind_gusts_10m = hourly.Variables(29).ValuesAsNumpy()
hourly_temperature_80m = hourly.Variables(30).ValuesAsNumpy()
hourly_temperature_120m = hourly.Variables(31).ValuesAsNumpy()
hourly_temperature_180m = hourly.Variables(32).ValuesAsNumpy()
hourly_soil_temperature_0cm = hourly.Variables(33).ValuesAsNumpy()
hourly_soil_temperature_6cm = hourly.Variables(34).ValuesAsNumpy()
hourly_soil_temperature_18cm = hourly.Variables(35).ValuesAsNumpy()
hourly_soil_temperature_54cm = hourly.Variables(36).ValuesAsNumpy()
hourly_soil_moisture_0_to_1cm = hourly.Variables(37).ValuesAsNumpy()
hourly_soil_moisture_1_to_3cm = hourly.Variables(38).ValuesAsNumpy()
hourly_soil_moisture_3_to_9cm = hourly.Variables(39).ValuesAsNumpy()
hourly_soil_moisture_9_to_27cm = hourly.Variables(40).ValuesAsNumpy()
hourly_soil_moisture_27_to_81cm = hourly.Variables(41).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["showers"] = hourly_showers
hourly_data["snowfall"] = hourly_snowfall
hourly_data["snow_depth"] = hourly_snow_depth
hourly_data["weather_code"] = hourly_weather_code
hourly_data["pressure_msl"] = hourly_pressure_msl
hourly_data["surface_pressure"] = hourly_surface_pressure
hourly_data["cloud_cover"] = hourly_cloud_cover
hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
hourly_data["visibility"] = hourly_visibility
hourly_data["evapotranspiration"] = hourly_evapotranspiration
hourly_data["et0_fao_evapotranspiration"] = hourly_et0_fao_evapotranspiration
hourly_data["vapour_pressure_deficit"] = hourly_vapour_pressure_deficit
hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
hourly_data["wind_speed_80m"] = hourly_wind_speed_80m
hourly_data["wind_speed_120m"] = hourly_wind_speed_120m
hourly_data["wind_speed_180m"] = hourly_wind_speed_180m
hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
hourly_data["wind_direction_80m"] = hourly_wind_direction_80m
hourly_data["wind_direction_120m"] = hourly_wind_direction_120m
hourly_data["wind_direction_180m"] = hourly_wind_direction_180m
hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m
hourly_data["temperature_80m"] = hourly_temperature_80m
hourly_data["temperature_120m"] = hourly_temperature_120m
hourly_data["temperature_180m"] = hourly_temperature_180m
hourly_data["soil_temperature_0cm"] = hourly_soil_temperature_0cm
hourly_data["soil_temperature_6cm"] = hourly_soil_temperature_6cm
hourly_data["soil_temperature_18cm"] = hourly_soil_temperature_18cm
hourly_data["soil_temperature_54cm"] = hourly_soil_temperature_54cm
hourly_data["soil_moisture_0_to_1cm"] = hourly_soil_moisture_0_to_1cm
hourly_data["soil_moisture_1_to_3cm"] = hourly_soil_moisture_1_to_3cm
hourly_data["soil_moisture_3_to_9cm"] = hourly_soil_moisture_3_to_9cm
hourly_data["soil_moisture_9_to_27cm"] = hourly_soil_moisture_9_to_27cm
hourly_data["soil_moisture_27_to_81cm"] = hourly_soil_moisture_27_to_81cm

df17 = pd.DataFrame(data = hourly_data)
print(df17)
# Out:
# Coordinates 37.54999923706055°N 127.0°E
# Elevation 33.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#                           date  temperature_2m  relative_humidity_2m  \
# 0    2024-12-01 00:00:00+00:00             NaN                   NaN
# 1    2024-12-01 01:00:00+00:00             NaN                   NaN
# 2    2024-12-01 02:00:00+00:00             NaN                   NaN
# 3    2024-12-01 03:00:00+00:00             NaN                   NaN
# 4    2024-12-01 04:00:00+00:00             NaN                   NaN
# ...                        ...             ...                   ...
# 2251 2025-03-04 19:00:00+00:00            1.10                  74.0
# 2252 2025-03-04 20:00:00+00:00            1.10                  73.0
# 2253 2025-03-04 21:00:00+00:00            1.10                  72.0
# 2254 2025-03-04 22:00:00+00:00            0.95                  71.0
# 2255 2025-03-04 23:00:00+00:00            1.05                  70.0
#
#       dew_point_2m  apparent_temperature  precipitation_probability  \
# 0              NaN                   NaN                        0.0
# 1              NaN                   NaN                        0.0
# 2              NaN                   NaN                        0.0
# 3              NaN                   NaN                        0.0
# 4              NaN                   NaN                        0.0
# ...            ...                   ...                        ...
# 2251     -3.019070             -2.294200                        0.0
# 2252     -3.201914             -2.417125                        0.0
# 2253     -3.386995             -2.428408                        0.0
# 2254     -3.718688             -2.545293                        5.0
# 2255     -3.812140             -2.382968                        3.0
#
#       precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0               NaN   NaN      NaN       NaN  ...               NaN
# 1               NaN   NaN      NaN       NaN  ...               NaN
# 2               NaN   NaN      NaN       NaN  ...               NaN
# 3               NaN   NaN      NaN       NaN  ...               NaN
# 4               NaN   NaN      NaN       NaN  ...               NaN
# ...             ...   ...      ...       ...  ...               ...
# 2251            0.0   0.0      0.0       0.0  ...             0.295
# 2252            0.0   0.0      0.0       0.0  ...             0.295
# 2253            0.0   0.0      0.0       0.0  ...             0.295
# 2254            0.0   0.0      0.0       0.0  ...             0.195
# 2255            0.0   0.0      0.0       0.0  ...             0.295
#
#       soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2251                 0.695                 1.245                  2.245
# 2252                 0.645                 1.145                  2.195
# 2253                 0.395                 1.045                  2.195
# 2254                 0.395                 0.945                  2.095
# 2255                 0.745                 0.895                  2.045
#
#       soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 2251                  3.445                   0.366                   0.369
# 2252                  3.445                   0.365                   0.367
# 2253                  3.445                   0.364                   0.366
# 2254                  3.445                   0.363                   0.365
# 2255                  3.445                   0.362                   0.365
#
#       soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2251                   0.374                    0.374
# 2252                   0.373                    0.374
# 2253                   0.371                    0.374
# 2254                   0.370                    0.374
# 2255                   0.369                    0.373
#
#       soil_moisture_27_to_81cm
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2251                     0.340
# 2252                     0.340
# 2253                     0.341
# 2254                     0.341
# 2255                     0.341
#
# [2256 rows x 43 columns]

# %%
df17["Country"] = "Seoul"

# %%
df = pd.concat([df, df17])

# %%
df.shape
# Out:
# (38352, 44)

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": 25.06,
	"longitude": 55.17,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth", "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", "soil_moisture_27_to_81cm"],
	"start_date": "2024-12-01",
	"end_date": "2025-03-04"
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_showers = hourly.Variables(7).ValuesAsNumpy()
hourly_snowfall = hourly.Variables(8).ValuesAsNumpy()
hourly_snow_depth = hourly.Variables(9).ValuesAsNumpy()
hourly_weather_code = hourly.Variables(10).ValuesAsNumpy()
hourly_pressure_msl = hourly.Variables(11).ValuesAsNumpy()
hourly_surface_pressure = hourly.Variables(12).ValuesAsNumpy()
hourly_cloud_cover = hourly.Variables(13).ValuesAsNumpy()
hourly_cloud_cover_low = hourly.Variables(14).ValuesAsNumpy()
hourly_cloud_cover_mid = hourly.Variables(15).ValuesAsNumpy()
hourly_cloud_cover_high = hourly.Variables(16).ValuesAsNumpy()
hourly_visibility = hourly.Variables(17).ValuesAsNumpy()
hourly_evapotranspiration = hourly.Variables(18).ValuesAsNumpy()
hourly_et0_fao_evapotranspiration = hourly.Variables(19).ValuesAsNumpy()
hourly_vapour_pressure_deficit = hourly.Variables(20).ValuesAsNumpy()
hourly_wind_speed_10m = hourly.Variables(21).ValuesAsNumpy()
hourly_wind_speed_80m = hourly.Variables(22).ValuesAsNumpy()
hourly_wind_speed_120m = hourly.Variables(23).ValuesAsNumpy()
hourly_wind_speed_180m = hourly.Variables(24).ValuesAsNumpy()
hourly_wind_direction_10m = hourly.Variables(25).ValuesAsNumpy()
hourly_wind_direction_80m = hourly.Variables(26).ValuesAsNumpy()
hourly_wind_direction_120m = hourly.Variables(27).ValuesAsNumpy()
hourly_wind_direction_180m = hourly.Variables(28).ValuesAsNumpy()
hourly_wind_gusts_10m = hourly.Variables(29).ValuesAsNumpy()
hourly_temperature_80m = hourly.Variables(30).ValuesAsNumpy()
hourly_temperature_120m = hourly.Variables(31).ValuesAsNumpy()
hourly_temperature_180m = hourly.Variables(32).ValuesAsNumpy()
hourly_soil_temperature_0cm = hourly.Variables(33).ValuesAsNumpy()
hourly_soil_temperature_6cm = hourly.Variables(34).ValuesAsNumpy()
hourly_soil_temperature_18cm = hourly.Variables(35).ValuesAsNumpy()
hourly_soil_temperature_54cm = hourly.Variables(36).ValuesAsNumpy()
hourly_soil_moisture_0_to_1cm = hourly.Variables(37).ValuesAsNumpy()
hourly_soil_moisture_1_to_3cm = hourly.Variables(38).ValuesAsNumpy()
hourly_soil_moisture_3_to_9cm = hourly.Variables(39).ValuesAsNumpy()
hourly_soil_moisture_9_to_27cm = hourly.Variables(40).ValuesAsNumpy()
hourly_soil_moisture_27_to_81cm = hourly.Variables(41).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["showers"] = hourly_showers
hourly_data["snowfall"] = hourly_snowfall
hourly_data["snow_depth"] = hourly_snow_depth
hourly_data["weather_code"] = hourly_weather_code
hourly_data["pressure_msl"] = hourly_pressure_msl
hourly_data["surface_pressure"] = hourly_surface_pressure
hourly_data["cloud_cover"] = hourly_cloud_cover
hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
hourly_data["visibility"] = hourly_visibility
hourly_data["evapotranspiration"] = hourly_evapotranspiration
hourly_data["et0_fao_evapotranspiration"] = hourly_et0_fao_evapotranspiration
hourly_data["vapour_pressure_deficit"] = hourly_vapour_pressure_deficit
hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
hourly_data["wind_speed_80m"] = hourly_wind_speed_80m
hourly_data["wind_speed_120m"] = hourly_wind_speed_120m
hourly_data["wind_speed_180m"] = hourly_wind_speed_180m
hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
hourly_data["wind_direction_80m"] = hourly_wind_direction_80m
hourly_data["wind_direction_120m"] = hourly_wind_direction_120m
hourly_data["wind_direction_180m"] = hourly_wind_direction_180m
hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m
hourly_data["temperature_80m"] = hourly_temperature_80m
hourly_data["temperature_120m"] = hourly_temperature_120m
hourly_data["temperature_180m"] = hourly_temperature_180m
hourly_data["soil_temperature_0cm"] = hourly_soil_temperature_0cm
hourly_data["soil_temperature_6cm"] = hourly_soil_temperature_6cm
hourly_data["soil_temperature_18cm"] = hourly_soil_temperature_18cm
hourly_data["soil_temperature_54cm"] = hourly_soil_temperature_54cm
hourly_data["soil_moisture_0_to_1cm"] = hourly_soil_moisture_0_to_1cm
hourly_data["soil_moisture_1_to_3cm"] = hourly_soil_moisture_1_to_3cm
hourly_data["soil_moisture_3_to_9cm"] = hourly_soil_moisture_3_to_9cm
hourly_data["soil_moisture_9_to_27cm"] = hourly_soil_moisture_9_to_27cm
hourly_data["soil_moisture_27_to_81cm"] = hourly_soil_moisture_27_to_81cm

df18 = pd.DataFrame(data = hourly_data)
print(df18)
# Out:
# Coordinates 25.0°N 55.125°E
# Elevation 8.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#                           date  temperature_2m  relative_humidity_2m  \
# 0    2024-12-01 00:00:00+00:00             NaN                   NaN
# 1    2024-12-01 01:00:00+00:00             NaN                   NaN
# 2    2024-12-01 02:00:00+00:00             NaN                   NaN
# 3    2024-12-01 03:00:00+00:00             NaN                   NaN
# 4    2024-12-01 04:00:00+00:00             NaN                   NaN
# ...                        ...             ...                   ...
# 2251 2025-03-04 19:00:00+00:00       22.093500                  65.0
# 2252 2025-03-04 20:00:00+00:00       21.743500                  67.0
# 2253 2025-03-04 21:00:00+00:00       21.393499                  67.0
# 2254 2025-03-04 22:00:00+00:00       21.043499                  68.0
# 2255 2025-03-04 23:00:00+00:00       20.793499                  68.0
#
#       dew_point_2m  apparent_temperature  precipitation_probability  \
# 0              NaN                   NaN                        0.0
# 1              NaN                   NaN                        0.0
# 2              NaN                   NaN                        0.0
# 3              NaN                   NaN                        0.0
# 4              NaN                   NaN                        0.0
# ...            ...                   ...                        ...
# 2251     15.207730             20.701765                        0.0
# 2252     15.347136             20.512634                        0.0
# 2253     15.013830             20.074892                        0.0
# 2254     14.910429             19.741594                        0.0
# 2255     14.671900             19.537415                        0.0
#
#       precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0               NaN   NaN      NaN       NaN  ...               NaN
# 1               NaN   NaN      NaN       NaN  ...               NaN
# 2               NaN   NaN      NaN       NaN  ...               NaN
# 3               NaN   NaN      NaN       NaN  ...               NaN
# 4               NaN   NaN      NaN       NaN  ...               NaN
# ...             ...   ...      ...       ...  ...               ...
# 2251            0.0   0.0      0.0       0.0  ...         20.393499
# 2252            0.0   0.0      0.0       0.0  ...         20.193501
# 2253            0.0   0.0      0.0       0.0  ...         20.193501
# 2254            0.0   0.0      0.0       0.0  ...         20.193501
# 2255            0.0   0.0      0.0       0.0  ...         20.293499
#
#       soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2251             21.393499             24.193501              27.393499
# 2252             21.093500             23.543499              26.743500
# 2253             20.843500             22.993500              26.193501
# 2254             20.643499             22.493500              25.693501
# 2255             20.593500             22.093500              25.193501
#
#       soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 2251              26.243500                   0.021                   0.037
# 2252              26.293499                   0.022                   0.037
# 2253              26.293499                   0.022                   0.037
# 2254              26.293499                   0.023                   0.037
# 2255              26.293499                   0.023                   0.037
#
#       soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2251                   0.064                    0.101
# 2252                   0.064                    0.101
# 2253                   0.064                    0.101
# 2254                   0.064                    0.101
# 2255                   0.064                    0.101
#
#       soil_moisture_27_to_81cm
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2251                     0.137
# 2252                     0.137
# 2253                     0.137
# 2254                     0.137
# 2255                     0.137
#
# [2256 rows x 43 columns]

# %%
df18["Country"] = "Dubai"

# %%
df = pd.concat([df, df18])

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": 34.05,
	"longitude": -118.24,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth", "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", "soil_moisture_27_to_81cm"],
	"start_date": "2024-12-01",
	"end_date": "2025-03-04"
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_showers = hourly.Variables(7).ValuesAsNumpy()
hourly_snowfall = hourly.Variables(8).ValuesAsNumpy()
hourly_snow_depth = hourly.Variables(9).ValuesAsNumpy()
hourly_weather_code = hourly.Variables(10).ValuesAsNumpy()
hourly_pressure_msl = hourly.Variables(11).ValuesAsNumpy()
hourly_surface_pressure = hourly.Variables(12).ValuesAsNumpy()
hourly_cloud_cover = hourly.Variables(13).ValuesAsNumpy()
hourly_cloud_cover_low = hourly.Variables(14).ValuesAsNumpy()
hourly_cloud_cover_mid = hourly.Variables(15).ValuesAsNumpy()
hourly_cloud_cover_high = hourly.Variables(16).ValuesAsNumpy()
hourly_visibility = hourly.Variables(17).ValuesAsNumpy()
hourly_evapotranspiration = hourly.Variables(18).ValuesAsNumpy()
hourly_et0_fao_evapotranspiration = hourly.Variables(19).ValuesAsNumpy()
hourly_vapour_pressure_deficit = hourly.Variables(20).ValuesAsNumpy()
hourly_wind_speed_10m = hourly.Variables(21).ValuesAsNumpy()
hourly_wind_speed_80m = hourly.Variables(22).ValuesAsNumpy()
hourly_wind_speed_120m = hourly.Variables(23).ValuesAsNumpy()
hourly_wind_speed_180m = hourly.Variables(24).ValuesAsNumpy()
hourly_wind_direction_10m = hourly.Variables(25).ValuesAsNumpy()
hourly_wind_direction_80m = hourly.Variables(26).ValuesAsNumpy()
hourly_wind_direction_120m = hourly.Variables(27).ValuesAsNumpy()
hourly_wind_direction_180m = hourly.Variables(28).ValuesAsNumpy()
hourly_wind_gusts_10m = hourly.Variables(29).ValuesAsNumpy()
hourly_temperature_80m = hourly.Variables(30).ValuesAsNumpy()
hourly_temperature_120m = hourly.Variables(31).ValuesAsNumpy()
hourly_temperature_180m = hourly.Variables(32).ValuesAsNumpy()
hourly_soil_temperature_0cm = hourly.Variables(33).ValuesAsNumpy()
hourly_soil_temperature_6cm = hourly.Variables(34).ValuesAsNumpy()
hourly_soil_temperature_18cm = hourly.Variables(35).ValuesAsNumpy()
hourly_soil_temperature_54cm = hourly.Variables(36).ValuesAsNumpy()
hourly_soil_moisture_0_to_1cm = hourly.Variables(37).ValuesAsNumpy()
hourly_soil_moisture_1_to_3cm = hourly.Variables(38).ValuesAsNumpy()
hourly_soil_moisture_3_to_9cm = hourly.Variables(39).ValuesAsNumpy()
hourly_soil_moisture_9_to_27cm = hourly.Variables(40).ValuesAsNumpy()
hourly_soil_moisture_27_to_81cm = hourly.Variables(41).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["showers"] = hourly_showers
hourly_data["snowfall"] = hourly_snowfall
hourly_data["snow_depth"] = hourly_snow_depth
hourly_data["weather_code"] = hourly_weather_code
hourly_data["pressure_msl"] = hourly_pressure_msl
hourly_data["surface_pressure"] = hourly_surface_pressure
hourly_data["cloud_cover"] = hourly_cloud_cover
hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
hourly_data["visibility"] = hourly_visibility
hourly_data["evapotranspiration"] = hourly_evapotranspiration
hourly_data["et0_fao_evapotranspiration"] = hourly_et0_fao_evapotranspiration
hourly_data["vapour_pressure_deficit"] = hourly_vapour_pressure_deficit
hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
hourly_data["wind_speed_80m"] = hourly_wind_speed_80m
hourly_data["wind_speed_120m"] = hourly_wind_speed_120m
hourly_data["wind_speed_180m"] = hourly_wind_speed_180m
hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
hourly_data["wind_direction_80m"] = hourly_wind_direction_80m
hourly_data["wind_direction_120m"] = hourly_wind_direction_120m
hourly_data["wind_direction_180m"] = hourly_wind_direction_180m
hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m
hourly_data["temperature_80m"] = hourly_temperature_80m
hourly_data["temperature_120m"] = hourly_temperature_120m
hourly_data["temperature_180m"] = hourly_temperature_180m
hourly_data["soil_temperature_0cm"] = hourly_soil_temperature_0cm
hourly_data["soil_temperature_6cm"] = hourly_soil_temperature_6cm
hourly_data["soil_temperature_18cm"] = hourly_soil_temperature_18cm
hourly_data["soil_temperature_54cm"] = hourly_soil_temperature_54cm
hourly_data["soil_moisture_0_to_1cm"] = hourly_soil_moisture_0_to_1cm
hourly_data["soil_moisture_1_to_3cm"] = hourly_soil_moisture_1_to_3cm
hourly_data["soil_moisture_3_to_9cm"] = hourly_soil_moisture_3_to_9cm
hourly_data["soil_moisture_9_to_27cm"] = hourly_soil_moisture_9_to_27cm
hourly_data["soil_moisture_27_to_81cm"] = hourly_soil_moisture_27_to_81cm

df19 = pd.DataFrame(data = hourly_data)
print(df19)
# Out:
# Coordinates 34.06025695800781°N -118.23432922363281°E
# Elevation 87.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#                           date  temperature_2m  relative_humidity_2m  \
# 0    2024-12-01 00:00:00+00:00             NaN                   NaN
# 1    2024-12-01 01:00:00+00:00             NaN                   NaN
# 2    2024-12-01 02:00:00+00:00             NaN                   NaN
# 3    2024-12-01 03:00:00+00:00             NaN                   NaN
# 4    2024-12-01 04:00:00+00:00             NaN                   NaN
# ...                        ...             ...                   ...
# 2251 2025-03-04 19:00:00+00:00       15.186501                  61.0
# 2252 2025-03-04 20:00:00+00:00       16.886499                  52.0
# 2253 2025-03-04 21:00:00+00:00       18.386499                  45.0
# 2254 2025-03-04 22:00:00+00:00       19.736500                  39.0
# 2255 2025-03-04 23:00:00+00:00       19.386499                  46.0
#
#       dew_point_2m  apparent_temperature  precipitation_probability  \
# 0              NaN                   NaN                        0.0
# 1              NaN                   NaN                        0.0
# 2              NaN                   NaN                        0.0
# 3              NaN                   NaN                        0.0
# 4              NaN                   NaN                        0.0
# ...            ...                   ...                        ...
# 2251      7.714614             14.539995                        0.0
# 2252      6.966231             17.290594                        0.0
# 2253      6.238449             18.400654                        0.0
# 2254      5.386623             18.960335                        0.0
# 2255      7.469091             17.189531                        1.0
#
#       precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0               NaN   NaN      NaN       NaN  ...               NaN
# 1               NaN   NaN      NaN       NaN  ...               NaN
# 2               NaN   NaN      NaN       NaN  ...               NaN
# 3               NaN   NaN      NaN       NaN  ...               NaN
# 4               NaN   NaN      NaN       NaN  ...               NaN
# ...             ...   ...      ...       ...  ...               ...
# 2251            0.0   0.0      0.0       0.0  ...         12.033501
# 2252            0.0   0.0      0.0       0.0  ...         13.433500
# 2253            0.0   0.0      0.0       0.0  ...         14.333500
# 2254            0.0   0.0      0.0       0.0  ...         14.333500
# 2255            0.0   0.0      0.0       0.0  ...         13.233500
#
#       soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2251             24.883499             18.433500              13.533501
# 2252             25.783499             19.883499              14.083500
# 2253             27.133499             21.483500              14.733500
# 2254             25.233500             22.083500              15.383499
# 2255             21.933500             21.483500              15.933500
#
#       soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 2251              15.033501                   0.221                   0.225
# 2252              15.033501                   0.219                   0.224
# 2253              15.033501                   0.218                   0.223
# 2254              15.033501                   0.216                   0.222
# 2255              15.033501                   0.215                   0.221
#
#       soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2251                   0.231                    0.247
# 2252                   0.231                    0.246
# 2253                   0.231                    0.246
# 2254                   0.230                    0.246
# 2255                   0.230                    0.246
#
#       soil_moisture_27_to_81cm
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2251                     0.271
# 2252                     0.271
# 2253                     0.271
# 2254                     0.271
# 2255                     0.271
#
# [2256 rows x 43 columns]

# %%
df19["Country"] = "Los Angeles"

# %%
df = pd.concat([df, df19])

# %%
df.shape
# Out:
# (42864, 44)

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": -22.90,
	"longitude": -43.17,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth", "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", "soil_moisture_27_to_81cm"],
	"start_date": "2024-12-01",
	"end_date": "2025-03-04"
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_showers = hourly.Variables(7).ValuesAsNumpy()
hourly_snowfall = hourly.Variables(8).ValuesAsNumpy()
hourly_snow_depth = hourly.Variables(9).ValuesAsNumpy()
hourly_weather_code = hourly.Variables(10).ValuesAsNumpy()
hourly_pressure_msl = hourly.Variables(11).ValuesAsNumpy()
hourly_surface_pressure = hourly.Variables(12).ValuesAsNumpy()
hourly_cloud_cover = hourly.Variables(13).ValuesAsNumpy()
hourly_cloud_cover_low = hourly.Variables(14).ValuesAsNumpy()
hourly_cloud_cover_mid = hourly.Variables(15).ValuesAsNumpy()
hourly_cloud_cover_high = hourly.Variables(16).ValuesAsNumpy()
hourly_visibility = hourly.Variables(17).ValuesAsNumpy()
hourly_evapotranspiration = hourly.Variables(18).ValuesAsNumpy()
hourly_et0_fao_evapotranspiration = hourly.Variables(19).ValuesAsNumpy()
hourly_vapour_pressure_deficit = hourly.Variables(20).ValuesAsNumpy()
hourly_wind_speed_10m = hourly.Variables(21).ValuesAsNumpy()
hourly_wind_speed_80m = hourly.Variables(22).ValuesAsNumpy()
hourly_wind_speed_120m = hourly.Variables(23).ValuesAsNumpy()
hourly_wind_speed_180m = hourly.Variables(24).ValuesAsNumpy()
hourly_wind_direction_10m = hourly.Variables(25).ValuesAsNumpy()
hourly_wind_direction_80m = hourly.Variables(26).ValuesAsNumpy()
hourly_wind_direction_120m = hourly.Variables(27).ValuesAsNumpy()
hourly_wind_direction_180m = hourly.Variables(28).ValuesAsNumpy()
hourly_wind_gusts_10m = hourly.Variables(29).ValuesAsNumpy()
hourly_temperature_80m = hourly.Variables(30).ValuesAsNumpy()
hourly_temperature_120m = hourly.Variables(31).ValuesAsNumpy()
hourly_temperature_180m = hourly.Variables(32).ValuesAsNumpy()
hourly_soil_temperature_0cm = hourly.Variables(33).ValuesAsNumpy()
hourly_soil_temperature_6cm = hourly.Variables(34).ValuesAsNumpy()
hourly_soil_temperature_18cm = hourly.Variables(35).ValuesAsNumpy()
hourly_soil_temperature_54cm = hourly.Variables(36).ValuesAsNumpy()
hourly_soil_moisture_0_to_1cm = hourly.Variables(37).ValuesAsNumpy()
hourly_soil_moisture_1_to_3cm = hourly.Variables(38).ValuesAsNumpy()
hourly_soil_moisture_3_to_9cm = hourly.Variables(39).ValuesAsNumpy()
hourly_soil_moisture_9_to_27cm = hourly.Variables(40).ValuesAsNumpy()
hourly_soil_moisture_27_to_81cm = hourly.Variables(41).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["showers"] = hourly_showers
hourly_data["snowfall"] = hourly_snowfall
hourly_data["snow_depth"] = hourly_snow_depth
hourly_data["weather_code"] = hourly_weather_code
hourly_data["pressure_msl"] = hourly_pressure_msl
hourly_data["surface_pressure"] = hourly_surface_pressure
hourly_data["cloud_cover"] = hourly_cloud_cover
hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
hourly_data["visibility"] = hourly_visibility
hourly_data["evapotranspiration"] = hourly_evapotranspiration
hourly_data["et0_fao_evapotranspiration"] = hourly_et0_fao_evapotranspiration
hourly_data["vapour_pressure_deficit"] = hourly_vapour_pressure_deficit
hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
hourly_data["wind_speed_80m"] = hourly_wind_speed_80m
hourly_data["wind_speed_120m"] = hourly_wind_speed_120m
hourly_data["wind_speed_180m"] = hourly_wind_speed_180m
hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
hourly_data["wind_direction_80m"] = hourly_wind_direction_80m
hourly_data["wind_direction_120m"] = hourly_wind_direction_120m
hourly_data["wind_direction_180m"] = hourly_wind_direction_180m
hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m
hourly_data["temperature_80m"] = hourly_temperature_80m
hourly_data["temperature_120m"] = hourly_temperature_120m
hourly_data["temperature_180m"] = hourly_temperature_180m
hourly_data["soil_temperature_0cm"] = hourly_soil_temperature_0cm
hourly_data["soil_temperature_6cm"] = hourly_soil_temperature_6cm
hourly_data["soil_temperature_18cm"] = hourly_soil_temperature_18cm
hourly_data["soil_temperature_54cm"] = hourly_soil_temperature_54cm
hourly_data["soil_moisture_0_to_1cm"] = hourly_soil_moisture_0_to_1cm
hourly_data["soil_moisture_1_to_3cm"] = hourly_soil_moisture_1_to_3cm
hourly_data["soil_moisture_3_to_9cm"] = hourly_soil_moisture_3_to_9cm
hourly_data["soil_moisture_9_to_27cm"] = hourly_soil_moisture_9_to_27cm
hourly_data["soil_moisture_27_to_81cm"] = hourly_soil_moisture_27_to_81cm

df20 = pd.DataFrame(data = hourly_data)
print(df20)
# Out:
# Coordinates -22.75°N -43.0°E
# Elevation 0.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#                           date  temperature_2m  relative_humidity_2m  \
# 0    2024-12-01 00:00:00+00:00             NaN                   NaN
# 1    2024-12-01 01:00:00+00:00             NaN                   NaN
# 2    2024-12-01 02:00:00+00:00             NaN                   NaN
# 3    2024-12-01 03:00:00+00:00             NaN                   NaN
# 4    2024-12-01 04:00:00+00:00             NaN                   NaN
# ...                        ...             ...                   ...
# 2251 2025-03-04 19:00:00+00:00       32.953999                  44.0
# 2252 2025-03-04 20:00:00+00:00       32.104000                  44.0
# 2253 2025-03-04 21:00:00+00:00       30.304001                  49.0
# 2254 2025-03-04 22:00:00+00:00       28.454000                  59.0
# 2255 2025-03-04 23:00:00+00:00       27.354000                  67.0
#
#       dew_point_2m  apparent_temperature  precipitation_probability  \
# 0              NaN                   NaN                       29.0
# 1              NaN                   NaN                       19.0
# 2              NaN                   NaN                       14.0
# 3              NaN                   NaN                       10.0
# 4              NaN                   NaN                        7.0
# ...            ...                   ...                        ...
# 2251     19.088369             34.409801                        3.0
# 2252     18.321514             33.041039                        0.0
# 2253     18.403032             31.337784                        0.0
# 2254     19.668642             30.360699                        0.0
# 2255     20.687115             30.040771                        0.0
#
#       precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0               NaN   NaN      NaN       NaN  ...               NaN
# 1               NaN   NaN      NaN       NaN  ...               NaN
# 2               NaN   NaN      NaN       NaN  ...               NaN
# 3               NaN   NaN      NaN       NaN  ...               NaN
# 4               NaN   NaN      NaN       NaN  ...               NaN
# ...             ...   ...      ...       ...  ...               ...
# 2251            0.0   0.0      0.0       0.0  ...         29.604000
# 2252            0.0   0.0      0.0       0.0  ...         29.204000
# 2253            0.0   0.0      0.0       0.0  ...         27.804001
# 2254            0.0   0.0      0.0       0.0  ...         26.004000
# 2255            0.0   0.0      0.0       0.0  ...         25.104000
#
#       soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2251             33.004002             34.754002              31.104000
# 2252             31.054001             34.104000              31.304001
# 2253             29.004000             33.004002              31.454000
# 2254             28.004000             31.754000              31.454000
# 2255             27.454000             30.754000              31.403999
#
#       soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 2251              30.153999                   0.106                   0.164
# 2252              30.153999                   0.109                   0.163
# 2253              30.204000                   0.108                   0.163
# 2254              30.204000                   0.107                   0.163
# 2255              30.204000                   0.107                   0.163
#
#       soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2251                   0.209                    0.276
# 2252                   0.209                    0.275
# 2253                   0.209                    0.275
# 2254                   0.209                    0.275
# 2255                   0.209                    0.275
#
#       soil_moisture_27_to_81cm
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2251                     0.348
# 2252                     0.348
# 2253                     0.348
# 2254                     0.348
# 2255                     0.348
#
# [2256 rows x 43 columns]

# %%
df20["Country"] = "Rio De Janeiro"

# %%
df = pd.concat([df, df20])

# %%
df.shape
# Out:
# (45120, 44)

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": -12.04,
	"longitude": -77.04,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth", "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", "soil_moisture_27_to_81cm"],
	"start_date": "2024-12-01",
	"end_date": "2025-03-04"
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_showers = hourly.Variables(7).ValuesAsNumpy()
hourly_snowfall = hourly.Variables(8).ValuesAsNumpy()
hourly_snow_depth = hourly.Variables(9).ValuesAsNumpy()
hourly_weather_code = hourly.Variables(10).ValuesAsNumpy()
hourly_pressure_msl = hourly.Variables(11).ValuesAsNumpy()
hourly_surface_pressure = hourly.Variables(12).ValuesAsNumpy()
hourly_cloud_cover = hourly.Variables(13).ValuesAsNumpy()
hourly_cloud_cover_low = hourly.Variables(14).ValuesAsNumpy()
hourly_cloud_cover_mid = hourly.Variables(15).ValuesAsNumpy()
hourly_cloud_cover_high = hourly.Variables(16).ValuesAsNumpy()
hourly_visibility = hourly.Variables(17).ValuesAsNumpy()
hourly_evapotranspiration = hourly.Variables(18).ValuesAsNumpy()
hourly_et0_fao_evapotranspiration = hourly.Variables(19).ValuesAsNumpy()
hourly_vapour_pressure_deficit = hourly.Variables(20).ValuesAsNumpy()
hourly_wind_speed_10m = hourly.Variables(21).ValuesAsNumpy()
hourly_wind_speed_80m = hourly.Variables(22).ValuesAsNumpy()
hourly_wind_speed_120m = hourly.Variables(23).ValuesAsNumpy()
hourly_wind_speed_180m = hourly.Variables(24).ValuesAsNumpy()
hourly_wind_direction_10m = hourly.Variables(25).ValuesAsNumpy()
hourly_wind_direction_80m = hourly.Variables(26).ValuesAsNumpy()
hourly_wind_direction_120m = hourly.Variables(27).ValuesAsNumpy()
hourly_wind_direction_180m = hourly.Variables(28).ValuesAsNumpy()
hourly_wind_gusts_10m = hourly.Variables(29).ValuesAsNumpy()
hourly_temperature_80m = hourly.Variables(30).ValuesAsNumpy()
hourly_temperature_120m = hourly.Variables(31).ValuesAsNumpy()
hourly_temperature_180m = hourly.Variables(32).ValuesAsNumpy()
hourly_soil_temperature_0cm = hourly.Variables(33).ValuesAsNumpy()
hourly_soil_temperature_6cm = hourly.Variables(34).ValuesAsNumpy()
hourly_soil_temperature_18cm = hourly.Variables(35).ValuesAsNumpy()
hourly_soil_temperature_54cm = hourly.Variables(36).ValuesAsNumpy()
hourly_soil_moisture_0_to_1cm = hourly.Variables(37).ValuesAsNumpy()
hourly_soil_moisture_1_to_3cm = hourly.Variables(38).ValuesAsNumpy()
hourly_soil_moisture_3_to_9cm = hourly.Variables(39).ValuesAsNumpy()
hourly_soil_moisture_9_to_27cm = hourly.Variables(40).ValuesAsNumpy()
hourly_soil_moisture_27_to_81cm = hourly.Variables(41).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["showers"] = hourly_showers
hourly_data["snowfall"] = hourly_snowfall
hourly_data["snow_depth"] = hourly_snow_depth
hourly_data["weather_code"] = hourly_weather_code
hourly_data["pressure_msl"] = hourly_pressure_msl
hourly_data["surface_pressure"] = hourly_surface_pressure
hourly_data["cloud_cover"] = hourly_cloud_cover
hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
hourly_data["visibility"] = hourly_visibility
hourly_data["evapotranspiration"] = hourly_evapotranspiration
hourly_data["et0_fao_evapotranspiration"] = hourly_et0_fao_evapotranspiration
hourly_data["vapour_pressure_deficit"] = hourly_vapour_pressure_deficit
hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
hourly_data["wind_speed_80m"] = hourly_wind_speed_80m
hourly_data["wind_speed_120m"] = hourly_wind_speed_120m
hourly_data["wind_speed_180m"] = hourly_wind_speed_180m
hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
hourly_data["wind_direction_80m"] = hourly_wind_direction_80m
hourly_data["wind_direction_120m"] = hourly_wind_direction_120m
hourly_data["wind_direction_180m"] = hourly_wind_direction_180m
hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m
hourly_data["temperature_80m"] = hourly_temperature_80m
hourly_data["temperature_120m"] = hourly_temperature_120m
hourly_data["temperature_180m"] = hourly_temperature_180m
hourly_data["soil_temperature_0cm"] = hourly_soil_temperature_0cm
hourly_data["soil_temperature_6cm"] = hourly_soil_temperature_6cm
hourly_data["soil_temperature_18cm"] = hourly_soil_temperature_18cm
hourly_data["soil_temperature_54cm"] = hourly_soil_temperature_54cm
hourly_data["soil_moisture_0_to_1cm"] = hourly_soil_moisture_0_to_1cm
hourly_data["soil_moisture_1_to_3cm"] = hourly_soil_moisture_1_to_3cm
hourly_data["soil_moisture_3_to_9cm"] = hourly_soil_moisture_3_to_9cm
hourly_data["soil_moisture_9_to_27cm"] = hourly_soil_moisture_9_to_27cm
hourly_data["soil_moisture_27_to_81cm"] = hourly_soil_moisture_27_to_81cm

df21 = pd.DataFrame(data = hourly_data)
print(df21)
# Out:
# Coordinates -11.875°N -77.125°E
# Elevation 133.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#                           date  temperature_2m  relative_humidity_2m  \
# 0    2024-12-01 00:00:00+00:00             NaN                   NaN
# 1    2024-12-01 01:00:00+00:00             NaN                   NaN
# 2    2024-12-01 02:00:00+00:00             NaN                   NaN
# 3    2024-12-01 03:00:00+00:00             NaN                   NaN
# 4    2024-12-01 04:00:00+00:00             NaN                   NaN
# ...                        ...             ...                   ...
# 2251 2025-03-04 19:00:00+00:00       29.159000                  53.0
# 2252 2025-03-04 20:00:00+00:00       28.409000                  56.0
# 2253 2025-03-04 21:00:00+00:00       27.009001                  63.0
# 2254 2025-03-04 22:00:00+00:00       26.009001                  67.0
# 2255 2025-03-04 23:00:00+00:00       24.809000                  73.0
#
#       dew_point_2m  apparent_temperature  precipitation_probability  \
# 0              NaN                   NaN                        0.0
# 1              NaN                   NaN                        0.0
# 2              NaN                   NaN                        0.0
# 3              NaN                   NaN                        0.0
# 4              NaN                   NaN                        0.0
# ...            ...                   ...                        ...
# 2251     18.603468             32.769688                        0.0
# 2252     18.788656             31.295605                        0.0
# 2253     19.365644             28.998665                        0.0
# 2254     19.407465             28.440849                        0.0
# 2255     19.639824             27.545174                        0.0
#
#       precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0               NaN   NaN      NaN       NaN  ...               NaN
# 1               NaN   NaN      NaN       NaN  ...               NaN
# 2               NaN   NaN      NaN       NaN  ...               NaN
# 3               NaN   NaN      NaN       NaN  ...               NaN
# 4               NaN   NaN      NaN       NaN  ...               NaN
# ...             ...   ...      ...       ...  ...               ...
# 2251            0.0   0.0      0.0       0.0  ...         23.559000
# 2252            0.0   0.0      0.0       0.0  ...         23.259001
# 2253            0.0   0.0      0.0       0.0  ...         22.559000
# 2254            0.0   0.0      0.0       0.0  ...         22.259001
# 2255            0.0   0.0      0.0       0.0  ...         21.559000
#
#       soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2251             41.808998             35.859001              29.409000
# 2252             38.759003             36.009003              29.858999
# 2253             33.609001             35.158997              30.209000
# 2254             30.309000             33.709000              30.409000
# 2255             27.309000             32.009003              30.559000
#
#       soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 2251              28.608999                   0.077                   0.099
# 2252              28.608999                   0.076                   0.099
# 2253              28.608999                   0.076                   0.099
# 2254              28.608999                   0.076                   0.099
# 2255              28.608999                   0.076                   0.099
#
#       soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2251                   0.148                    0.194
# 2252                   0.148                    0.194
# 2253                   0.148                    0.194
# 2254                   0.148                    0.194
# 2255                   0.148                    0.194
#
#       soil_moisture_27_to_81cm
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2251                     0.242
# 2252                     0.242
# 2253                     0.242
# 2254                     0.242
# 2255                     0.242
#
# [2256 rows x 43 columns]

# %%
df21["Country"] = "Lima"

# %%
df = pd.concat([df, df21])

# %%
df.shape
# Out:
# (47376, 44)

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": -33.91,
	"longitude": 18.42,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth", "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", "soil_moisture_27_to_81cm"],
	"start_date": "2024-12-01",
	"end_date": "2025-03-04"
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_showers = hourly.Variables(7).ValuesAsNumpy()
hourly_snowfall = hourly.Variables(8).ValuesAsNumpy()
hourly_snow_depth = hourly.Variables(9).ValuesAsNumpy()
hourly_weather_code = hourly.Variables(10).ValuesAsNumpy()
hourly_pressure_msl = hourly.Variables(11).ValuesAsNumpy()
hourly_surface_pressure = hourly.Variables(12).ValuesAsNumpy()
hourly_cloud_cover = hourly.Variables(13).ValuesAsNumpy()
hourly_cloud_cover_low = hourly.Variables(14).ValuesAsNumpy()
hourly_cloud_cover_mid = hourly.Variables(15).ValuesAsNumpy()
hourly_cloud_cover_high = hourly.Variables(16).ValuesAsNumpy()
hourly_visibility = hourly.Variables(17).ValuesAsNumpy()
hourly_evapotranspiration = hourly.Variables(18).ValuesAsNumpy()
hourly_et0_fao_evapotranspiration = hourly.Variables(19).ValuesAsNumpy()
hourly_vapour_pressure_deficit = hourly.Variables(20).ValuesAsNumpy()
hourly_wind_speed_10m = hourly.Variables(21).ValuesAsNumpy()
hourly_wind_speed_80m = hourly.Variables(22).ValuesAsNumpy()
hourly_wind_speed_120m = hourly.Variables(23).ValuesAsNumpy()
hourly_wind_speed_180m = hourly.Variables(24).ValuesAsNumpy()
hourly_wind_direction_10m = hourly.Variables(25).ValuesAsNumpy()
hourly_wind_direction_80m = hourly.Variables(26).ValuesAsNumpy()
hourly_wind_direction_120m = hourly.Variables(27).ValuesAsNumpy()
hourly_wind_direction_180m = hourly.Variables(28).ValuesAsNumpy()
hourly_wind_gusts_10m = hourly.Variables(29).ValuesAsNumpy()
hourly_temperature_80m = hourly.Variables(30).ValuesAsNumpy()
hourly_temperature_120m = hourly.Variables(31).ValuesAsNumpy()
hourly_temperature_180m = hourly.Variables(32).ValuesAsNumpy()
hourly_soil_temperature_0cm = hourly.Variables(33).ValuesAsNumpy()
hourly_soil_temperature_6cm = hourly.Variables(34).ValuesAsNumpy()
hourly_soil_temperature_18cm = hourly.Variables(35).ValuesAsNumpy()
hourly_soil_temperature_54cm = hourly.Variables(36).ValuesAsNumpy()
hourly_soil_moisture_0_to_1cm = hourly.Variables(37).ValuesAsNumpy()
hourly_soil_moisture_1_to_3cm = hourly.Variables(38).ValuesAsNumpy()
hourly_soil_moisture_3_to_9cm = hourly.Variables(39).ValuesAsNumpy()
hourly_soil_moisture_9_to_27cm = hourly.Variables(40).ValuesAsNumpy()
hourly_soil_moisture_27_to_81cm = hourly.Variables(41).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["showers"] = hourly_showers
hourly_data["snowfall"] = hourly_snowfall
hourly_data["snow_depth"] = hourly_snow_depth
hourly_data["weather_code"] = hourly_weather_code
hourly_data["pressure_msl"] = hourly_pressure_msl
hourly_data["surface_pressure"] = hourly_surface_pressure
hourly_data["cloud_cover"] = hourly_cloud_cover
hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
hourly_data["visibility"] = hourly_visibility
hourly_data["evapotranspiration"] = hourly_evapotranspiration
hourly_data["et0_fao_evapotranspiration"] = hourly_et0_fao_evapotranspiration
hourly_data["vapour_pressure_deficit"] = hourly_vapour_pressure_deficit
hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
hourly_data["wind_speed_80m"] = hourly_wind_speed_80m
hourly_data["wind_speed_120m"] = hourly_wind_speed_120m
hourly_data["wind_speed_180m"] = hourly_wind_speed_180m
hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
hourly_data["wind_direction_80m"] = hourly_wind_direction_80m
hourly_data["wind_direction_120m"] = hourly_wind_direction_120m
hourly_data["wind_direction_180m"] = hourly_wind_direction_180m
hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m
hourly_data["temperature_80m"] = hourly_temperature_80m
hourly_data["temperature_120m"] = hourly_temperature_120m
hourly_data["temperature_180m"] = hourly_temperature_180m
hourly_data["soil_temperature_0cm"] = hourly_soil_temperature_0cm
hourly_data["soil_temperature_6cm"] = hourly_soil_temperature_6cm
hourly_data["soil_temperature_18cm"] = hourly_soil_temperature_18cm
hourly_data["soil_temperature_54cm"] = hourly_soil_temperature_54cm
hourly_data["soil_moisture_0_to_1cm"] = hourly_soil_moisture_0_to_1cm
hourly_data["soil_moisture_1_to_3cm"] = hourly_soil_moisture_1_to_3cm
hourly_data["soil_moisture_3_to_9cm"] = hourly_soil_moisture_3_to_9cm
hourly_data["soil_moisture_9_to_27cm"] = hourly_soil_moisture_9_to_27cm
hourly_data["soil_moisture_27_to_81cm"] = hourly_soil_moisture_27_to_81cm

df22 = pd.DataFrame(data = hourly_data)
print(df22)
# Out:
# Coordinates -34.0°N 18.5°E
# Elevation 0.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#                           date  temperature_2m  relative_humidity_2m  \
# 0    2024-12-01 00:00:00+00:00             NaN                   NaN
# 1    2024-12-01 01:00:00+00:00             NaN                   NaN
# 2    2024-12-01 02:00:00+00:00             NaN                   NaN
# 3    2024-12-01 03:00:00+00:00             NaN                   NaN
# 4    2024-12-01 04:00:00+00:00             NaN                   NaN
# ...                        ...             ...                   ...
# 2251 2025-03-04 19:00:00+00:00       21.113501                  84.0
# 2252 2025-03-04 20:00:00+00:00       21.013500                  83.0
# 2253 2025-03-04 21:00:00+00:00       20.813499                  86.0
# 2254 2025-03-04 22:00:00+00:00       20.563499                  87.0
# 2255 2025-03-04 23:00:00+00:00       20.363501                  88.0
#
#       dew_point_2m  apparent_temperature  precipitation_probability  \
# 0              NaN                   NaN                        0.0
# 1              NaN                   NaN                        0.0
# 2              NaN                   NaN                        0.0
# 3              NaN                   NaN                        0.0
# 4              NaN                   NaN                        0.0
# ...            ...                   ...                        ...
# 2251     18.303595             22.320580                        0.0
# 2252     18.015036             22.292810                        0.0
# 2253     18.384821             22.417400                        0.0
# 2254     18.323633             22.354607                        0.0
# 2255     18.309122             22.310421                        0.0
#
#       precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0               NaN   NaN      NaN       NaN  ...               NaN
# 1               NaN   NaN      NaN       NaN  ...               NaN
# 2               NaN   NaN      NaN       NaN  ...               NaN
# 3               NaN   NaN      NaN       NaN  ...               NaN
# 4               NaN   NaN      NaN       NaN  ...               NaN
# ...             ...   ...      ...       ...  ...               ...
# 2251            0.0   0.0      0.0       0.0  ...         19.013500
# 2252            0.0   0.0      0.0       0.0  ...         19.113501
# 2253            0.0   0.0      0.0       0.0  ...         18.913500
# 2254            0.0   0.0      0.0       0.0  ...         18.813499
# 2255            0.0   0.0      0.0       0.0  ...         18.613501
#
#       soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2251             21.013500             23.113501                25.9135
# 2252             20.963501             22.763500                25.4135
# 2253             20.813499             22.513500                24.9135
# 2254             20.513500             22.213501                24.5135
# 2255             20.263500             21.913500                24.1635
#
#       soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 2251              25.013500                   0.050                   0.057
# 2252              25.013500                   0.050                   0.057
# 2253              24.963501                   0.051                   0.057
# 2254              24.963501                   0.051                   0.058
# 2255              24.913500                   0.052                   0.058
#
#       soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2251                   0.075                    0.105
# 2252                   0.075                    0.105
# 2253                   0.075                    0.105
# 2254                   0.075                    0.105
# 2255                   0.075                    0.105
#
#       soil_moisture_27_to_81cm
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2251                     0.149
# 2252                     0.149
# 2253                     0.149
# 2254                     0.149
# 2255                     0.149
#
# [2256 rows x 43 columns]

# %%
df22["Country"] = "Cape Town"

# %%
df = pd.concat([df, df22])

# %%
df.shape
# Out:
# (49632, 44)

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": -45.03,
	"longitude": 168.66,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth", "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", "soil_moisture_27_to_81cm"],
	"start_date": "2024-12-01",
	"end_date": "2025-03-04"
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_showers = hourly.Variables(7).ValuesAsNumpy()
hourly_snowfall = hourly.Variables(8).ValuesAsNumpy()
hourly_snow_depth = hourly.Variables(9).ValuesAsNumpy()
hourly_weather_code = hourly.Variables(10).ValuesAsNumpy()
hourly_pressure_msl = hourly.Variables(11).ValuesAsNumpy()
hourly_surface_pressure = hourly.Variables(12).ValuesAsNumpy()
hourly_cloud_cover = hourly.Variables(13).ValuesAsNumpy()
hourly_cloud_cover_low = hourly.Variables(14).ValuesAsNumpy()
hourly_cloud_cover_mid = hourly.Variables(15).ValuesAsNumpy()
hourly_cloud_cover_high = hourly.Variables(16).ValuesAsNumpy()
hourly_visibility = hourly.Variables(17).ValuesAsNumpy()
hourly_evapotranspiration = hourly.Variables(18).ValuesAsNumpy()
hourly_et0_fao_evapotranspiration = hourly.Variables(19).ValuesAsNumpy()
hourly_vapour_pressure_deficit = hourly.Variables(20).ValuesAsNumpy()
hourly_wind_speed_10m = hourly.Variables(21).ValuesAsNumpy()
hourly_wind_speed_80m = hourly.Variables(22).ValuesAsNumpy()
hourly_wind_speed_120m = hourly.Variables(23).ValuesAsNumpy()
hourly_wind_speed_180m = hourly.Variables(24).ValuesAsNumpy()
hourly_wind_direction_10m = hourly.Variables(25).ValuesAsNumpy()
hourly_wind_direction_80m = hourly.Variables(26).ValuesAsNumpy()
hourly_wind_direction_120m = hourly.Variables(27).ValuesAsNumpy()
hourly_wind_direction_180m = hourly.Variables(28).ValuesAsNumpy()
hourly_wind_gusts_10m = hourly.Variables(29).ValuesAsNumpy()
hourly_temperature_80m = hourly.Variables(30).ValuesAsNumpy()
hourly_temperature_120m = hourly.Variables(31).ValuesAsNumpy()
hourly_temperature_180m = hourly.Variables(32).ValuesAsNumpy()
hourly_soil_temperature_0cm = hourly.Variables(33).ValuesAsNumpy()
hourly_soil_temperature_6cm = hourly.Variables(34).ValuesAsNumpy()
hourly_soil_temperature_18cm = hourly.Variables(35).ValuesAsNumpy()
hourly_soil_temperature_54cm = hourly.Variables(36).ValuesAsNumpy()
hourly_soil_moisture_0_to_1cm = hourly.Variables(37).ValuesAsNumpy()
hourly_soil_moisture_1_to_3cm = hourly.Variables(38).ValuesAsNumpy()
hourly_soil_moisture_3_to_9cm = hourly.Variables(39).ValuesAsNumpy()
hourly_soil_moisture_9_to_27cm = hourly.Variables(40).ValuesAsNumpy()
hourly_soil_moisture_27_to_81cm = hourly.Variables(41).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["showers"] = hourly_showers
hourly_data["snowfall"] = hourly_snowfall
hourly_data["snow_depth"] = hourly_snow_depth
hourly_data["weather_code"] = hourly_weather_code
hourly_data["pressure_msl"] = hourly_pressure_msl
hourly_data["surface_pressure"] = hourly_surface_pressure
hourly_data["cloud_cover"] = hourly_cloud_cover
hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
hourly_data["visibility"] = hourly_visibility
hourly_data["evapotranspiration"] = hourly_evapotranspiration
hourly_data["et0_fao_evapotranspiration"] = hourly_et0_fao_evapotranspiration
hourly_data["vapour_pressure_deficit"] = hourly_vapour_pressure_deficit
hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
hourly_data["wind_speed_80m"] = hourly_wind_speed_80m
hourly_data["wind_speed_120m"] = hourly_wind_speed_120m
hourly_data["wind_speed_180m"] = hourly_wind_speed_180m
hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
hourly_data["wind_direction_80m"] = hourly_wind_direction_80m
hourly_data["wind_direction_120m"] = hourly_wind_direction_120m
hourly_data["wind_direction_180m"] = hourly_wind_direction_180m
hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m
hourly_data["temperature_80m"] = hourly_temperature_80m
hourly_data["temperature_120m"] = hourly_temperature_120m
hourly_data["temperature_180m"] = hourly_temperature_180m
hourly_data["soil_temperature_0cm"] = hourly_soil_temperature_0cm
hourly_data["soil_temperature_6cm"] = hourly_soil_temperature_6cm
hourly_data["soil_temperature_18cm"] = hourly_soil_temperature_18cm
hourly_data["soil_temperature_54cm"] = hourly_soil_temperature_54cm
hourly_data["soil_moisture_0_to_1cm"] = hourly_soil_moisture_0_to_1cm
hourly_data["soil_moisture_1_to_3cm"] = hourly_soil_moisture_1_to_3cm
hourly_data["soil_moisture_3_to_9cm"] = hourly_soil_moisture_3_to_9cm
hourly_data["soil_moisture_9_to_27cm"] = hourly_soil_moisture_9_to_27cm
hourly_data["soil_moisture_27_to_81cm"] = hourly_soil_moisture_27_to_81cm

df23 = pd.DataFrame(data = hourly_data)
print(df23)
# Out:
# Coordinates -45.0°N 168.75°E
# Elevation 318.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#                           date  temperature_2m  relative_humidity_2m  \
# 0    2024-12-01 00:00:00+00:00             NaN                   NaN
# 1    2024-12-01 01:00:00+00:00             NaN                   NaN
# 2    2024-12-01 02:00:00+00:00             NaN                   NaN
# 3    2024-12-01 03:00:00+00:00             NaN                   NaN
# 4    2024-12-01 04:00:00+00:00             NaN                   NaN
# ...                        ...             ...                   ...
# 2251 2025-03-04 19:00:00+00:00          8.2085                  79.0
# 2252 2025-03-04 20:00:00+00:00          8.7585                  75.0
# 2253 2025-03-04 21:00:00+00:00          9.7085                  69.0
# 2254 2025-03-04 22:00:00+00:00         11.0085                  63.0
# 2255 2025-03-04 23:00:00+00:00         12.6585                  57.0
#
#       dew_point_2m  apparent_temperature  precipitation_probability  \
# 0              NaN                   NaN                        0.0
# 1              NaN                   NaN                        0.0
# 2              NaN                   NaN                        0.0
# 3              NaN                   NaN                        0.0
# 4              NaN                   NaN                        0.0
# ...            ...                   ...                        ...
# 2251      4.782106              5.799006                        0.0
# 2252      4.571245              6.135322                        0.0
# 2253      4.293321              6.936666                        0.0
# 2254      4.232690              8.247125                        0.0
# 2255      4.357234             10.678218                        0.0
#
#       precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0               NaN   NaN      NaN       NaN  ...               NaN
# 1               NaN   NaN      NaN       NaN  ...               NaN
# 2               NaN   NaN      NaN       NaN  ...               NaN
# 3               NaN   NaN      NaN       NaN  ...               NaN
# 4               NaN   NaN      NaN       NaN  ...               NaN
# ...             ...   ...      ...       ...  ...               ...
# 2251            0.0   0.0      0.0       0.0  ...            6.0085
# 2252            0.0   0.0      0.0       0.0  ...            5.8085
# 2253            0.0   0.0      0.0       0.0  ...            6.2085
# 2254            0.0   0.0      0.0       0.0  ...            7.0085
# 2255            0.0   0.0      0.0       0.0  ...            8.3085
#
#       soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2251             11.108500               10.6085                14.9085
# 2252             13.358500               11.0085                14.6585
# 2253             16.308500               12.2085                14.5085
# 2254             18.508499               13.8585                14.5085
# 2255             21.258499               15.6585                14.6585
#
#       soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 2251              18.358501                   0.143                   0.145
# 2252              18.308498                   0.143                   0.145
# 2253              18.308498                   0.142                   0.145
# 2254              18.258499                   0.140                   0.145
# 2255              18.208500                   0.136                   0.143
#
#       soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2251                   0.152                    0.163
# 2252                   0.152                    0.163
# 2253                   0.152                    0.163
# 2254                   0.152                    0.163
# 2255                   0.151                    0.163
#
#       soil_moisture_27_to_81cm
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2251                     0.171
# 2252                     0.171
# 2253                     0.171
# 2254                     0.171
# 2255                     0.171
#
# [2256 rows x 43 columns]

# %%
df23["Country"] = "Queenstown"

# %%
df = pd.concat([df, df23])

# %%
df.shape
# Out:
# (51888, 44)

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": -37.81,
	"longitude": 144.96,
	"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "precipitation_probability", "precipitation", "rain", "showers", "snowfall", "snow_depth", "weather_code", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "visibility", "evapotranspiration", "et0_fao_evapotranspiration", "vapour_pressure_deficit", "wind_speed_10m", "wind_speed_80m", "wind_speed_120m", "wind_speed_180m", "wind_direction_10m", "wind_direction_80m", "wind_direction_120m", "wind_direction_180m", "wind_gusts_10m", "temperature_80m", "temperature_120m", "temperature_180m", "soil_temperature_0cm", "soil_temperature_6cm", "soil_temperature_18cm", "soil_temperature_54cm", "soil_moisture_0_to_1cm", "soil_moisture_1_to_3cm", "soil_moisture_3_to_9cm", "soil_moisture_9_to_27cm", "soil_moisture_27_to_81cm"],
	"start_date": "2024-12-01",
	"end_date": "2025-03-04"
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
hourly_precipitation_probability = hourly.Variables(4).ValuesAsNumpy()
hourly_precipitation = hourly.Variables(5).ValuesAsNumpy()
hourly_rain = hourly.Variables(6).ValuesAsNumpy()
hourly_showers = hourly.Variables(7).ValuesAsNumpy()
hourly_snowfall = hourly.Variables(8).ValuesAsNumpy()
hourly_snow_depth = hourly.Variables(9).ValuesAsNumpy()
hourly_weather_code = hourly.Variables(10).ValuesAsNumpy()
hourly_pressure_msl = hourly.Variables(11).ValuesAsNumpy()
hourly_surface_pressure = hourly.Variables(12).ValuesAsNumpy()
hourly_cloud_cover = hourly.Variables(13).ValuesAsNumpy()
hourly_cloud_cover_low = hourly.Variables(14).ValuesAsNumpy()
hourly_cloud_cover_mid = hourly.Variables(15).ValuesAsNumpy()
hourly_cloud_cover_high = hourly.Variables(16).ValuesAsNumpy()
hourly_visibility = hourly.Variables(17).ValuesAsNumpy()
hourly_evapotranspiration = hourly.Variables(18).ValuesAsNumpy()
hourly_et0_fao_evapotranspiration = hourly.Variables(19).ValuesAsNumpy()
hourly_vapour_pressure_deficit = hourly.Variables(20).ValuesAsNumpy()
hourly_wind_speed_10m = hourly.Variables(21).ValuesAsNumpy()
hourly_wind_speed_80m = hourly.Variables(22).ValuesAsNumpy()
hourly_wind_speed_120m = hourly.Variables(23).ValuesAsNumpy()
hourly_wind_speed_180m = hourly.Variables(24).ValuesAsNumpy()
hourly_wind_direction_10m = hourly.Variables(25).ValuesAsNumpy()
hourly_wind_direction_80m = hourly.Variables(26).ValuesAsNumpy()
hourly_wind_direction_120m = hourly.Variables(27).ValuesAsNumpy()
hourly_wind_direction_180m = hourly.Variables(28).ValuesAsNumpy()
hourly_wind_gusts_10m = hourly.Variables(29).ValuesAsNumpy()
hourly_temperature_80m = hourly.Variables(30).ValuesAsNumpy()
hourly_temperature_120m = hourly.Variables(31).ValuesAsNumpy()
hourly_temperature_180m = hourly.Variables(32).ValuesAsNumpy()
hourly_soil_temperature_0cm = hourly.Variables(33).ValuesAsNumpy()
hourly_soil_temperature_6cm = hourly.Variables(34).ValuesAsNumpy()
hourly_soil_temperature_18cm = hourly.Variables(35).ValuesAsNumpy()
hourly_soil_temperature_54cm = hourly.Variables(36).ValuesAsNumpy()
hourly_soil_moisture_0_to_1cm = hourly.Variables(37).ValuesAsNumpy()
hourly_soil_moisture_1_to_3cm = hourly.Variables(38).ValuesAsNumpy()
hourly_soil_moisture_3_to_9cm = hourly.Variables(39).ValuesAsNumpy()
hourly_soil_moisture_9_to_27cm = hourly.Variables(40).ValuesAsNumpy()
hourly_soil_moisture_27_to_81cm = hourly.Variables(41).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m
hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
hourly_data["dew_point_2m"] = hourly_dew_point_2m
hourly_data["apparent_temperature"] = hourly_apparent_temperature
hourly_data["precipitation_probability"] = hourly_precipitation_probability
hourly_data["precipitation"] = hourly_precipitation
hourly_data["rain"] = hourly_rain
hourly_data["showers"] = hourly_showers
hourly_data["snowfall"] = hourly_snowfall
hourly_data["snow_depth"] = hourly_snow_depth
hourly_data["weather_code"] = hourly_weather_code
hourly_data["pressure_msl"] = hourly_pressure_msl
hourly_data["surface_pressure"] = hourly_surface_pressure
hourly_data["cloud_cover"] = hourly_cloud_cover
hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
hourly_data["visibility"] = hourly_visibility
hourly_data["evapotranspiration"] = hourly_evapotranspiration
hourly_data["et0_fao_evapotranspiration"] = hourly_et0_fao_evapotranspiration
hourly_data["vapour_pressure_deficit"] = hourly_vapour_pressure_deficit
hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
hourly_data["wind_speed_80m"] = hourly_wind_speed_80m
hourly_data["wind_speed_120m"] = hourly_wind_speed_120m
hourly_data["wind_speed_180m"] = hourly_wind_speed_180m
hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
hourly_data["wind_direction_80m"] = hourly_wind_direction_80m
hourly_data["wind_direction_120m"] = hourly_wind_direction_120m
hourly_data["wind_direction_180m"] = hourly_wind_direction_180m
hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m
hourly_data["temperature_80m"] = hourly_temperature_80m
hourly_data["temperature_120m"] = hourly_temperature_120m
hourly_data["temperature_180m"] = hourly_temperature_180m
hourly_data["soil_temperature_0cm"] = hourly_soil_temperature_0cm
hourly_data["soil_temperature_6cm"] = hourly_soil_temperature_6cm
hourly_data["soil_temperature_18cm"] = hourly_soil_temperature_18cm
hourly_data["soil_temperature_54cm"] = hourly_soil_temperature_54cm
hourly_data["soil_moisture_0_to_1cm"] = hourly_soil_moisture_0_to_1cm
hourly_data["soil_moisture_1_to_3cm"] = hourly_soil_moisture_1_to_3cm
hourly_data["soil_moisture_3_to_9cm"] = hourly_soil_moisture_3_to_9cm
hourly_data["soil_moisture_9_to_27cm"] = hourly_soil_moisture_9_to_27cm
hourly_data["soil_moisture_27_to_81cm"] = hourly_soil_moisture_27_to_81cm

df24 = pd.DataFrame(data = hourly_data)
print(df24)
# Out:
# Coordinates -37.75°N 145.0°E
# Elevation 21.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s
#                           date  temperature_2m  relative_humidity_2m  \
# 0    2024-12-01 00:00:00+00:00             NaN                   NaN
# 1    2024-12-01 01:00:00+00:00             NaN                   NaN
# 2    2024-12-01 02:00:00+00:00             NaN                   NaN
# 3    2024-12-01 03:00:00+00:00             NaN                   NaN
# 4    2024-12-01 04:00:00+00:00             NaN                   NaN
# ...                        ...             ...                   ...
# 2251 2025-03-04 19:00:00+00:00       20.824001                  56.0
# 2252 2025-03-04 20:00:00+00:00       20.924000                  56.0
# 2253 2025-03-04 21:00:00+00:00       21.424000                  53.0
# 2254 2025-03-04 22:00:00+00:00       22.874001                  44.0
# 2255 2025-03-04 23:00:00+00:00       24.924000                  37.0
#
#       dew_point_2m  apparent_temperature  precipitation_probability  \
# 0              NaN                   NaN                        0.0
# 1              NaN                   NaN                        4.0
# 2              NaN                   NaN                        9.0
# 3              NaN                   NaN                       19.0
# 4              NaN                   NaN                       36.0
# ...            ...                   ...                        ...
# 2251     11.724771             19.986824                        0.0
# 2252     11.817991             19.959187                        0.0
# 2253     11.448860             20.081091                        0.0
# 2254      9.979030             20.565742                        0.0
# 2255      9.233466             22.141218                        0.0
#
#       precipitation  rain  showers  snowfall  ...  temperature_180m  \
# 0               NaN   NaN      NaN       NaN  ...               NaN
# 1               NaN   NaN      NaN       NaN  ...               NaN
# 2               NaN   NaN      NaN       NaN  ...               NaN
# 3               NaN   NaN      NaN       NaN  ...               NaN
# 4               NaN   NaN      NaN       NaN  ...               NaN
# ...             ...   ...      ...       ...  ...               ...
# 2251            0.0   0.0      0.0       0.0  ...         22.324001
# 2252            0.0   0.0      0.0       0.0  ...         21.724001
# 2253            0.0   0.0      0.0       0.0  ...         20.824001
# 2254            0.0   0.0      0.0       0.0  ...         20.224001
# 2255            0.0   0.0      0.0       0.0  ...         21.424000
#
#       soil_temperature_0cm  soil_temperature_6cm  soil_temperature_18cm  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
# 3                      NaN                   NaN                    NaN
# 4                      NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 2251             18.474001             19.674000              22.724001
# 2252             18.874001             19.824001              22.524000
# 2253             20.674000             20.074001              22.374001
# 2254             25.024000             21.024000              22.224001
# 2255             28.974001             22.824001              22.174000
#
#       soil_temperature_54cm  soil_moisture_0_to_1cm  soil_moisture_1_to_3cm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 2251              21.574001                   0.237                   0.248
# 2252              21.574001                   0.238                   0.249
# 2253              21.574001                   0.238                   0.249
# 2254              21.624001                   0.237                   0.249
# 2255              21.624001                   0.236                   0.249
#
#       soil_moisture_3_to_9cm  soil_moisture_9_to_27cm  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2251                   0.273                    0.306
# 2252                   0.273                    0.306
# 2253                   0.273                    0.306
# 2254                   0.272                    0.305
# 2255                   0.272                    0.305
#
#       soil_moisture_27_to_81cm
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 2251                     0.353
# 2252                     0.353
# 2253                     0.353
# 2254                     0.353
# 2255                     0.353
#
# [2256 rows x 43 columns]

# %%
df24["Country"] = "Melbourne"

# %%
df = pd.concat([df, df24])

# %%
df.shape
# Out:
# (54144, 44)

# %%
csv_file_path = "weather_data.csv"
df.to_csv(csv_file_path)
